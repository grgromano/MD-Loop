# %%
from D_CODE.run_simulation import run as run_SRT
from D_CODE.run_simulation_vi import run as run_DCODE

# %% [markdown]
# ### STD:

# %% [markdown]
# ##### SR-T

# %%
# setting:
ode_name = 'GompertzODE' # help="name of the ode", type=str
ode_param = '1.5,1.5' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE, ode_param=1.5,1.5, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# updated version 0
# 0
# 0.01
# (41, 50, 1)
# [0.01052971 0.01971066 0.0214243  0.04367502 0.0566261  0.08562108
#  0.11359581 0.139703   0.1759595  0.21277205 0.25158077 0.28734482
#  0.32150475 0.354586   0.38932217 0.41939919 0.44419043 0.46989698
#  0.4958048  0.5165569 ]
# Numerical differentiation: Done.
# Running with seed 100
#
# Forza Italia!!
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    13.78      1.72517e+14       21        0.0303987        0.0316181      2.54m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     6.57           1775.4        9        0.0680977        0.0677715      1.73m
#    2     3.03          331.449        9        0.0683578        0.0654303      1.64m
#
# promising programs:
# log(1.136)
# log(1.143)
# log(1.143)
# log(1.149)
# log(1.143)
# log(1.128)
# log(1.149)
# log(1.128)
# log(1.128)
# log(1.150)
# log(1.150)
# log(1.128)
# log(1.150)
# log(1.136)
# log(1.124)
#
#    3     2.36          17.3838       24        0.0677334        0.0678542      1.58m
#    4     2.38          3021.99        2         0.105394         0.129098      1.44m
# 0.1205207232648644
# C
# [[0.00270238]
#  [0.0074834 ]
#  [0.00097286]
#  [0.00484744]
#  [0.00914889]
#  [0.00906465]
#  [0.0054259 ]
#  [0.00664914]
#  [0.00128501]
#  [0.00194489]]
# building blocks:
# number of building blocks:  0
#
#
# C
# False

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'GompertzODE' # help="name of the ode", type=str
ode_param = '1.5,1.5' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 25 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE, ode_param=1.5,1.5, x_id=0, freq=10, n_sample=25, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (81, 25, 1)
# (161, 25, 1)
# [0.01436104 0.01944147 0.0250178  0.03124716 0.03856975 0.04734454
#  0.0575598  0.06891211 0.08117257 0.09444035 0.10899285 0.12488943
#  0.14177327 0.15910126 0.17655295 0.19418195 0.2121871  0.23060483
#  0.24925936 0.26795161]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    10.67      4.02402e+13       12         0.184824         0.189281      2.40m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     9.54      4.50289e+08       23         0.125258         0.121833      1.74m
#    2     7.92      8.14792e+08       10        0.0134308        0.0138331      1.74m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#
# promising programs:
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), pow(X0, 1.933)))
# mul(sin(X0), sub(neg(log(X0)), pow(X0, 1.933)))
# mul(sin(X0), sub(neg(log(X0)), pow(X0, 1.933)))
# mul(sin(X0), sub(neg(log(X0)), pow(X0, 1.933)))
# mul(sin(X0), sub(neg(log(X0)), pow(X0, 1.933)))
# mul(log(pow(X0, 1.792)), sub(div(pow(X0, 1.703), cos(X0)), sin(X0)))
# div(sin(sub(log(1.552), mul(X0, X0))), sub(1.598, X0))
# div(sin(sub(log(1.552), mul(X0, X0))), sub(1.595, X0))
# mul(pow(X0, 1.026), sub(cos(add(X0, X0)), sin(log(add(X0, X0)))))
# mul(pow(X0, 1.026), sub(cos(add(X0, X0)), sin(log(add(X0, X0)))))
# sub(cos(div(pow(X0, 1.696), pow(X0, 1.792))), pow(X0, 1.679))
# sub(cos(div(pow(X0, 1.696), pow(X0, 1.792))), pow(X0, 1.679))
# sub(cos(div(pow(X0, 1.696), pow(X0, 1.792))), pow(X0, 1.679))
# sub(cos(div(pow(X0, 1.696), pow(X0, 1.792))), pow(X0, 1.679))
#
#    3    10.66      5.90888e+06       10        0.0467622        0.0444745      1.69m
#    4    11.68      1.31424e+07       22        0.0288061        0.0264319      1.60m
#
# promising programs:
# mul(X0, sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
# mul(sin(X0), sub(neg(log(X0)), mul(X0, X0)))
#
#    5    11.49       3.4036e+07       27         0.010459       0.00920389      1.49m
#    6    12.07      4.82814e+07       23       0.00710004       0.00558387      1.47m
#    7    11.67      5.36918e+08       23       0.00661881       0.00911286      1.28m
#    8    10.32      2.79232e+07       23       0.00674937       0.00815545      1.15m
#    9     9.93           451138       10        0.0103972        0.0146516      1.00m
#
# promising programs:
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
# mul(mul(1.477, X0), neg(log(mul(1.477, X0))))
#
#   10     9.97           958258       10       0.00995112        0.0142903     53.99s
#   11     9.75      5.67053e+06       10       0.00985568        0.0149902     48.19s
# mul(sin(mul(1.477, X0)), neg(log(mul(1.477, X0))))
# -log(1.4774099379841534*X0)*sin(1.4774099379841534*X0)
# -log(C*X0)*sin(C*X0)
# [[0.00382049]
#  [0.009678  ]
#  [0.00913533]
#  [0.00165177]
#  [0.00193938]
#  [0.00165092]
#  [0.00109176]
#  [0.00756645]
#  [0.00965467]
#  [0.00074588]]
# building blocks:
# pow(X0, 1.933)
# log(pow(X0, 1.792))
# cos(add(X0, X0))
# sin(log(add(X0, X0)))
# log(add(X0, X0))
# log(mul(1.477, X0))
# number of building blocks:  6
#
#
# -log(C*X0)*sin(C*X0)
# False

# %% [markdown]
# ### parameter $b$:

# %% [markdown]
# ##### SR-T

# %%
# setting:
ode_name = 'GompertzODE_par_b' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE_par_b, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# updated version 0
# [0.0, 1.0]
# [0.01, 2.0]
# (41, 50, 2)
# [0.00838977 0.01345293 0.02494    0.03930199 0.0545351  0.0814087
#  0.10418839 0.13324683 0.16097706 0.19302568 0.22590294 0.25719612
#  0.28768979 0.31802648 0.34881875 0.38057732 0.399272   0.41793973
#  0.44087904 0.46159024]
# Numerical differentiation: Done.
# Running with seed 100
#
# Forza Italia!!
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    12.10      4.18801e+11       36        0.0936501        0.0879769      4.07m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     6.25          2343.33       13        0.0322995        0.0439198      3.64m
#    2     3.08          128.639       13          0.03353        0.0328448      3.57m
#
# promising programs:
# log(1.133)
# log(1.141)
# log(1.133)
# log(1.141)
# log(1.141)
# log(1.128)
# log(1.133)
# log(1.133)
# log(1.132)
# log(1.133)
# log(1.144)
# log(1.128)
# log(1.130)
# log(1.141)
# log(1.130)
#
#    3     2.33          3774.45        2         0.102815         0.123087      3.79m
#    4     2.32          17105.2        2         0.102627         0.124781      3.37m
#
# promising programs:
# log(1.130)
# log(1.134)
# log(1.135)
# log(1.130)
# log(1.133)
# log(1.134)
# log(1.132)
# log(1.133)
# log(1.127)
# log(1.133)
# log(1.134)
# log(1.134)
# log(1.134)
# log(1.133)
# log(1.133)
#
#    5     2.32           106170        2         0.102084         0.130117      2.95m
# 0.12181253823546625
# C
# [[7.85946728e-03 5.73265558e-03 9.60285127e-03 8.25262236e-04
#   7.48654797e-03 2.50798372e-03 6.80113470e-03 5.00513292e-04
#   2.46151707e-03 9.70463161e-03]
#  [1.71510592e+00 1.95478039e+00 1.99506884e+00 1.31448214e+00
#   1.32967790e+00 1.00419455e+00 1.80416961e+00 1.83852577e+00
#   1.65764060e+00 1.83211442e+00]]
# building blocks:
# number of building blocks:  0
#
#
# C
# False

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'GompertzODE_par_b' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE_par_b, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (41, 50, 2)
# (81, 50, 2)
# [0.00659898 0.00906377 0.01253579 0.01679708 0.02184551 0.02788817
#  0.03514144 0.04363763 0.05321233 0.06365807 0.07487884 0.08690889
#  0.09981169 0.11357837 0.12811049 0.14327264 0.15894905 0.17506133
#  0.19154581 0.20830852]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79      9.29567e+15       20         0.110841         0.102764      4.50m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     7.57       2.9298e+10       20         0.107994         0.128388      4.05m
#    2     4.53      2.87999e+07       11        0.0944348         0.101089      3.61m
#
# promising programs:
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, cos(1.393)))), sin(log(mul(X0, X1))))
# log(1.173)
# log(1.176)
# log(1.174)
# cos(1.417)
# cos(1.428)
# cos(1.414)
#
#    3     2.44      4.37214e+06       11        0.0916729         0.125945      3.05m
#    4     2.36      6.82891e+06       11        0.0899317         0.141616      2.95m
#
# promising programs:
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), log(mul(X0, X1)))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
# mul(neg(sin(add(X0, X0))), sin(log(mul(X0, X1))))
#
#    5     2.61      4.09473e+11       11        0.0899374         0.141565      3.01m
#    6     3.64           666553       11        0.0860022         0.070732      2.56m
#    7     7.16      3.37377e+09       12        0.0651667        0.0697509      2.42m
#    8    10.46           317699        9         0.056776        0.0542358      2.23m
#    9    10.13       2.6446e+06        9        0.0548552        0.0682439      2.03m
#
# promising programs:
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.538, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.582)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(1.605, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.610)), log(mul(X0, X1)))
#
#   10     9.50      2.70165e+07        9        0.0535253        0.0802129      1.86m
#   11     8.99      1.03466e+06        9        0.0511878        0.0734249      1.64m
#   12     9.00      1.36543e+07       10        0.0500256        0.0999339      1.40m
#   13     9.01      6.03814e+07        9        0.0483226        0.0992116      1.20m
#   14     8.94      5.69924e+10        9        0.0499251         0.084789      1.01m
#   15     8.95      3.32992e+07        9        0.0481124        0.0974503     47.90s
#   16     8.93       5.8513e+07        9        0.0489121        0.0902526     36.40s
#   17     8.94      7.14979e+07        9        0.0487652        0.0915752     23.96s
#   18     8.92      5.24451e+08        9        0.0484332         0.094563     11.99s
#
# promising programs:
# mul(neg(mul(1.474, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.498)), log(mul(X0, X1)))
# mul(neg(mul(1.538, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.498)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.498)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.498)), log(mul(X0, X1)))
# mul(neg(mul(1.483, X0)), log(mul(X0, X1)))
# mul(neg(mul(1.538, X0)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.482)), log(mul(X0, X1)))
# mul(neg(mul(X0, 1.535)), log(mul(X0, X1)))
#
#   19     8.95           910554        9        0.0486351        0.0937533      0.00s
# mul(neg(mul(1.474, X0)), log(mul(X0, X1)))
# -1.4743639068951073*X0*log(X0*X1)
# -C*X0*log(X0*X1)
# [[9.85297922e-03 1.24063465e-03 4.91080473e-04 6.86177213e-03
#   7.80156591e-03 7.49671759e-03 1.43584005e-03 5.21157265e-03
#   4.68014388e-03 7.48538931e-03]
#  [1.30951346e+00 1.00348129e+00 1.63028311e+00 1.60335970e+00
#   1.11911624e+00 1.51153631e+00 1.96201795e+00 1.44840925e+00
#   1.03753338e+00 1.09261214e+00]]
# building blocks:
# log(mul(X0, X1))
# sin(add(X0, X0))
# sin(log(mul(X0, X1)))
# number of building blocks:  3
#
#
# -C*X0*log(X0*X1)
# True

# %% [markdown]
# ### parameters $a, b$:

# %% [markdown]
# ##### SR-T

# %%
# setting:
ode_name = 'GompertzODE_par_ab' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE_par_ab, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# updated version 0
# [0.0, 1.0, 1.0]
# [0.01, 2.0, 2.0]
# (81, 50, 3)
# [0.01170997 0.02531479 0.04288691 0.05988143 0.08839487 0.1170632
#  0.14225246 0.17644986 0.20244877 0.23842213 0.27130182 0.29741583
#  0.32170973 0.34794147 0.37144589 0.38907102 0.40570061 0.41786775
#  0.43676831 0.44434151]
# Numerical differentiation: Done.
# Running with seed 100
#
# Forza Italia!!
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          34798.8        9         0.074304        0.0752778      4.76m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     5.69           52.533       11        0.0517828        0.0516349      4.55m
#    2     3.35          23.4725       10        0.0741614        0.0766105      4.67m
#
# promising programs:
# log(1.011)
# log(1.011)
# log(1.011)
# log(1.007)
# cos(1.558)
# cos(1.558)
# cos(1.558)
# cos(1.554)
# log(1.009)
# log(1.009)
# log(1.011)
# cos(1.558)
# log(1.014)
# cos(1.558)
# cos(1.558)
#
#    3     2.32          6.14614        2        0.0798864         0.107239      4.42m
#    4     2.29          17.4478        2        0.0795816         0.110736      3.38m
#
# promising programs:
# log(1.011)
# log(1.011)
# log(1.011)
# log(1.011)
# log(1.011)
# cos(1.554)
# log(1.011)
# cos(1.554)
# cos(1.554)
# log(1.014)
# log(1.011)
# log(1.011)
# log(1.011)
# cos(1.554)
# log(1.009)
#
#    5     2.28          211.417        2        0.0802161         0.104272      4.94m
# 0.011248616431812481
# C
# [[9.45414235e-03 5.36446035e-03 3.24613281e-04 1.66800776e-03
#   6.77822041e-03 7.45388469e-04 4.45822966e-03 7.11622862e-03
#   3.51973213e-03 7.57539566e-03]
#  [1.81779161e+00 1.06036851e+00 1.46115472e+00 1.73890972e+00
#   1.66822182e+00 1.43198148e+00 1.96047101e+00 1.63778022e+00
#   1.76678405e+00 1.72294765e+00]
#  [1.66661570e+00 1.23605681e+00 1.31817885e+00 1.52179115e+00
#   1.53272840e+00 1.73257787e+00 1.12778758e+00 1.20053974e+00
#   1.29643439e+00 1.99660863e+00]]
# building blocks:
# number of building blocks:  0
#
#
# C
# False

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'GompertzODE_par_ab' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 25 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=GompertzODE_par_ab, ode_param=None, x_id=0, freq=10, n_sample=25, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (81, 25, 3)
# (161, 25, 3)
# [0.00842651 0.0115646  0.01508303 0.0193479  0.0247308  0.03140795
#  0.03929356 0.04816464 0.0578766  0.06848418 0.08015967 0.09298365
#  0.1068045  0.12130134 0.13619377 0.15140305 0.16701793 0.18310389
#  0.19953739 0.21601455]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      2.10896e+15       20          0.64517         0.550576      3.74m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     8.44      1.02204e+10       20         0.102578        0.0828515      3.67m
#    2     5.59      1.43199e+07       17        0.0199735        0.0096223      3.38m
#
# promising programs:
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(1.319, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(log(mul(X2, X0)), neg(X0))
# mul(log(mul(X2, X0)), neg(X0))
# mul(log(mul(X2, X0)), neg(X0))
# mul(div(mul(pow(X1, 1.928), 1.159), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(mul(pow(X1, 1.928), 1.159), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(mul(pow(X1, 1.928), 1.159), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(mul(pow(X1, 1.928), 1.159), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(log(mul(X2, X0)), neg(X0))
# mul(div(mul(pow(X1, 1.928), 1.159), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(log(mul(X2, X0)), neg(X0))
# mul(log(mul(X2, X0)), neg(X0))
#
#    3     4.27           983782       17        0.0186623        0.0192381      3.15m
#    4     6.44      1.31896e+07       17        0.0165329        0.0348535      3.02m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#
# promising programs:
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(pow(X1, 1.283), mul(log(mul(X2, X0)), neg(X0)))
# mul(div(mul(pow(X1, 1.928), sin(X2)), neg(div(X1, X0))), log(mul(X2, X0)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
# mul(div(add(X1, X1), neg(add(X0, X0))), mul(log(mul(X2, X0)), pow(X0, 1.971)))
#
#    5    11.81      4.11137e+10        9        0.0148403        0.0169413      3.30m
#    6    14.67       1.1073e+10        9        0.0130786        0.0298605      3.19m
#    7    12.95      2.43758e+09       17        0.0137854        0.0550023      2.75m
#    8    12.83      5.92399e+08        9        0.0116779        0.0401326      2.34m
#    9    13.71      2.32351e+09        9        0.0123423          0.03526      2.17m
#
# promising programs:
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(mul(log(mul(X2, X0)), neg(X0)), X1)
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(X1, mul(log(mul(X2, X0)), neg(X0)))
# mul(X1, mul(log(mul(X2, X0)), neg(X0)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(mul(log(mul(X2, X0)), neg(X0)), X1)
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
#
#   10    12.02      2.47833e+09        9         0.012005        0.0377335      1.88m
#   11     9.51       4.7994e+07        9        0.0116779        0.0401326      1.65m
#   12     8.93      1.69862e+07        9        0.0116779        0.0401326      1.50m
#   13     8.92      3.77377e+06        9        0.0116779        0.0401326      1.25m
#   14     8.90      4.05063e+06        9        0.0116779        0.0401326      1.01m
#   15     8.91      3.70946e+06        9        0.0116779        0.0401326     50.49s
# mul(log(mul(X2, X0)), neg(mul(X0, X1)))
# [[2.04327224e-03 3.16927072e-03 6.47489559e-03 3.32777824e-03
#   9.86116232e-03 4.68006378e-03 2.65015194e-03 7.03277234e-03
#   4.40678879e-03 3.11469647e-04]
#  [1.89858741e+00 1.81162862e+00 1.23091593e+00 1.89402391e+00
#   1.37738795e+00 1.04558953e+00 1.73286007e+00 1.18949278e+00
#   1.21571600e+00 1.28718969e+00]
#  [1.40779048e+00 1.29502431e+00 1.08568793e+00 1.98933484e+00
#   1.86623960e+00 1.66030110e+00 1.84750944e+00 1.38399183e+00
#   1.11327877e+00 1.31265154e+00]]
# building blocks:
# pow(X0, 1.971)
# log(mul(X2, X0))
# pow(X1, 1.928)
# pow(X1, 1.283)
# div(X1, X0)
# number of building blocks:  5
#
#
# -X0*X1*log(X0*X2)
# True
