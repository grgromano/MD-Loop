# %%
from D_CODE.run_simulation import run as run_SRT
from D_CODE.run_simulation_vi import run as run_DCODE

# %% [markdown]
# ### STD:

# %% [markdown]
# ##### SR-T

# %%
# setting:
ode_name = 'LogisticODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 5 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=LogisticODE, ode_param=None, x_id=0, freq=5, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# updated version 0
# 0
# 0.1
# (51, 50, 1)
# [0.09594072 0.11273574 0.11594045 0.14296686 0.15259521 0.17945353
#  0.20069856 0.21601533 0.24290603 0.26945305 0.29878276 0.32504304
#  0.3510476  0.37814397 0.41047832 0.43963737 0.46480539 0.49435666
#  0.52711671 0.5554979 ]
# Numerical differentiation: Done.
# Running with seed 100
#
# Forza Italia!!
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    10.71      6.53708e+07       11       0.00545119       0.00530243      1.90m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     6.56          73736.2        6        0.0041652       0.00280255      1.85m
#    2     3.06          44659.9        6       0.00344219       0.00930971      1.69m
#
# promising programs:
# log(1.089)
# cos(1.482)
# log(1.089)
# log(1.089)
# log(1.098)
# cos(1.486)
# log(1.089)
# cos(1.486)
# cos(1.486)
# log(1.098)
# log(1.098)
# log(1.098)
# log(1.089)
# log(1.098)
# log(1.098)
#
#    3     2.31          8.31762       12        0.0273616        0.0274251      1.66m
#    4     2.34           542.55        2        0.0375108        0.0427321      1.51m
#
# promising programs:
# cos(1.482)
# log(1.098)
# cos(1.482)
# log(1.098)
# log(1.098)
# log(1.098)
# log(1.098)
# log(1.098)
# log(1.092)
# cos(1.482)
# cos(1.482)
# log(1.091)
# log(1.098)
# log(1.098)
# log(1.092)
#
#    5     2.30          193.575        9        0.0267834        0.0260852      1.53m
#    6     2.30          10.7486        2        0.0374828        0.0422513      1.29m
# 0.088822729548477211
# C
# [[0.08006421]
#  [0.03580999]
#  [0.08930754]
#  [0.07750942]
#  [0.04861535]
#  [0.04657622]
#  [0.00212822]
#  [0.0779104 ]
#  [0.01092412]
#  [0.02937083]]
# building blocks:
# number of building blocks:  0
#
#
# C
# False

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'LogisticODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 5 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=LogisticODE, ode_param=None, x_id=0, freq=5, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (51, 50, 1)
# (201, 50, 1)
# [0.09364454 0.09730115 0.1006522  0.10380027 0.10685838 0.10993713
#  0.11313233 0.11651487 0.12012449 0.12396854 0.12802584 0.13225517
#  0.13660644 0.14103268 0.14550013 0.1499947  0.15452346 0.15911111
#  0.16379274 0.16860465]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    10.71      2.77458e+16       11        0.0102469       0.00740436      5.52m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1    10.25      1.10981e+10        5       0.00642339        0.0148969      4.63m
#    2     6.55      5.78614e+06        5       0.00701763       0.00954874      4.83m
#
# promising programs:
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
#
#    3     4.56      2.15344e+07        5       0.00614241        0.0174257      3.47m
#    4     6.21      5.68178e+10        5       0.00601986        0.0185287      3.49m
#
# promising programs:
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
#
#    5     5.27      6.62997e+09        5       0.00603053        0.0184327      3.14m
#    6     5.06      4.66021e+07        5       0.00589299        0.0196705      2.74m
#    7     5.06      2.94704e+07        5       0.00586713        0.0199032      2.63m
#    8     5.06      1.41199e+08        5       0.00580718        0.0204428      2.29m
#    9     5.08      1.22686e+08        5       0.00590449         0.019567      2.36m
#
# promising programs:
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
# sub(X0, pow(X0, 1.499))
#
#   10     5.05      3.27655e+06        5       0.00587944        0.0197924      2.31m
#   11     5.04      7.16555e+07        5        0.0059124        0.0194958      1.68m
#   12     5.07      2.82989e+06        5       0.00578906        0.0206059      1.52m
# sub(X0, pow(X0, 1.499))
# X0 - X0**1.499479910506444
# X0 - X0**C
# [[0.00024834]
#  [0.02403274]
#  [0.0255753 ]
#  [0.08257229]
#  [0.07186235]
#  [0.07588178]
#  [0.040884  ]
#  [0.07836312]
#  [0.0755036 ]
#  [0.06871245]]
# building blocks:
# pow(X0, 1.499)
# number of building blocks:  1
#
#
# X0 - X0**C
# True

# %% [markdown]
# ### parameter $k$:

# %% [markdown]
# ##### SR-T

# %%
# setting:
ode_name = 'LogisticODE_k' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 5 # help="sampling frequency", type=float, default=10
n_sample = 25 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=LogisticODE_k, ode_param=None, x_id=0, freq=5, n_sample=25, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# updated version 0
# [0.0, 0.2]
# [0.1, 1.5]
# (101, 25, 2)
# [0.09810328 0.11774279 0.12456784 0.15607209 0.17109676 0.2043011
#  0.23283602 0.25633497 0.29220132 0.32836966 0.36777386 0.40433271
#  0.44060607 0.4776772  0.5194332  0.5572221  0.59002222 0.62604491
#  0.6640016  0.69624126]
# Numerical differentiation: Done.
# Running with seed 100
#
# Forza Italia!!
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.81          658.176        5        0.0192951        0.0205919      2.92m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     6.96          26.6451       22        0.0153017        0.0170101      2.48m
#    2     3.38          21.5859        5        0.0188674        0.0244413      2.35m
#
# promising programs:
# log(1.005)
# cos(1.557)
# log(1.001)
# log(1.005)
# log(1.003)
# log(1.013)
# log(1.013)
# log(1.013)
# log(1.013)
# log(1.013)
# log(1.013)
# cos(1.557)
# log(1.013)
# log(1.013)
# cos(1.556)
#
#    3     2.48          69.2336        5        0.0187934        0.0251079      2.06m
#    4     2.29          6.81293        5        0.0198993        0.0210726      1.99m
#
# promising programs:
# log(1.005)
# log(1.005)
# log(1.005)
# log(1.005)
# log(1.005)
# log(1.013)
# log(1.005)
# log(1.003)
# log(1.013)
# log(1.005)
# log(1.005)
# log(1.013)
# log(1.005)
# log(1.013)
# log(1.003)
#
#    5     2.31          6.11779        7        0.0368632        0.0343285      1.87m
# X0**1.2216499679949326 - X0**1.3784137802300416
# X0**C - X0**C
# [[0.0167356  0.01083917 0.07558505 0.09972621 0.06756687 0.04771294
#   0.02325034 0.09842825 0.03981692 0.07333349]
#  [0.89625004 0.25473665 0.64149692 0.91715545 0.43182445 0.37343418
#   1.24492276 1.31511682 1.1040577  1.33973561]]
# building blocks:
# number of building blocks:  0
#
#
# 0
# False

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'LogisticODE_k' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 5 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=LogisticODE_k, ode_param=None, x_id=0, freq=5, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (51, 50, 2)
# (201, 50, 2)
# [0.09698462 0.10116265 0.1056464  0.1104429  0.11553425 0.12088903
#  0.12647486 0.13226901 0.13826501 0.14447383 0.15092006 0.15763442
#  0.16464467 0.17196751 0.17960337 0.18753535 0.19573233 0.20415565
#  0.21276755 0.2215397 ]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.81      5.34612e+11       16         0.179027         0.141695      7.18m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     9.06      3.11845e+14       22         0.135072         0.131486      5.30m
#    2     5.57      1.47107e+08        8        0.0310072        0.0182142      4.59m
#
# promising programs:
# sub(X0, pow(X0, add(1.005, X1)))
# add(X0, neg(pow(X0, add(1.005, X1))))
# add(X0, neg(pow(X0, add(1.005, X1))))
# add(X0, neg(pow(X0, add(1.005, X1))))
# add(X0, neg(pow(X0, add(1.005, X1))))
# add(X0, neg(pow(X0, add(1.005, X1))))
# mul(add(X0, X1), sub(X0, pow(X0, 1.559)))
# mul(add(X0, X1), sub(X0, pow(X0, 1.559)))
# mul(add(X0, X1), sub(X0, pow(X0, 1.559)))
# mul(add(X0, X1), sub(X0, pow(X0, 1.559)))
# mul(mul(sin(X1), sub(1.037, X0)), X0)
# sin(mul(neg(log(pow(X0, 1.375))), mul(sin(X1), pow(X0, 1.622))))
# sub(X0, pow(X0, 1.727))
# sub(X0, pow(X0, 1.803))
# sub(X0, pow(X0, 1.836))
#
#    3     5.22      4.95089e+09        8         0.026759        0.0564473      4.41m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    4     6.86      1.45556e+07        9        0.0214497        0.0951615      4.61m
#
# promising programs:
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
#
#    5     5.87      6.73542e+06        7        0.0235904        0.0849651      4.12m
#    6     6.19      1.71513e+06        8         0.021413         0.104561      3.63m
#    7     7.21      1.62991e+08        7        0.0207798          0.11026      3.44m
#    8     6.96      8.96818e+07        7        0.0194161         0.122534      3.09m
#    9     6.90      4.50362e+06        7        0.0202783         0.114774      2.88m
#
# promising programs:
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
# sub(X0, pow(X0, add(1.005, X1)))
#
#   10     6.93      2.07384e+06        7        0.0203827         0.113835      2.51m
#   11     6.90      5.96141e+06        7         0.019966         0.117585      2.27m
#   12     6.90      3.81316e+07        7        0.0208441         0.109681      2.00m
# sub(X0, pow(X0, add(1.005, X1)))
# X0 - X0**(X1 + 1.0049298055821259)
# X0 - X0**(X1 + C)
# [[6.75200029e-04 9.19768980e-02 3.15813578e-02 5.43890405e-02
#   5.36595163e-02 5.40683002e-02 6.27640760e-02 3.24847888e-02
#   4.27760994e-02 4.10115834e-02]
#  [1.01766290e+00 1.05996960e+00 1.32099050e+00 1.35520498e+00
#   8.99991506e-01 2.50791631e-01 4.42409733e-01 3.75874482e-01
#   2.11332272e-01 1.41663096e+00]]
# building blocks:
# pow(X0, add(1.005, X1))
# log(pow(X0, 1.375))
# number of building blocks:  2
#
#
# X0 - X0**(C + X1)
# True

# %% [markdown]
# ### parameter $a$:

# %% [markdown]
# ##### D-CODE

# %%
# setting:
ode_name = 'LogisticODE_a' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 5 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
    ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed)
# Out:
# Running with: ode_name=LogisticODE_a, ode_param=None, x_id=0, freq=5, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# updated version 0
# (51, 50, 2)
# (201, 50, 2)
# [0.0919756  0.0955157  0.0993445  0.10345531 0.10781458 0.11237573
#  0.1170937  0.121937   0.12689447 0.13197569 0.13720556 0.14261471
#  0.14822876 0.15405921 0.1600983  0.16631911 0.17268053 0.17913602
#  0.1856436  0.19217497]
# Running with seed 100
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79      5.12141e+11        5        0.0761233        0.0784943      5.91m
#    1     8.81      3.12309e+10        5        0.0688338           0.1441      4.63m
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/D-CODE/D_CODE/functions.py:131: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    2     5.61      2.87142e+06        5         0.059887         0.224621      3.73m
#
# promising programs:
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sin(sub(X0, pow(X0, 1.559))), X1)
# mul(sin(sub(X0, pow(X0, 1.559))), X1)
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
# sub(X0, pow(X0, 1.559))
#
#    3     4.07      1.41555e+06        8        0.0194488        0.0158848      3.12m
#    4     5.53      3.87634e+09        8        0.0102391        0.0098692      3.19m
#
# promising programs:
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
# mul(sub(X0, pow(X0, 1.559)), X1)
#
#    5     5.15      4.55135e+07        8        0.0101115        0.0110173      3.07m
#    6     5.63      1.88323e+09        8        0.0097382        0.0143769      2.95m
#    7     6.81      2.35642e+06        8       0.00908477        0.0147473      2.81m
#    8     6.92      1.09564e+08        8        0.0093429        0.0179345      2.43m
#    9     6.91      3.18542e+07        7       0.00902511        0.0216995      2.27m
#
# promising programs:
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.513)), X1)
# mul(sub(X0, pow(X0, 1.514)), X1)
# mul(sub(X0, pow(X0, 1.513)), X1)
# mul(sub(X0, pow(X0, 1.514)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.514)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
#
#   10     6.91      1.13462e+06        7       0.00900399        0.0153674      2.00m
#   11     6.89      1.06428e+09        7       0.00870133        0.0180913      1.68m
#   12     6.90           586839        7       0.00866016        0.0184619      1.47m
#   13     6.94       1.6187e+07        7       0.00863007        0.0187327      1.29m
#   14     6.93      7.30628e+06        7       0.00858627        0.0191269      1.04m
#   15     6.93      1.74618e+06        7       0.00860114        0.0189931     50.63s
#   16     6.92      5.24341e+07        7       0.00861999        0.0188234     38.02s
#   17     6.88           741419        7       0.00853045        0.0196292     25.59s
#   18     6.92      7.65683e+07        7       0.00848496        0.0200387     12.68s
#
# promising programs:
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
# mul(sub(X0, pow(X0, 1.494)), X1)
#
#   19     6.96      1.83775e+07        7       0.00861106        0.0189037      0.00s
# mul(sub(X0, pow(X0, 1.494)), X1)
# X1*(X0 - X0**1.4943716598362284)
# X1*(X0 - X0**C)
# [[0.03193137 0.07376076 0.07550067 0.07132788 0.08042213 0.0297725
#   0.04505678 0.01652037 0.05678729 0.09412476]
#  [0.63824878 0.54366844 0.7902477  1.42914639 0.6765984  0.50912072
#   0.50111896 1.08581493 1.39601262 1.2750229 ]]
# building blocks:
# pow(X0, 1.559)
# sin(sub(X0, pow(X0, 1.559)))
# pow(X0, 1.494)
# number of building blocks:  3
#
#
# X1*(X0 - X0**C)
# True
