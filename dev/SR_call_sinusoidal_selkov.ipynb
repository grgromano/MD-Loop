# %% [markdown]
# ##### import:

# %%
from Data.auxiliar_functions import SRT_simulation, D_CODE_simulation, set_param_freq

# %% [markdown]
# ## STD:

# %% [markdown]
# #### SR-T

# %% [markdown]
# ##### eq. 1:

# %%
# SR-T series 2:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 20 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [10, 15, 20, 25, 30]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 10
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# -0.00621336085509159
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 20
#      18 for T0, T in zip(T0s, Ts):
#      19     print(f'T0: {T0}, T: {T}')
# ---> 20     SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, T0=T0, T=T)
#
# File ~/Documents/polimi/thesis/repos/EKF-SINDy/Data/auxiliar_functions.py:26, in SRT_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, idx, T0, T)
#      23 def SRT_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, idx=0, T0=0, T=15):
#      24     print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
#      25     ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed))
# ---> 26     building_blocks_lambda, function_names = run_SRT(ode_name, param, x_id, freq, n_sample, noise_sigma, alg, seed=seed, n_seed=n_seed, idx=idx, T0=T0, T=T)
#      27     return building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/run_simulation.py:65, in run(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, idx, T0, T)
#      63     dxdt_hat = (yt[1:, :, :] - yt[:-1, :, :]) / (dg.solver.t[1:] - dg.solver.t[:-1])[:, None, None]
#      64 elif alg != 'gp':
# ---> 65     dxdt_hat = num_diff(yt, dg, alg, T0)
#      66 else:
#      67     dxdt_hat, xt_hat = num_diff_gp(yt, dg, ode)
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/interpolate.py:243, in num_diff(yt, dg, alg, T0)
#     242 def num_diff(yt, dg, alg, T0=0):
# --> 243     alpha = num_dff_tuning(yt, dg, alg, T0)
#     245     T, B, D = yt.shape
#     247     diff_mat = np.zeros_like(yt)
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/interpolate.py:206, in num_dff_tuning(yt, dg, alg, T0)
#     204 for alpha in grid:
#     205     if alg == 'tv':
# --> 206         res = TVRegDiff(y_single, itern=200, alph=alpha, u0=None, scale='small', dx=dg.solver.dt,
#     207                         plotflag=False, precondflag=False,
#     208                         diffkernel='sq', cgtol=1e-3, cgmaxit=100)
#     209     elif alg == 'spline':
#     210         res = dxdt(y_single, dg.solver.t, kind="spline", s=alpha)
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/tvregdiff/tvregdiff.py:257, in TVRegDiff(data, itern, alph, u0, scale, ep, dx, plotflag, diagflag, precondflag, diffkernel, cgtol, cgmaxit)
#     254 def linop(v): return (alph * L * v + AT(A(v)))
#     255 linop = splin.LinearOperator((n, n), linop)
# --> 257 s, info_i = sparse.linalg.cg(
#     258     linop, g, x0=None, tol=cgtol, maxiter=cgmaxit,
#     259     callback=None, M=P, atol='legacy')
#     261 if diagflag:
#     262     log_iteration(ii, s[0], u, g)
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/scipy/_lib/deprecation.py:213, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     211 extra_args = len(args) - len(all_args)
#     212 if extra_args <= 0:
# --> 213     return f(*args, **kwargs)
#     215 # extra_args > 0
#     216 args_msg = [
#     217     f"{name}={arg}"
#     218     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#     219 ]
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/scipy/sparse/linalg/_isolve/iterative.py:416, in cg(A, b, x0, tol, maxiter, M, callback, atol, rtol)
#     413     p = np.empty_like(r)
#     414     p[:] = z[:]
# --> 416 q = matvec(p)
#     417 alpha = rho_cur / dotprod(p, q)
#     418 x += alpha*p
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:205, in LinearOperator.matvec(self, x)
#     194     """Default matrix-vector multiplication handler.
#     195
#     196     If self is a linear operator of shape (M, N), then this method will
#    (...)
#     201     will define matrix-vector multiplication as well.
#     202     """
#     203     return self.matmat(x.reshape(-1, 1))
# --> 205 def matvec(self, x):
#     206     """Matrix-vector multiplication.
#     207
#     208     Performs the operation y=A*x where A is an MxN linear
#    (...)
#     226
#     227     """
#     229     x = np.asanyarray(x)
#
# KeyboardInterrupt:

# %%
# SR-T series 1:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.16579463 0.29437232 0.44572531 0.60154893 0.7830185  0.95481316
#  1.10091358 1.24540781 1.34260071 1.43429116 1.48949675 1.5024819
#  1.49072764 1.47088642 1.44072204 1.40225641 1.3766028  1.36359045
#  1.39643074 1.43525073]
# [0.05757505 0.06562537 0.05269261 0.06044826 0.0589719  0.05975886
#  0.06716626 0.07029733 0.07066073 0.08973529 0.08967005 0.10780676
#  0.10690799 0.11803747 0.10612201 0.12319043 0.12566297 0.13392626
#  0.12272682 0.1353295 ]
# [0.09378664 0.19518573 0.3046601  0.40234334 0.50047108 0.60772061
#  0.69208652 0.80576229 0.89638727 0.9955634  1.10188372 1.19841214
#  1.28949586 1.39509544 1.48949195 1.60040358 1.69807566 1.80426331
#  1.90856896 2.00679363]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.08213e+08        9          0.68443         0.689187      1.49m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     4.21          7125.15        9         0.683233         0.699964      1.13m
#    2     3.33          279.484        9         0.681915         0.711824     50.57s
#
# promising programs:
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X0, X1), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
# sub(neg(add(mul(X1, X0), neg(1.382))), X1)
#
#    3     3.71          3401.25       11         0.673526          0.67305     31.65s
#    4     3.83          44.2705        9         0.679741         0.731389     15.99s
#
# promising programs:
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
# sub(sub(1.341, X1), mul(X0, X1))
#
#    5     5.40           621.27       11          0.66692         0.684579      0.00s
#
# SR-T model:  C - X0*X1**C - X1
#
# building blocks:
# X0*X1
#
# number of building blocks:  1
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [2.33802261 2.0348915  1.6128815  1.15115209 0.74177546 0.42261129
#  0.25238798 0.15643293 0.10603803 0.0990902  0.13127869 0.18414319
#  0.27046203 0.35584796 0.44890667 0.54138797 0.62502453 0.69386358
#  0.73157724 0.74792835]
# [1.13896715 1.38820375 1.67572238 1.97511835 2.16755592 2.23974894
#  2.18496472 2.04449281 1.91463151 1.76798413 1.63177549 1.51829464
#  1.42891516 1.34665934 1.28430911 1.23670267 1.20612316 1.18906059
#  1.18410079 1.18490694]
# [4.99954129 5.09369595 5.19405884 5.29515368 5.4072678  5.4922978
#  5.60487242 5.70723978 5.8086815  5.90184159 5.99380695 6.10114347
#  6.19360903 6.29482246 6.40295529 6.4884213  6.60993699 6.69572555
#  6.79499535 6.90092972]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      7.20207e+08        9         0.661455         0.682334      1.36m
#    1     4.66          152.591        7         0.564876         0.528807      1.15m
#    2     3.76          15839.3        7         0.553993         0.626749     50.27s
#
# promising programs:
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(sin(mul(neg(X2), neg(3.202))))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(sin(mul(neg(X2), neg(3.202))))
# sin(sin(mul(neg(X2), neg(3.202))))
#
#    3     3.96          8896.46        7         0.557457         0.595575     33.11s
#    4     4.98          51.1629        9         0.538218         0.556222     16.48s
#
# promising programs:
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
# sin(mul(neg(X2), neg(3.202)))
#
#    5     6.78           1115.7        9         0.539437         0.545257      0.00s
#
# SR-T model:  -log(X1) + sin(C*X2)
#
# building blocks:
# 3.2023503130172637*X2
#
# number of building blocks:  1
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [1.12269151 1.18810342 1.28343703 1.38225861 1.51574014 1.64601814
#  1.77333524 1.87467808 1.97694439 2.02747663 2.04799616 2.02940627
#  1.9901383  1.91246427 1.81358765 1.71100929 1.6065239  1.50911496
#  1.4309839  1.37785597]
# [0.46574307 0.47327393 0.44840238 0.43412505 0.44052714 0.44618387
#  0.46000453 0.45962499 0.48659875 0.50328814 0.51459167 0.52981597
#  0.56422506 0.59431192 0.63334851 0.64690853 0.67462439 0.68931358
#  0.70236553 0.71412605]
# [ 9.99449271 10.10528362 10.19348343 10.30266043 10.39137821 10.50366737
#  10.59562246 10.69963227 10.7905558  10.89559093 11.00158817 11.09445541
#  11.20614819 11.29746083 11.40925645 11.50343127 11.59930157 11.69691479
#  11.79192485 11.90396518]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.25515e+09       20         0.476558         0.480978      1.37m
#    1     4.57          1156.84       13         0.441981         0.448385      1.16m
#    2     4.23          2765.54        4         0.322523         0.328333     53.07s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(sin(mul(3.139, X2)))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, 0.430)), sin(X1))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, 0.430)), sin(X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(0.831, X1)))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(0.868, X1)))
#
#    3     4.17          18945.6        4         0.322837         0.325514     35.80s
#    4     5.95          79.4247       24         0.215391         0.211866     18.94s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
#
#    5     6.68          1457.11       26         0.214873         0.220686      0.00s
#
# SR-T model:  C - X1 + sin(sin(-C*X2 + C*X2**C + X2**C + sin(X0 + X1)))
#
# building blocks:
# sin(3.1394689809108645*X2)
# X2**1.8842541798778392
# X0**0.430181755352103
# -sin(sin(3.000452122270786*X2))
#
# number of building blocks:  4
#
# T0: 15, T: 30
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [1.05003714 1.03470476 0.98929151 0.91754214 0.83628598 0.75717258
#  0.67914541 0.6227951  0.58772792 0.598829   0.62736004 0.68936944
#  0.78409436 0.88219951 1.0127612  1.15624035 1.28056454 1.40134532
#  1.4826458  1.55409203]
# [0.85908733 0.85328552 0.86734757 0.84898023 0.84604073 0.83399502
#  0.79080469 0.76843505 0.72936996 0.68737254 0.66012989 0.63824158
#  0.60197357 0.58438133 0.56532356 0.55488689 0.5353286  0.54554728
#  0.54757105 0.5464219 ]
# [15.00287308 15.1068157  15.19963056 15.3033967  15.39697888 15.49962264
#  15.60517032 15.70834916 15.80281614 15.89575497 16.00604353 16.09837214
#  16.20113972 16.29950343 16.39665276 16.50358181 16.61174063 16.70146354
#  16.80294257 16.90843635]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.60025e+09       20         0.393317         0.392826      1.38m
#    1     4.46          199.766       20         0.392098         0.403792      1.17m
#    2     3.87          984.464        4         0.284874         0.287433     51.85s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# neg(sin(neg(sub(sub(0.565, X1), mul(3.000, X2)))))
# neg(sin(mul(3.000, X2)))
# neg(sin(neg(sub(sub(0.411, X1), mul(3.000, X2)))))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
# neg(sin(mul(3.000, X2)))
#
#    3     4.48          31478.9        4         0.285092         0.285467     35.00s
#    4     6.70          80.1937       10         0.234639         0.241796     20.44s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
#
#    5     7.36          73.2719       26         0.147671         0.145947      0.00s
#
# SR-T model:  sin(C - X1) + sin(-C*X2 + X2**C + X2**(X1**C) + sin(X0 + X1))
#
# building blocks:
# 3.1394689809108645*X2
#
# number of building blocks:  1
#
# T0: 20, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.88457512 0.89486723 0.92698459 0.97435089 1.04517985 1.11159119
#  1.17640608 1.20326691 1.21821236 1.18086263 1.11812656 1.01421916
#  0.90194125 0.76800114 0.65139604 0.5324616  0.43348535 0.36977958
#  0.3402838  0.341858  ]
# [0.96454432 0.96001369 0.95626875 0.95357509 0.9583575  0.97380238
#  0.99892621 1.01902709 1.09073087 1.1068224  1.16732517 1.22115032
#  1.2394605  1.24430171 1.24189973 1.20785761 1.16928364 1.10743614
#  1.04857484 0.98762607]
# [19.99184413 20.09625037 20.20624251 20.30306412 20.41087385 20.50133061
#  20.59806643 20.69400262 20.79448285 20.89770076 21.0001976  21.10031188
#  21.19150634 21.29804259 21.40667976 21.49864392 21.59549412 21.7026128
#  21.80136751 21.91390814]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.94099e+09       20         0.377493         0.377918      1.58m
#    1     4.46          181.078       20         0.375935         0.391942      1.31m
#    2     3.77          1182.54        4         0.271647         0.273875     52.83s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(X1))))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 1.635))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), X1)), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, X1)), pow(X2, 0.640)), X1)), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X1))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X1))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(X1))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X1))), neg(0.681))
#
#    3     3.95          45789.6       16         0.265534         0.255112     35.57s
#    4     5.67          114.246       19         0.217926         0.217486     20.91s
#
# promising programs:
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
#
#    5     9.27          199.856       21         0.201592         0.208192      0.00s
#
# SR-T model:  sin(-C*X2 + 2*X2**C + sin(X1**C + sin(X0)))
#
# building blocks:
# 3.1394689809108645*X2
# X2**2.182075682230325
# X2**0.6395216888991612
# X2**X1
#
# number of building blocks:  4

# %%
# SR-T single shot:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 20 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# [0.07152106 0.12070248 0.17634033 0.22691126 0.30190801 0.37501415
#  0.43897139 0.52546744 0.59442873 0.69066673 0.78321854 0.86328174
#  0.94239007 1.02886893 1.11049909 1.17856747 1.24368127 1.29635821
#  1.36255108 1.39785042]
# [0.06296788 0.07194099 0.05862157 0.06465799 0.0601791  0.05680533
#  0.05909045 0.05639444 0.0505261  0.06328709 0.05714875 0.06974964
#  0.06409831 0.07142973 0.05674753 0.07205071 0.07362126 0.08160885
#  0.07044471 0.08302818]
# [-0.00621336  0.04518573  0.1046601   0.15234334  0.20047108  0.25772061
#   0.29208652  0.35576229  0.39638727  0.4455634   0.50188372  0.54841214
#   0.58949586  0.64509544  0.68949195  0.75040358  0.79807566  0.85426331
#   0.90856896  0.95679363]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          54592.3        4          0.73399         0.713504      6.91m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     4.05          62.9247        5         0.666025         0.665864      5.95m
#    2     3.32          8.92881        5         0.665614         0.669567      6.06m
#
# promising programs:
# sin(neg(neg(mul(3.120, X2))))
# sin(cos(div(X2, neg(0.342))))
# sin(cos(div(X2, neg(0.342))))
# sin(cos(div(X2, neg(0.342))))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# sin(cos(div(X2, neg(0.342))))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
# cos(div(X2, neg(0.342)))
#
#    3     4.17          8.00588        6         0.626871         0.618927      5.38m
#    4     4.42           8.6149        8         0.620324         0.609968      5.70m
#
# promising programs:
# sin(mul(3.120, X2))
# sin(mul(3.120, X2))
# sin(mul(3.120, X2))
# sin(mul(3.120, X2))
# sin(mul(3.120, X2))
# sin(sin(mul(3.120, X2)))
# sin(sin(mul(3.120, X2)))
# sin(sin(mul(3.120, X2)))
# sin(mul(3.120, X2))
# sin(mul(3.120, X2))
# sin(sin(mul(3.120, X2)))
# sin(sin(mul(3.120, X2)))
# sin(sin(mul(3.120, X2)))
# sin(mul(3.120, X2))
# sin(neg(neg(mul(3.120, X2))))
#
#    5     4.74          97.3147       11         0.573242         0.590993      5.66m
#    6     5.19          14.0876       12           0.5624         0.572285      4.88m
#    7     5.29          39.0411       13         0.558937         0.569605      5.01m
#    8     5.10          5.41589       10         0.485804         0.524689      4.58m
#    9     4.43          6.93708       10         0.485188         0.530228      3.65m
#
# promising programs:
# add(sub(cos(X1), sin(2.734)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), sin(X0)), sin(mul(3.120, X2)))
#
#   10     4.98          11.3005       10          0.43173         0.417989      3.09m
#   11     8.14          8.25734       11         0.243648         0.254273      3.05m
#   12    10.04           11.108       11         0.243663         0.254142      2.92m
#   13    10.04          7.77009       12         0.242665         0.255803      2.32m
#   14    10.39           14.921       14         0.147965         0.148119      2.05m
#
# promising programs:
# add(sub(cos(cos(X1)), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(X1)), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(X1)), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(X1)), mul(mul(X1, X0), X1)), sin(sin(mul(3.120, X2))))
# add(sub(cos(sub(sub(cos(X1), 0.617), sin(X0))), mul(X1, X0)), sin(mul(3.120, X2)))
# add(sub(cos(sub(sub(cos(X1), 0.617), sin(X0))), mul(X1, X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X1, X0)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
# add(sub(cos(X1), mul(X0, X1)), sin(mul(3.120, X2)))
#
#   15    11.34          27.9102       14          0.14766         0.150862      1.63m
#   16    11.79           509255       14         0.147379         0.153395      1.31m
#   17    11.05          14.8729       15         0.116122         0.116611     48.90s
#   18    11.23          89.2686       15         0.116572         0.112563     23.62s
#
# promising programs:
# add(sub(0.617, mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(0.603, mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(2.620)), mul(mul(X0, X1), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(cos(pow(X0, 0.162)))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(cos(0.901))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(neg(3.593))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(sin(sin(1.168))), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(0.284)), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(0.284)), mul(mul(X1, X0), X1)), sin(mul(3.120, X2)))
# add(sub(cos(cos(0.284)), mul(mul(X0, X1), X1)), sin(mul(3.120, X2)))
#
#   19    12.16          11.6285       17        0.0896246        0.0923086      0.00s
#
# SR-T model:  -X0*X1**C + sin(C*X2) + cos(cos(cos(X0**C)))
#
# building blocks:
# 3.1199960302564387*X2
# sin(3.1199960302564387*X2)
# -2.921430597371855*X2
# cos(2.921430597371855*X2)
# sin(cos(2.921430597371855*X2))
# sin(sin(3.1199960302564387*X2))
# cos(cos(X1))
# X0*X1**2
# X0*X1
# 0.64703598180702371
# cos(cos(X0**0.16201169531814116))
# cos(cos(cos(X0**0.16201169531814116)))
# cos(X0**0.16201169531814116)
# 0.8132772373642043
# -0.89998925279444209
# 0.62161838681008237
# 0.7956232172948609
# 0.57358221848772679
#
# number of building blocks:  18
# ([<function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>],
#  [<function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=0)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=1)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=2)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=3)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=4)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=5)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=6)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=7)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=8)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=9)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=10)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=11)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=12)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=13)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=14)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=15)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=16)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=17)>])

# %% [markdown]
# #### D-CODE

# %% [markdown]
# ##### eq. 1:

# %%
#D-CODE series 4:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.60627e+24        9          145.233          146.278      2.92m
#    1     6.86      9.41891e+14        7          139.715          139.687      2.18m
#    2     7.60      1.43024e+16        9          113.547          113.516      1.71m
#
# promising programs:
# sub(sin(add(X1, log(neg(mul(0.162, X1))))), neg(mul(mul(X1, X1), neg(X0))))
# add(mul(neg(X0), mul(X1, X1)), sin(2.236))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), pow(X1, 2.012)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sub(sin(add(X1, X0)), X1)))), neg(mul(pow(X1, 1.996), X0)))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(0.718))
# sub(sin(add(log(3.498), mul(X1, X1))), mul(X1, X0))
# sin(mul(3.187, X2))
#
#    3     6.62      5.07817e+14       16          111.113          110.921      1.01m
#    4     7.90      1.83924e+10       14          49.5635          49.7743     34.33s
#
# promising programs:
# add(sin(add(X0, X1)), sub(sin(mul(3.187, X2)), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(mul(3.187, X2)), add(sin(add(pow(X1, 1.168), X1)), neg(mul(X1, X0))))
# add(sin(add(X0, X1)), sub(sin(sin(sin(mul(neg(X2), neg(3.202))))), X1))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.659, X1), mul(X1, X0)))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.680, X1), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# sub(sub(sin(sin(mul(neg(X2), neg(3.202)))), mul(X1, X0)), neg(0.715))
# add(mul(X0, mul(sub(sin(mul(neg(X2), neg(3.202))), X1), X1)), sin(0.718))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(neg(X2), neg(3.202))), sub(0.793, X1))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(mul(neg(X2), neg(3.202))))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sin(add(X1, add(X1, X0))))
#
#    5     9.11      8.70771e+15       11          41.0211          41.0373      0.00s
#
# D-CODE model:  -X1 + sin(C*X2) + sin(X0 + X1)
#
# building blocks:
# X1**1.954775679844595
# sin(X0 + X1)
# sin(3.186700227887775*X2)
# X1**1.1684265190435612
# sin(X1 + X1**1.1684265190435612)
# X1**0.04531823176110219
# sin(X0 + 2*X1)
#
# number of building blocks:  7
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [2.33761972 2.20663286 2.03468758 1.83731175 1.62093645 1.39054147
#  1.15584966 0.93121655 0.73044156 0.56163325 0.42605283 0.32065966
#  0.24128169 0.18403423 0.14513293 0.12065073 0.10707052 0.1021016
#  0.10485464 0.11522456]
# [1.14061167 1.25849889 1.38557153 1.52567747 1.67606748 1.82792663
#  1.96916034 2.08786165 2.1750891  2.22637567 2.2420097  2.22630814
#  2.18612231 2.12897942 2.06147464 1.98846692 1.91319974 1.83795358
#  1.76462708 1.69486665]
# [5.00040622 5.06312791 5.10170825 5.1443415  5.19646318 5.25143129
#  5.30302841 5.35100742 5.39879155 5.44872515 5.50018511 5.55128405
#  5.60123342 5.65076967 5.70082299 5.75136315 5.80162881 5.8511668
#  5.90037582 5.95004226]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.42304e+23       14          368.331          369.765      2.58m
#    1     6.01      3.69567e+10       14          324.441          330.453      2.13m
#    2     6.28      6.51605e+15       14          325.147          324.097      1.49m
#
# promising programs:
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1)))), X0)
# mul(mul(mul(mul(X1, X0), 2.688), add(pow(X0, 0.597), neg(X1))), X0)
# sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), X0), add(mul(pow(X0, 1.202), sin(mul(sub(X0, X1), sin(X1)))), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# sub(sub(mul(pow(X1, 3.024), sin(mul(sin(neg(X0)), sin(pow(X0, 1.720))))), neg(pow(X0, 2.850))), pow(X0, 1.207))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1))))
# mul(mul(mul(X1, X0), mul(mul(X1, X0), X0)), add(pow(X0, 0.597), neg(X1)))
#
#    3     7.90      1.27573e+14       31          291.526          294.187      1.16m
#    4     9.39      2.62864e+16       33          283.332          287.343     34.13s
#
# promising programs:
# mul(pow(X0, 1.653), add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(mul(sin(pow(X2, 2.152)), add(2.283, X1)), log(sin(X1)))), X0)
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(mul(X1, X0))), pow(X1, 1.671)), sub(sin(sin(sub(X0, X1))), log(sin(X1))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(sin(X1))))
# sub(mul(mul(mul(pow(X1, mul(X1, X0)), X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(sub(X0, X1), mul(X0, X1)), X1))), pow(X0, 0.868)), X0)
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(mul(mul(X0, X0), sub(X0, X1)), X1), mul(X1, X0))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(sub(X0, X1), pow(X0, 1.420)), log(sin(X1))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(X0, mul(sub(sub(pow(X0, 1.684), X1), X1), mul(X1, X0)))
# mul(mul(mul(X1, X0), mul(sub(pow(X0, 1.200), mul(sin(mul(sub(X0, X1), mul(X0, X1))), mul(X0, X1))), X0)), add(pow(X0, 0.597), neg(X1)))
# sub(add(mul(mul(sub(X0, X1), pow(X0, 1.720)), mul(X1, X0)), neg(log(pow(X1, 1.934)))), pow(X0, 1.207))
# mul(mul(mul(X1, X0), pow(X0, X1)), add(mul(sin(sub(X0, X1)), pow(X0, 1.420)), neg(X1)))
#
#    5    12.02      1.45472e+16       35          251.079          245.263      0.00s
#
# D-CODE model:  X0**C*(X0**C*X1**C*(X0**C - X1)*log(X1) - log(sin(X1)) + sin(log(X0**C)))
#
# building blocks:
# X1**2.498600833205385
# log(sin(X1))
# X0**0.5974440705033232
# X0**1.2023549501406876
# -sin(X0)
# sin(log(X0**1.4204037111558676))
# sin(X0 - X1)
# X1**(X0*X1)
# sin(3.000452122270786*X2)
# -sin(sin(3.000452122270786*X2))
# X0**0.868369908862835
# X0**1.4204037111558676
# log(X1**1.933823638326436)
# X0**X1
#
# number of building blocks:  14
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.12618013 1.1563143  1.1864209  1.22415442 1.27157488 1.32677478
#  1.38657322 1.44853656 1.51160497 1.57562137 1.64045604 1.70531968
#  1.76860439 1.8282921  1.88261827 1.93047884 1.97129014 2.00453653
#  2.02953575 2.04565985]
# [0.46316475 0.4611573  0.45653788 0.45191938 0.44785587 0.44418405
#  0.4411593  0.4395103  0.43969522 0.44136021 0.44364867 0.44604587
#  0.44888846 0.45304432 0.45911341 0.46692721 0.47575824 0.484948
#  0.49434287 0.50422376]
# [ 9.99709453 10.08027149 10.10830927 10.1417367  10.19429914 10.25374301
#  10.30723699 10.35340051 10.39851865 10.4473497  10.49913833 10.5505608
#  10.60010389 10.64896441 10.69880135 10.74980203 10.80099728 10.85167412
#  10.90191888 10.95199278]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      5.44442e+24       12          287.305           288.61      3.12m
#    1     6.26      5.45513e+10       12          287.485          286.993      2.18m
#    2     7.03      1.31059e+12       24          283.089          283.104      1.95m
#
# promising programs:
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(log(X1)), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(sub(log(2.698), neg(X1)))))), neg(0.681)))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sin(2.516)), 2.288)))))
# sub(neg(sin(mul(3.000, X2))), add(log(X1), sin(X1)))
# neg(add(pow(X1, 0.979), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), sub(1.891, X1))))
# sub(sin(mul(3.139, X2)), pow(X1, 2.321))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(X1, neg(X0)), sub(sin(X2), sub(1.717, X1))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(pow(X1, 2.415), sin(neg(X1))), 0.640)), pow(X1, 0.650))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(neg(sin(sub(log(add(X1, X1)), neg(log(X1)))))))
# sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(0.681)), log(X1))
# sub(sin(neg(sin(mul(3.000, X2)))), sub(log(add(X1, X1)), neg(log(X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(sin(sin(neg(X1))), log(sin(X1))), pow(X0, 0.232))))
# neg(sub(log(add(X1, X1)), neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))))
#
#    3     9.67      8.50939e+14       29          230.321          230.544      1.32m
#    4    13.17      8.34436e+14       45          220.004          219.469     52.25s
#
# promising programs:
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(X1)))))))))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sub(sin(X1), X0)), 2.288)))))), sin(sub(log(add(X1, X1)), neg(log(mul(sin(X0), add(0.482, X1)))))))
# sub(sub(sub(neg(X1), log(X1)), log(add(sin(sub(X0, X1)), pow(X1, X0)))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X1)), sin(pow(X1, 2.288)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, sin(neg(X1)))), pow(X2, 0.640)), sin(1.934)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(log(X1), 0.640)), pow(X1, 0.650))))), neg(sin(sin(neg(X2)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, log(mul(2.703, X1))))))), sub(neg(0.518), log(X1)))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(0.180))), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# sub(sub(sin(mul(3.139, X2)), sin(X0)), log(X1))
# sub(sin(neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(mul(3.000, X2))))))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(neg(pow(mul(3.139, X2), 2.920)))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X1, 1.506))))))))))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(log(neg(pow(mul(3.139, X2), 2.920))))))))), add(log(X1), sin(X1)))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(1.934)))))), neg(sin(sin(add(neg(log(X1)), add(neg(pow(X1, 1.185)), sub(X0, X0)))))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, pow(X2, 0.640))))), neg(0.681)), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(neg(sin(mul(3.000, X2))))))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(2.206))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
#
#    5    16.75      3.53098e+15       48          199.695           201.83      0.00s
#
# D-CODE model:  -sin(log(X0) - log(C + X1) + sin(X2) - sin(sin(-C*X2 + 2*X2**C + sin(X1**(-X1))) - sin(sin(X1)))) - sin(sin(C*X2))
#
# building blocks:
# X2**0.6395216888991612
# X2**0.9293847888625885
# log(X1*X2)
# sin(3.000452122270786*X2)
# sin(X1 + 0.9923542927995774)
# X2**1.8842541798778392
# X1**0.9785288320096076
# -sin(sin(3.000452122270786*X2))
# X1**0.6497749208699527
# log(2*X1)
# -sin(sin(X1))
# log(sin(X1))
# X0**0.231803684746055
# log(X1 + 0.7159165005953514)
# sin(X1**(-X1))
# X2**X1
# log(X1**1.5185074432758638)
# X2**(-sin(X1))
# log(2.702752972305997*X1)
# X1**1.1850199841118407
# sin(log(X0))
#
# number of building blocks:  21
#
# T0: 15, T: 30
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.05800508 1.05470963 1.03674209 1.01133535 0.98205567 0.94977985
#  0.91437937 0.87592543 0.83512402 0.79329375 0.75216452 0.71354103
#  0.67890345 0.64919751 0.62499372 0.60683831 0.59540754 0.59131565
#  0.594851   0.60599851]
# [0.86098146 0.86178728 0.86131893 0.8621175  0.86285643 0.86136984
#  0.85685661 0.8500116  0.84182186 0.83259188 0.82198915 0.80966988
#  0.79565199 0.78017679 0.76345312 0.74568061 0.72727446 0.70892551
#  0.69133509 0.67485381]
# [14.99457149 15.09300328 15.11024126 15.13616715 15.19021995 15.25385449
#  15.3087389  15.35375598 15.39830643 15.44854936 15.50240521 15.55483018
#  15.60421351 15.65277039 15.70253542 15.75289771 15.80214403 15.85013467
#  15.89853687 15.94870518]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34        1.568e+25       20          51.9549          52.2362      2.42m
#    1     7.23      3.44315e+15       20          51.9517          52.2651      2.04m
#    2     7.28      8.66874e+12       25          34.4682          34.3907      2.04m
#
# promising programs:
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X1, X1)))))
# sin(sub(log(mul(X1, sin(3.461))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 3.392))))
# sin(sub(X1, sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(neg(X1), sin(2.236))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), 0.717)))
# sin(mul(3.139, X2))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), sin(add(X0, X1))), sin(pow(2.488, 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sub(0.793, mul(log(neg(pow(X0, 3.875))), log(neg(sin(1.999)))))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(neg(pow(X1, 2.644)), 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(X0))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, neg(X1))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2)))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2)))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(sin(mul(neg(log(X1)), sin(log(X0)))), sin(2.236))))), neg(0.681))
#
#    3     8.19      3.89536e+15       18          16.6763          16.6624      1.20m
#    4    11.42      2.23391e+10       24          9.34874           9.3207     43.77s
#
# promising programs:
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X2)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(neg(0.681), 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(add(X0, X1))))), neg(sub(0.717, X1)))
# sub(sin(sub(pow(0.658, 0.657), sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sub(0.793, pow(X1, 2.014)))))), neg(sub(sin(2.325), X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))), neg(sin(sin(sub(0.711, X1)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(X0, X2))))))), neg(sub(0.637, X1)))
# neg(sin(neg(sub(sin(sub(0.717, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), 0.919))))))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(neg(2.862))))))))), neg(sub(0.868, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sin(2.325), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.000, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sub(0.868, X1), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sub(X1, X2), mul(3.108, X2))))))), neg(sub(0.637, X1)))
#
#    5    15.97      5.40578e+10       24          9.33153          9.47561      0.00s
#
# D-CODE model:  C - X1 + sin(sin(-C*X2 + 2*X2**C + sin(X0 + X1)))
#
# building blocks:
# sin(2*X1)
# X2**0.6395216888991612
# X2**1.8842541798778392
# -sin(X1 - 0.78663562254828674)
# sin(3.1394689809108645*X2)
# sin(X0 + X1)
# X1**(-X0)
# sin(X1**(-X0))
# sin(log(X0))
# X2**X2
# 12.35452176388197*X2**2.288047709755393
# -sin(X1**2.0137689262307594 - 0.7928934028760071)
# -sin(sin(X1 - 0.7108489859819501))
# -sin(X1 - 0.7174908107608908)
#
# number of building blocks:  14
#
# T0: 20, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.8847791  0.88934426 0.89307867 0.90373045 0.92330836 0.9497428
#  0.97991463 1.01181917 1.04479584 1.07842559 1.11151931 1.14211658
#  1.16826829 1.1886972  1.20273356 1.20975153 1.20880233 1.19883965
#  1.17927357 1.15029467]
# [0.96307461 0.96140043 0.95555174 0.95192465 0.95154928 0.95264399
#  0.95379907 0.95544899 0.95912152 0.96581617 0.97523251 0.986389
#  0.99876102 1.01274785 1.02915277 1.04836445 1.07004414 1.09341339
#  1.11762889 1.14186241]
# [19.99450487 20.10729364 20.11116891 20.12809312 20.18434507 20.25405222
#  20.31134607 20.35422583 20.39584492 20.4453447  20.50021923 20.55319836
#  20.6015589  20.64848922 20.69769519 20.74915377 20.80028674 20.84968066
#  20.89847202 20.94841881]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      5.33693e+24       20          237.821          242.272      2.64m
#    1     5.46      1.23101e+10       21          216.598          212.697      2.57m
#    2     6.93      1.35375e+12       21          169.257          166.802      1.66m
#
# promising programs:
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(pow(X0, 3.438), log(X0)))))
# sub(sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), sin(pow(X0, 2.770)))
# sub(add(add(sin(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(0.681))), pow(X0, 3.262)), neg(log(sin(X1)))), pow(X0, 1.207))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(pow(X0, 3.438), log(X0))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(pow(X0, 1.219), sin(pow(X0, 2.951)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, add(sin(log(X0)), neg(neg(0.757))))), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), sin(mul(X1, log(X2)))), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(pow(X0, 2.859), pow(X0, 1.207))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(pow(X0, 2.120), sub(X0, X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(X0, X1), pow(X0, 2.235))))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(mul(sin(sin(log(X1))), neg(mul(pow(X1, 1.612), pow(X0, 2.972)))), pow(X0, 1.720)))), neg(0.681))
# mul(sin(sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(neg(log(pow(X1, 2.305))))))), pow(X0, 1.420))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(neg(log(pow(X1, 2.305))))))
#
#    3     8.93      2.79228e+15       27          115.972          116.261      1.22m
#    4    11.04      6.50204e+09       27          114.406          114.908     44.44s
#
# promising programs:
# sub(mul(sub(pow(X0, 2.190), mul(0.443, X0)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(pow(X0, mul(X0, X0)), X1), sin(add(mul(3.000, X2), pow(X0, 2.431))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), neg(neg(0.681)))))), neg(sub(pow(X0, 2.859), pow(X0, 1.207))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X0, 1.599)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(mul(mul(X0, X0), sub(X0, sin(pow(X1, 2.288)))), log(X0)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), X0), pow(X2, 0.640)), sin(pow(X1, 2.288))))), neg(mul(sin(mul(sin(X0), log(X0))), pow(X0, 3.895))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(sin(sin(sin(neg(mul(X2, X1))))), 0.640)), sin(pow(X1, 2.288)))))
# add(sub(mul(X0, X0), X1), neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(mul(3.100, X1))))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))), 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 2.143)), sin(pow(X1, 2.288)))))
# sub(sin(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, mul(sin(X0), log(X0)))))), neg(0.681))), neg(mul(pow(X0, 3.438), log(X0))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
#
#    5    15.62       5.8029e+09       29          107.156           109.65      0.00s
#
# D-CODE model:  (X0 - X1)*(-C*X0 + X0**C) + sin(-C*X2 + 2*X2**C + sin(X1**C))
#
# building blocks:
# X0**1.5986934150251917
# sin(X1**2.288047709755393)
# X0**(X0**1.5986934150251917)
# X2**0.6395216888991612
# log(sin(X1))
# X0**1.2073528903982544
# sin(3.000452122270786*X2)
# -sin(sin(3.000452122270786*X2))
# sin(log(X0))
# sin(X1*log(X2))
# log(X1**2.305327328044378)
# -sin(log(X1**2.305327328044378))
# X0**(X0**2)
# sin(log(X0)*sin(X0))
#
# number of building blocks:  14

# %%
#D-CODE series 3 - STANDARD VERSION:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0]
Ts = [15]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.60627e+24        9          145.233          146.278      5.31m
#    1     6.86      9.41891e+14        7          139.715          139.687      4.46m
#    2     7.60      1.43024e+16        9          113.547          113.516      4.09m
#
# promising programs:
# sub(sin(add(X1, log(neg(mul(0.162, X1))))), neg(mul(mul(X1, X1), neg(X0))))
# add(mul(neg(X0), mul(X1, X1)), sin(2.236))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), pow(X1, 2.012)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sub(sin(add(X1, X0)), X1)))), neg(mul(pow(X1, 1.996), X0)))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(0.718))
# sub(sin(add(log(3.498), mul(X1, X1))), mul(X1, X0))
# sin(mul(3.187, X2))
#
#    3     6.62      5.07817e+14       16          111.113          110.921      3.27m
#    4     7.90      1.83924e+10       14          49.5635          49.7743      2.91m
#
# promising programs:
# add(sin(add(X0, X1)), sub(sin(mul(3.187, X2)), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(mul(3.187, X2)), add(sin(add(pow(X1, 1.168), X1)), neg(mul(X1, X0))))
# add(sin(add(X0, X1)), sub(sin(sin(sin(mul(neg(X2), neg(3.202))))), X1))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.659, X1), mul(X1, X0)))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.680, X1), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# sub(sub(sin(sin(mul(neg(X2), neg(3.202)))), mul(X1, X0)), neg(0.715))
# add(mul(X0, mul(sub(sin(mul(neg(X2), neg(3.202))), X1), X1)), sin(0.718))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(neg(X2), neg(3.202))), sub(0.793, X1))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(mul(neg(X2), neg(3.202))))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sin(add(X1, add(X1, X0))))
#
#    5     9.11      8.70771e+15       11          41.0211          41.0373      2.46m
#    6    10.00      4.69181e+13       15          16.0824          16.1976      2.09m
#    7    13.35      1.45465e+15       14          15.8489          15.9099      1.82m
#    8    16.30      7.06883e+15       14           15.847           15.927      1.25m
#    9    17.91      7.11502e+15       13           13.946          14.3429     39.01s
#
# promising programs:
# add(sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715)), sin(mul(3.170, X2)))
# add(sin(log(mul(neg(3.833), sub(mul(mul(X0, X1), X1), 3.498)))), sub(sin(mul(3.187, X2)), mul(mul(X0, X1), X1)))
# sub(add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0))), neg(sub(X0, X0)))
# add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0)))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# sub(add(sin(log(log(neg(sin(add(sub(X1, pow(X2, 2.198)), sin(sin(mul(neg(X2), neg(3.202)))))))))), neg(mul(pow(X1, 1.996), X0))), neg(sin(sin(mul(3.187, X2)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# sub(sin(log(2.105)), neg(add(sin(mul(3.187, X2)), neg(mul(pow(X1, 1.996), X0)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sin(mul(3.187, X2)), sub(sin(log(2.105)), mul(mul(X0, X1), X1)))
#
#   10    20.02      2.73212e+10       14          6.72017          6.72766      0.00s
#
# D-CODE model:  C - X0*X1**C + sin(C*X2)
#
#
# [1000. 1000. 1000.]
# True
#
# [1000. 1000. 1000.]
# True
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [1000. 1000. 1000.]
# True
#
# [1000. 1000. 1000.]
# True
#
# [1000. 1000. 1000.]
# True
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [6.02442986e-05 1.97519189e-03 0.00000000e+00]
# False
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [6.02442986e-05 1.97519189e-03 0.00000000e+00]
# False
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [1000. 1000. 1000.]
# True
#
# [1000. 1000. 1000.]
# True
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.24790921 0.24790921 0.24790921]
# True
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.00354666 0.02690489 0.        ]
# False
#
# [0.01154491 0.07214943 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.00354666 0.02690489 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.07307465 0.04825302 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.80346704 0.86916037 0.        ]
# False
#
# [0.80346704 0.86916037 0.        ]
# False
#
# [0.80346704 0.86916037 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.80346704 0.86916037 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.80346704 0.86916037 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.24790921 0.24790921 0.24790921]
# True
#
# [0.24790921 0.24790921 0.24790921]
# True
#
# [0.24790921 0.24790921 0.24790921]
# True
#
# [0.24790921 0.24790921 0.24790921]
# True
#
# [0.08104935 0.09344254 0.        ]
# False
#
# [0.08104935 0.09344254 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03883236 0.01426472 0.        ]
# False
#
# [0.03883236 0.01426472 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.99492481 0.99798563 0.99408817]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.99492481 0.99798563 0.99408817]
# False
#
# [0.99492481 0.99798563 0.99408817]
# False
#
# [0.0385899  0.01417561 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [7.95889083e-05 2.36107658e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03922443 0.0144088  0.        ]
# False
#
# [0.03902292 0.0143379  0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [6.52451103e-05 2.07875262e-03 0.00000000e+00]
# False
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.03903283 0.01433839 0.        ]
# False
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
#
# [0.67749455 0.67749455 0.67749455]
# True
# building blocks:
# X1**1.954775679844595
# sin(X0 + X1)
# sin(3.186700227887775*X2)
# X1**1.1684265190435612
# sin(X1 + X1**1.1684265190435612)
# X1**0.04531823176110219
# sin(X0 + 2*X1)
# -sin(X1 - 1.6795866326184206)
#
# number of building blocks:  8

# %%
#D-CODE series 3 - STANDARD VERSION:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.60627e+24        9          145.233          146.278      6.34m
#    1     6.86      9.41891e+14        7          139.715          139.687      5.17m
#    2     7.60      1.43024e+16        9          113.547          113.516      5.97m
#
# promising programs:
# sub(sin(add(X1, log(neg(mul(0.162, X1))))), neg(mul(mul(X1, X1), neg(X0))))
# add(mul(neg(X0), mul(X1, X1)), sin(2.236))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), pow(X1, 2.012)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sub(sin(add(X1, X0)), X1)))), neg(mul(pow(X1, 1.996), X0)))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(0.718))
# sub(sin(add(log(3.498), mul(X1, X1))), mul(X1, X0))
# sin(mul(3.187, X2))
#
#    3     6.62      5.07817e+14       16          111.113          110.921      3.53m
#    4     7.90      1.83924e+10       14          49.5635          49.7743      3.11m
#
# promising programs:
# add(sin(add(X0, X1)), sub(sin(mul(3.187, X2)), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(mul(3.187, X2)), add(sin(add(pow(X1, 1.168), X1)), neg(mul(X1, X0))))
# add(sin(add(X0, X1)), sub(sin(sin(sin(mul(neg(X2), neg(3.202))))), X1))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.659, X1), mul(X1, X0)))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.680, X1), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# sub(sub(sin(sin(mul(neg(X2), neg(3.202)))), mul(X1, X0)), neg(0.715))
# add(mul(X0, mul(sub(sin(mul(neg(X2), neg(3.202))), X1), X1)), sin(0.718))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(neg(X2), neg(3.202))), sub(0.793, X1))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(mul(neg(X2), neg(3.202))))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sin(add(X1, add(X1, X0))))
#
#    5     9.11      8.70771e+15       11          41.0211          41.0373      2.64m
#    6    10.00      4.69181e+13       15          16.0824          16.1976      2.21m
#    7    13.35      1.45465e+15       14          15.8489          15.9099      1.82m
#    8    16.30      7.06883e+15       14           15.847           15.927      1.39m
#    9    17.91      7.11502e+15       13           13.946          14.3429     41.59s
#
# promising programs:
# add(sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715)), sin(mul(3.170, X2)))
# add(sin(log(mul(neg(3.833), sub(mul(mul(X0, X1), X1), 3.498)))), sub(sin(mul(3.187, X2)), mul(mul(X0, X1), X1)))
# sub(add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0))), neg(sub(X0, X0)))
# add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0)))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# sub(add(sin(log(log(neg(sin(add(sub(X1, pow(X2, 2.198)), sin(sin(mul(neg(X2), neg(3.202)))))))))), neg(mul(pow(X1, 1.996), X0))), neg(sin(sin(mul(3.187, X2)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# sub(sin(log(2.105)), neg(add(sin(mul(3.187, X2)), neg(mul(pow(X1, 1.996), X0)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sin(mul(3.187, X2)), sub(sin(log(2.105)), mul(mul(X0, X1), X1)))
#
#   10    20.02      2.73212e+10       14          6.72017          6.72766      0.00s
#
# D-CODE model:  C - X0*X1**C + sin(C*X2)
#
# building blocks:
# log(-0.16215838256749215*X1)
# X1**1.954775679844595
# sin(X0 + X1)
# 0.24790920821746188
# sin(3.186700227887775*X2)
# X1**1.1684265190435612
# sin(X1 + X1**1.1684265190435612)
# X1**0.04531823176110219
# sin(X0 + 2*X1)
# -sin(X1 - 1.6795866326184206)
# 0.67749455440052803
#
# number of building blocks:  11
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [2.33761972 2.20663286 2.03468758 1.83731175 1.62093645 1.39054147
#  1.15584966 0.93121655 0.73044156 0.56163325 0.42605283 0.32065966
#  0.24128169 0.18403423 0.14513293 0.12065073 0.10707052 0.1021016
#  0.10485464 0.11522456]
# [1.14061167 1.25849889 1.38557153 1.52567747 1.67606748 1.82792663
#  1.96916034 2.08786165 2.1750891  2.22637567 2.2420097  2.22630814
#  2.18612231 2.12897942 2.06147464 1.98846692 1.91319974 1.83795358
#  1.76462708 1.69486665]
# [5.00040622 5.06312791 5.10170825 5.1443415  5.19646318 5.25143129
#  5.30302841 5.35100742 5.39879155 5.44872515 5.50018511 5.55128405
#  5.60123342 5.65076967 5.70082299 5.75136315 5.80162881 5.8511668
#  5.90037582 5.95004226]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.42304e+23       14          368.331          369.765      5.04m
#    1     6.01      3.69567e+10       14          324.441          330.453      4.76m
#    2     6.28      6.51605e+15       14          325.147          324.097      3.81m
#
# promising programs:
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1)))), X0)
# mul(mul(mul(mul(X1, X0), 2.688), add(pow(X0, 0.597), neg(X1))), X0)
# sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), X0), add(mul(pow(X0, 1.202), sin(mul(sub(X0, X1), sin(X1)))), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# sub(sub(mul(pow(X1, 3.024), sin(mul(sin(neg(X0)), sin(pow(X0, 1.720))))), neg(pow(X0, 2.850))), pow(X0, 1.207))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1))))
# mul(mul(mul(X1, X0), mul(mul(X1, X0), X0)), add(pow(X0, 0.597), neg(X1)))
#
#    3     7.90      1.27573e+14       31          291.526          294.187      3.32m
#    4     9.39      2.62864e+16       33          283.332          287.343      2.95m
#
# promising programs:
# mul(pow(X0, 1.653), add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(mul(sin(pow(X2, 2.152)), add(2.283, X1)), log(sin(X1)))), X0)
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(mul(X1, X0))), pow(X1, 1.671)), sub(sin(sin(sub(X0, X1))), log(sin(X1))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(sin(X1))))
# sub(mul(mul(mul(pow(X1, mul(X1, X0)), X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(sub(X0, X1), mul(X0, X1)), X1))), pow(X0, 0.868)), X0)
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(mul(mul(X0, X0), sub(X0, X1)), X1), mul(X1, X0))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(sub(X0, X1), pow(X0, 1.420)), log(sin(X1))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(X0, mul(sub(sub(pow(X0, 1.684), X1), X1), mul(X1, X0)))
# mul(mul(mul(X1, X0), mul(sub(pow(X0, 1.200), mul(sin(mul(sub(X0, X1), mul(X0, X1))), mul(X0, X1))), X0)), add(pow(X0, 0.597), neg(X1)))
# sub(add(mul(mul(sub(X0, X1), pow(X0, 1.720)), mul(X1, X0)), neg(log(pow(X1, 1.934)))), pow(X0, 1.207))
# mul(mul(mul(X1, X0), pow(X0, X1)), add(mul(sin(sub(X0, X1)), pow(X0, 1.420)), neg(X1)))
#
#    5    12.02      1.45472e+16       35          251.079          245.263      2.73m
#    6    15.82      3.56412e+14       36          248.452          252.062      2.69m
#    7    19.77      6.51555e+15       45          195.777          190.578      2.07m
#    8    24.21      1.60529e+12       35          200.077          203.821      1.58m
#    9    29.89      7.64663e+14       35          198.186          220.841     54.49s
#
# promising programs:
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X1, X1))), sin(sub(sub(mul(pow(X0, X0), sub(1.881, mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1)))), X0))), X1), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# add(mul(pow(X0, X1), sub(X0, X1)), add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(mul(X1, X0))), pow(X1, 1.671)), sub(mul(sin(neg(X0)), sin(mul(3.000, X2))), log(sin(X1)))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(add(pow(X0, 0.597), mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499))))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(mul(X1, pow(X0, 0.597)), mul(X0, X0)), add(pow(X1, 0.670), log(X0))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(pow(X0, 0.597))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# mul(mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(pow(X2, 1.282)), log(sin(X1)))), X0), X0)
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(add(neg(neg(X1)), neg(X1)))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(mul(X0, X0), sub(X0, X1)), neg(add(mul(mul(mul(mul(pow(X0, 2.850), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(mul(pow(X1, 3.024), sin(mul(sin(neg(X0)), sin(mul(mul(mul(X1, pow(X0, 1.420)), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(neg(X1)))))), add(sub(X0, X1), neg(X1)))))))), log(sin(X1))))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(mul(X0, X0), sub(X0, X1)), neg(add(mul(mul(mul(mul(pow(X0, 2.850), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(mul(pow(X1, 3.024), sin(log(X1)))), log(sin(X1))))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(log(X1), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(pow(X0, 1.720), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), X0)))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
#
#   10    35.67      1.28634e+14       81          182.568          200.447      0.00s
#
# D-CODE model:  X0**C*(X0*X1**C*(X0 - X1) - X1) - log(X1) + sin(-X0**X0*(C - X0*(X0**C*X1**C*(X0**C - X1)*log(X1) - log(sin(X1)) + sin(log(X0)))) + X1 + X1**C + log(log(X2))) - sin(sin(C*X2))
#
# building blocks:
# X1**2.498600833205385
# log(sin(X1))
# X0**0.5974440705033232
# X0**1.2023549501406876
# -sin(X0)
# sin(X0**1.7202848489897984)
# sin(log(X0**1.4204037111558676))
# sin(X0 - X1)
# X1**(X0*X1)
# sin(3.000452122270786*X2)
# -sin(sin(3.000452122270786*X2))
# X0**0.868369908862835
# X0**1.4204037111558676
# log(X1**1.933823638326436)
# X0**X1
# X1**0.6698384162529611
# X0**X0
# log(log(X2))
# log(X0*X1)
# sin(X2**1.2820478906043982)
#
# number of building blocks:  20
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.12618013 1.1563143  1.1864209  1.22415442 1.27157488 1.32677478
#  1.38657322 1.44853656 1.51160497 1.57562137 1.64045604 1.70531968
#  1.76860439 1.8282921  1.88261827 1.93047884 1.97129014 2.00453653
#  2.02953575 2.04565985]
# [0.46316475 0.4611573  0.45653788 0.45191938 0.44785587 0.44418405
#  0.4411593  0.4395103  0.43969522 0.44136021 0.44364867 0.44604587
#  0.44888846 0.45304432 0.45911341 0.46692721 0.47575824 0.484948
#  0.49434287 0.50422376]
# [ 9.99709453 10.08027149 10.10830927 10.1417367  10.19429914 10.25374301
#  10.30723699 10.35340051 10.39851865 10.4473497  10.49913833 10.5505608
#  10.60010389 10.64896441 10.69880135 10.74980203 10.80099728 10.85167412
#  10.90191888 10.95199278]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      5.44442e+24       12          287.305           288.61      5.65m
#    1     6.26      5.45513e+10       12          287.485          286.993      4.45m
#    2     7.03      1.31059e+12       24          283.089          283.104      4.53m
#
# promising programs:
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(log(X1)), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(sub(log(2.698), neg(X1)))))), neg(0.681)))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sin(2.516)), 2.288)))))
# sub(neg(sin(mul(3.000, X2))), add(log(X1), sin(X1)))
# neg(add(pow(X1, 0.979), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), sub(1.891, X1))))
# sub(sin(mul(3.139, X2)), pow(X1, 2.321))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(X1, neg(X0)), sub(sin(X2), sub(1.717, X1))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(pow(X1, 2.415), sin(neg(X1))), 0.640)), pow(X1, 0.650))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(neg(sin(sub(log(add(X1, X1)), neg(log(X1)))))))
# sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(0.681)), log(X1))
# sub(sin(neg(sin(mul(3.000, X2)))), sub(log(add(X1, X1)), neg(log(X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(sin(sin(neg(X1))), log(sin(X1))), pow(X0, 0.232))))
# neg(sub(log(add(X1, X1)), neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))))
#
#    3     9.67      8.50939e+14       29          230.321          230.544      4.13m
#    4    13.17      8.34436e+14       45          220.004          219.469      4.08m
#
# promising programs:
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(X1)))))))))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sub(sin(X1), X0)), 2.288)))))), sin(sub(log(add(X1, X1)), neg(log(mul(sin(X0), add(0.482, X1)))))))
# sub(sub(sub(neg(X1), log(X1)), log(add(sin(sub(X0, X1)), pow(X1, X0)))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X1)), sin(pow(X1, 2.288)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, sin(neg(X1)))), pow(X2, 0.640)), sin(1.934)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(log(X1), 0.640)), pow(X1, 0.650))))), neg(sin(sin(neg(X2)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, log(mul(2.703, X1))))))), sub(neg(0.518), log(X1)))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(0.180))), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# sub(sub(sin(mul(3.139, X2)), sin(X0)), log(X1))
# sub(sin(neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(mul(3.000, X2))))))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(neg(pow(mul(3.139, X2), 2.920)))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X1, 1.506))))))))))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(log(neg(pow(mul(3.139, X2), 2.920))))))))), add(log(X1), sin(X1)))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(1.934)))))), neg(sin(sin(add(neg(log(X1)), add(neg(pow(X1, 1.185)), sub(X0, X0)))))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, pow(X2, 0.640))))), neg(0.681)), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(neg(sin(mul(3.000, X2))))))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(2.206))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
#
#    5    16.75      3.53098e+15       48          199.695           201.83      3.98m
#    6    20.12      8.22352e+15       24          187.846          188.602      4.33m
#    7    25.49       2.9207e+15       27          186.972          188.001      3.35m
#    8    31.51      5.75174e+15       66          182.234          182.453      2.54m
#    9    38.87       4.3625e+15       30          166.766          167.546      1.53m
#
# promising programs:
# mul(sub(neg(neg(log(X1))), X1), add(sin(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(neg(X2))))), sin(neg(X1)))), sin(sin(sin(add(neg(log(neg(pow(X1, 2.920)))), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, neg(sin(sin(neg(sin(sub(sub(add(X0, X2), pow(X2, 0.640)), sin(pow(log(X1), sin(mul(3.000, X2)))))))))))), pow(log(X1), 0.640)), pow(X1, 0.650))))), log(X1))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), log(mul(2.703, X1))), pow(log(X1), 0.640)), sin(pow(X1, 2.288))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sin(add(log(X0), add(log(mul(X2, X1)), X1)))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), X1)), sin(add(neg(pow(X1, 1.185)), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(mul(3.139, X2)), log(X1)))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(sub(sub(sub(sin(mul(3.139, X2)), sin(X0)), log(X1)), mul(mul(3.139, X2), X2)), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), log(mul(2.703, X1))), pow(log(X1), 0.640)), sin(add(X0, X0))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(pow(X1, 2.415), sin(neg(X1))), 0.640)), pow(X1, 0.650)))))), sin(add(neg(log(add(0.716, X1))), add(sub(add(neg(neg(neg(pow(X1, X0)))), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(mul(3.139, X2)), log(X1))))), neg(X0)), sub(sin(X2), sub(1.717, X1))))))
# sub(sin(sub(sub(sin(mul(3.139, X2)), sub(neg(sin(mul(X2, X2))), sub(0.868, X1))), neg(sin(sub(neg(pow(X1, 1.771)), log(X0)))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(pow(X2, 1.884), X1)))))))))))
# sub(sin(neg(sin(neg(sub(sin(mul(3.139, X2)), pow(X1, 1.733)))))), sin(add(neg(pow(X0, 0.289)), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))))))))
# sub(sin(neg(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 1.884)))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(neg(sin(1.431)), 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(sub(sub(sin(neg(X2)), pow(sin(1.378), 0.640)), pow(X1, 0.400))))))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(sub(sin(neg(neg(mul(3.139, sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(neg(0.681), 1.506))))))), neg(sin(sin(neg(log(X1)))))))))))))))))))
# sub(sub(sin(mul(3.139, X2)), sin(log(sin(sin(sub(sin(sub(sin(mul(2.654, X2)), sin(pow(add(sub(log(X0), neg(X0)), sub(sin(X2), neg(log(X1)))), 2.198)))), sin(log(sin(log(sin(X2))))))))))), sin(add(neg(log(add(log(X2), sin(1.476)))), add(sub(log(X0), neg(X0)), sin(X2)))))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(pow(X2, 0.640), 1.884)), pow(X2, 0.640)), sin(pow(log(X2), 0.640))))), sin(add(neg(sin(add(sub(neg(X1), log(log(X0))), sin(log(X0))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(X0))))))
#
#   10    45.80      1.66854e+15       91          165.836          165.743      0.00s
#
# D-CODE model:  (-X1 + log(X1))*(sin(sin(X1) - sin(-C*X2 + 2*X2**C + sin(log(-X2)))) + sin(sin(sin(X0 + log(X0) + log(X1) - log(-X1**C) + sin(X2) - sin(sin(-C*X2 + X1**C + X2**sin(sin(sin(X0 + X2 - X2**C - sin(log(X1)**sin(C*X2))))) + log(X1)**C))))))
#
# building blocks:
# X2**0.6395216888991612
# X2**0.9293847888625885
# log(X1*X2)
# sin(3.000452122270786*X2)
# sin(X1 + 0.9923542927995774)
# ---------------------------------------------------------------------------
# ValueErrorExpression                      Traceback (most recent call last)
# Cell In[2], line 19
#      17 for T0, T in zip(T0s, Ts):
#      18     print(f'T0: {T0}, T: {T}')
# ---> 19     D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
#
# File ~/Documents/polimi/thesis/repos/EKF-SINDy/Data/auxiliar_functions.py:31, in D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0, T)
#      28 def D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=0, T=15):
#      29     print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
#      30     ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed))
# ---> 31     building_blocks_lambda, function_names = run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed, T0=T0, T=T)
#      32     return building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/run_simulation_vi.py:86, in run(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, seed, n_seed, T0, T)
#      83 start = time.time()
#      85 # find the ODE f:
# ---> 86 f_hat, est_gp, building_blocks_lambda, function_names = run_gp_ode(ode_data, X_ph, y_ph, ode, x_id, s)
#      88 # evaluate the functional form:
#      89 f_true = ode.get_expression()[x_id]
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:201, in run_gp_ode(ode_data, X_train, y_train, ode, x_id, seed)
#     197 building_blocks = get_building_blocks(est_gp, ode)
#     199 additional_bb = list(a_add.args) # additional building blocks
# --> 201 building_blocks_lambda, function_names = get_building_blocks_lambda(building_blocks, ode, additional_bb)
#     203 return a, est_gp, building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:260, in get_building_blocks_lambda(building_blocks, ode, additional_bb, idx)
#     253             subprograms_filtered.append(subprograms[i])
#     255     return subprograms_filtered
#     258 def get_building_blocks_lambda(building_blocks, ode, additional_bb, idx=0):
#     259
# --> 260     # print('building blocks:')
#     261     # for i in range(len(building_blocks)):
#     262     #     print(building_blocks[i])
#     263     # print('number of building blocks: ', len(building_blocks))
#     264     # print(' ')
#     267     print('building blocks:') # pysym version
#     268     building_blocks_pysym = []
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:359, in gp_to_pysym_with_coef_constants(est_gp, ode, tol, tol2, expand, promising)
#     356 else:
#     357     f_star = est_gp._program
# --> 359 f_star_list, var_list, coef_list = parse_program_to_list(f_star.program)
#     360 # print(f_star_list)
#     361 # print(var_list)
#     362 # print(coef_list)
#     364 f_star_infix = generator.Generator.prefix_to_infix(f_star_list, variables=var_list, coefficients=coef_list)
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/utils/generator.py:558, in Generator.infix_to_sympy(cls, infix, variables, rewrite_functions, no_rewrite)
#     556     raise ImAccomulationBounds
#     557 if expr.has(sp.I) or expr.has(AccumBounds):
# --> 558     raise ValueErrorExpression
#     559 if not no_rewrite:
#     560     expr = cls.rewrite_sympy_expr(expr, rewrite_functions)
#
# ValueErrorExpression:

# %%
#D-CODE series 3 - POLYNOMIAL VERSION:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [15, 20]
#T0s = [0, 5, 10, 15, 20]
Ts = [30, 35]
#Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 15, T: 30
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.05800508 1.05470963 1.03674209 1.01133535 0.98205567 0.94977985
#  0.91437937 0.87592543 0.83512402 0.79329375 0.75216452 0.71354103
#  0.67890345 0.64919751 0.62499372 0.60683831 0.59540754 0.59131565
#  0.594851   0.60599851]
# [0.86098146 0.86178728 0.86131893 0.8621175  0.86285643 0.86136984
#  0.85685661 0.8500116  0.84182186 0.83259188 0.82198915 0.80966988
#  0.79565199 0.78017679 0.76345312 0.74568061 0.72727446 0.70892551
#  0.69133509 0.67485381]
# [14.99457149 15.09300328 15.11024126 15.13616715 15.19021995 15.25385449
#  15.3087389  15.35375598 15.39830643 15.44854936 15.50240521 15.55483018
#  15.60421351 15.65277039 15.70253542 15.75289771 15.80214403 15.85013467
#  15.89853687 15.94870518]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34        1.568e+25       20          51.9549          52.2362      5.44m
#    1     7.23      3.44315e+15       20          51.9517          52.2651      4.31m
#    2     7.28      8.66874e+12       25          34.4682          34.3907      3.91m
#
# promising programs:
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X1, X1)))))
# sin(sub(log(mul(X1, sin(3.461))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 3.392))))
# sin(sub(X1, sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(neg(X1), sin(2.236))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), 0.717)))
# sin(mul(3.139, X2))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), sin(add(X0, X1))), sin(pow(2.488, 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sub(0.793, mul(log(neg(pow(X0, 3.875))), log(neg(sin(1.999)))))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(neg(pow(X1, 2.644)), 2.288)))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(X0))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, neg(X1))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2)))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2)))))), neg(0.681))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(sin(mul(neg(log(X1)), sin(log(X0)))), sin(2.236))))), neg(0.681))
#
#    3     8.19      3.89536e+15       18          16.6763          16.6624      3.68m
#    4    11.42      2.23391e+10       24          9.34874           9.3207      3.66m
#
# promising programs:
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X2)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(neg(0.681), 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(add(X0, X1))))), neg(sub(0.717, X1)))
# sub(sin(sub(pow(0.658, 0.657), sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sub(0.793, pow(X1, 2.014)))))), neg(sub(sin(2.325), X1)))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))), neg(sin(sin(sub(0.711, X1)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(X0, X2))))))), neg(sub(0.637, X1)))
# neg(sin(neg(sub(sin(sub(0.717, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), 0.919))))))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(neg(2.862))))))))), neg(sub(0.868, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sin(2.325), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.000, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(mul(X1, X2), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sub(0.868, X1), mul(3.108, X2))))))), neg(sub(0.637, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(sub(sub(X1, X2), mul(3.108, X2))))))), neg(sub(0.637, X1)))
#
#    5    15.97      5.40578e+10       24          9.33153          9.47561      3.48m
#    6    21.17      6.72698e+10       33            6.953           6.9306      3.41m
#    7    21.46      5.22495e+10       33          6.94488          7.00363      2.65m
#    8    26.01      2.01893e+11       33          6.94494          7.00312      1.95m
#    9    30.60      1.32516e+11       21          6.48063          6.50171      1.04m
#
# promising programs:
# neg(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, X0)), pow(sin(X0), 0.640)), sin(add(X0, X1)))), sin(add(neg(X1), sin(2.236)))))
# sub(sin(sub(sub(X0, X0), sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, pow(X1, 3.956))), sin(add(mul(X0, X1), sin(X0)))))), neg(sub(0.868, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(add(sub(log(3.108), mul(log(X2), sub(1.717, X1))), mul(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(neg(X0))))))))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0)))), neg(sub(0.717, X1)))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(3.000, X2), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(neg(mul(3.139, X2)), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0)))), neg(sin(sub(0.711, X1))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 0.640)), pow(X2, 0.640)), sin(X0)))), neg(sub(0.711, X1)))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, pow(X0, 1.380))), pow(mul(3.000, X2), 2.288)), sin(X0)))), neg(sub(0.717, X1)))
#
#   10    31.72      1.37767e+11       31          5.39735          5.46589      0.00s
#
# D-CODE model:  C - X1 + sin(-C*X2 + X2**C + X2**(X1**C) + sin(X0*X1 + sin(X0)))
#
# building blocks:
# sin(2*X1)
# X2**0.6395216888991612
# 3.1394689809108645*X2
# X2**1.8842541798778392
# X2**2.182075682230325
# -0.31441230343413796*X1
# -sin(X1 - 0.78663562254828674)
# sin(X0 + X1)
# 0.98087503140919141
# X1**(-X0)
# sin(X1**(-X0))
# 3.1084510584079896*X2
# sin(log(X0))
# X2**X2
# 12.35452176388197*X2**2.288047709755393
# 3.000452122270786*X2
# -sin(X1**2.0137689262307594 - 0.7928934028760071)
# -sin(sin(X1 - 0.7108489859819501))
# -sin(X1 - 0.7174908107608908)
# -0.2759786024156675
# sin(X1**(-0.2759786024156675))
# sin(X0)**0.6395216888991612
# X2**X0
# X2**(X1**3.9562130703399276)
# (1.7167909351554378 - X1)*log(X2)
# -sin(X1 - 0.7108489859819501)
# X0**1.3798775831846182
# 0.8681241135578475
# -X1
# sin(-3.1394689809108645*X2 + X2**1.8842541798778392 + X2**(X1**3.9562130703399276) + sin(X0*X1 + sin(X0)))
#
# number of building blocks:  30
#
# T0: 20, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.8847791  0.88934426 0.89307867 0.90373045 0.92330836 0.9497428
#  0.97991463 1.01181917 1.04479584 1.07842559 1.11151931 1.14211658
#  1.16826829 1.1886972  1.20273356 1.20975153 1.20880233 1.19883965
#  1.17927357 1.15029467]
# [0.96307461 0.96140043 0.95555174 0.95192465 0.95154928 0.95264399
#  0.95379907 0.95544899 0.95912152 0.96581617 0.97523251 0.986389
#  0.99876102 1.01274785 1.02915277 1.04836445 1.07004414 1.09341339
#  1.11762889 1.14186241]
# [19.99450487 20.10729364 20.11116891 20.12809312 20.18434507 20.25405222
#  20.31134607 20.35422583 20.39584492 20.4453447  20.50021923 20.55319836
#  20.6015589  20.64848922 20.69769519 20.74915377 20.80028674 20.84968066
#  20.89847202 20.94841881]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      5.33693e+24       20          237.821          242.272      4.84m
#    1     5.46      1.23101e+10       21          216.598          212.697      4.36m
#    2     6.93      1.35375e+12       21          169.257          166.802      4.16m
#
# promising programs:
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(pow(X0, 3.438), log(X0)))))
# sub(sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), sin(pow(X0, 2.770)))
# sub(add(add(sin(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(0.681))), pow(X0, 3.262)), neg(log(sin(X1)))), pow(X0, 1.207))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(pow(X0, 3.438), log(X0))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(pow(X0, 1.219), sin(pow(X0, 2.951)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, add(sin(log(X0)), neg(neg(0.757))))), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), sin(mul(X1, log(X2)))), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(pow(X0, 2.859), pow(X0, 1.207))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(pow(X0, 2.120), sub(X0, X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(X0, X1), pow(X0, 2.235))))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(mul(sin(sin(log(X1))), neg(mul(pow(X1, 1.612), pow(X0, 2.972)))), pow(X0, 1.720)))), neg(0.681))
# mul(sin(sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(neg(log(pow(X1, 2.305))))))), pow(X0, 1.420))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(neg(log(pow(X1, 2.305))))))
#
#    3     8.93      2.79228e+15       27          115.972          116.261      3.99m
#    4    11.04      6.50204e+09       27          114.406          114.908      3.68m
#
# promising programs:
# sub(mul(sub(pow(X0, 2.190), mul(0.443, X0)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sub(pow(X0, mul(X0, X0)), X1), sin(add(mul(3.000, X2), pow(X0, 2.431))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), neg(neg(0.681)))))), neg(sub(pow(X0, 2.859), pow(X0, 1.207))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X0, 1.599)))))
# sub(sub(X0, X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), mul(mul(mul(X0, X0), sub(X0, sin(pow(X1, 2.288)))), log(X0)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), X0), pow(X2, 0.640)), sin(pow(X1, 2.288))))), neg(mul(sin(mul(sin(X0), log(X0))), pow(X0, 3.895))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(sin(sin(sin(neg(mul(X2, X1))))), 0.640)), sin(pow(X1, 2.288)))))
# add(sub(mul(X0, X0), X1), neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(mul(3.100, X1))))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))), 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 2.143)), sin(pow(X1, 2.288)))))
# sub(sin(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, mul(sin(X0), log(X0)))))), neg(0.681))), neg(mul(pow(X0, 3.438), log(X0))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
#
#    5    15.62       5.8029e+09       29          107.156           109.65      3.57m
#    6    21.14      2.81577e+10       48          97.8109          97.3036      3.42m
#    7    26.35      7.66596e+09       48          93.4182          92.3483      2.97m
#    8    30.99      3.21827e+09       48          88.0029          87.9504      2.28m
#    9    37.18      1.28105e+10       48          87.9918          88.0497      1.38m
#
# promising programs:
# sub(pow(X0, 3.039), add(sin(sub(sub(sub(mul(3.139, X2), pow(sub(sub(pow(X0, 3.013), X0), neg(sin(mul(3.000, X2)))), pow(X0, sub(mul(3.139, X2), mul(3.139, X2))))), pow(X2, 0.640)), sin(pow(X1, sub(pow(X0, 2.708), sin(mul(pow(X0, pow(X0, 1.599)), X0))))))), neg(neg(pow(X0, 1.771)))))
# sub(mul(mul(pow(X0, 3.438), log(X0)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(sub(sub(X0, X1), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))), 2.288)))))
# sub(mul(log(X0), pow(X0, 3.171)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X0, pow(X0, 1.880))), pow(X2, 0.640)), sin(add(X0, X0)))))), 0.640)), sin(pow(X1, pow(X2, 2.767))))))
# add(neg(sin(add(sin(3.346), sub(sub(sub(mul(3.139, X2), pow(X2, X1)), add(X0, neg(sin(sub(pow(X0, 2.687), sin(pow(X0, 2.319))))))), sin(1.884))))), mul(mul(pow(X0, 1.913), X0), log(X0)))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, sin(pow(X1, 2.288)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(0.866, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, sin(pow(X1, 2.288)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, sin(pow(X1, 2.288)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, sin(pow(X1, 2.288)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)))), pow(X0, sin(pow(X1, 2.288)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X0, sin(pow(X1, 3.645)))), pow(mul(mul(X0, X0), sub(X0, X1)), log(X0)))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, mul(X0, X0)))))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), 0.811), pow(X2, 0.640)), sin(pow(sub(sub(X0, X1), sin(sub(mul(3.139, X2), pow(X2, 1.884)))), 2.288)))))
# sub(mul(log(X0), pow(X0, 3.171)), sin(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, mul(3.139, X2))), 0.640)), mul(mul(sin(sin(log(X1))), neg(mul(pow(X1, 1.612), pow(X0, 2.972)))), pow(X0, 1.720))), sin(sin(pow(X1, X0))))))
# sub(mul(sub(pow(X0, 2.190), mul(0.443, X0)), sub(X0, sin(mul(X0, X0)))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), sin(0.640)), sin(pow(X2, 1.884)))))
# sub(add(sub(neg(log(1.372)), sin(sin(sub(sub(sub(mul(3.139, X2), sin(pow(sub(sub(X0, X1), sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))), 2.288))), pow(neg(sin(sin(neg(neg(sin(mul(3.000, X2))))))), 0.640)), sin(1.378))))), X0), neg(sub(X0, add(log(add(X1, X0)), sin(pow(X0, 2.694))))))
# sub(mul(pow(X0, pow(X0, 1.599)), sub(X0, X1)), sin(sub(sub(sub(mul(3.139, X2), pow(0.811, 1.884)), pow(X2, 0.640)), sin(pow(sub(sub(X0, X1), sin(sin(sub(sub(sub(sin(add(X0, X1)), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))), 2.288)))))
#
#   10    43.62      3.01962e+10       56          81.2605          82.6713      0.00s
#
# D-CODE model:  sin(-C*X2 - X0 + X0**C + X2**C + sin(X1**(X0**C - sin(X0*X0**(X0**C)))) + sin(C*X2))
#
# building blocks:
# X0**1.5986934150251917
# sin(X1**2.288047709755393)
# X0**(X0**1.5986934150251917)
# X2**1.8842541798778392
# 3.1394689809108645*X2
# X2**0.6395216888991612
# log(sin(X1))
# X0**1.2073528903982544
# sin(3.000452122270786*X2)
# 3.000452122270786*X2
# -sin(sin(3.000452122270786*X2))
# sin(log(X0))
# sin(X1*log(X2))
# X0**2.1197377038475516
# X0**1.4204037111558676
# log(X1**2.305327328044378)
# -sin(log(X1**2.305327328044378))
# 0.4432597352761886*X0
# X0**(X0**2)
# X0**2.43136392889404
# sin(log(X0)*sin(X0))
# X1*X2
# -sin(sin(X1*X2))
# 3.1003885276129344*X1
# 0.67405396039287823
# X0**1.7709764947455422
# 0.98087503140919141
# X1**(X2**2.767142646161873)
# sin(2*X0)
# X2**X1
# sin(X0**(X0**2))
# X0**sin(X1**2.288047709755393)
# log(X0 + X1)
# X0**sin(X1**3.6451209223575134)
# sin(sin(log(X1)))
# sin(sin(X1**X0))
# X1**X0
# sin(X1**X0)
# 8.0498705930896413
# X0**3.0387495450398103
# sin(-X0 + X0**3.0126895732469965 + X2**0.6395216888991612 - 3.1394689809108645*X2 + sin(X1**(X0**2.707876708959799 - sin(X0*X0**(X0**1.5986934150251917)))) + sin(3.000452122270786*X2))
#
# number of building blocks:  41

# %%
#D-CODE series 3 - POLYNOMIAL VERSION:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.60627e+24        9          145.233          146.278      7.33m
#    1     6.86      9.41891e+14        7          139.715          139.687      5.27m
#    2     7.60      1.43024e+16        9          113.547          113.516      3.96m
#
# promising programs:
# sub(sin(add(X1, log(neg(mul(0.162, X1))))), neg(mul(mul(X1, X1), neg(X0))))
# add(mul(neg(X0), mul(X1, X1)), sin(2.236))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), pow(X1, 2.012)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sin(X2)))), neg(mul(pow(X1, 1.996), X0)))
# add(sin(log(sub(neg(3.833), sub(sin(add(X1, X0)), X1)))), neg(mul(pow(X1, 1.996), X0)))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(0.718))
# sub(sin(add(log(3.498), mul(X1, X1))), mul(X1, X0))
# sin(mul(3.187, X2))
#
#    3     6.62      5.07817e+14       16          111.113          110.921      3.49m
#    4     7.90      1.83924e+10       14          49.5635          49.7743      3.02m
#
# promising programs:
# add(sin(add(X0, X1)), sub(sin(mul(3.187, X2)), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(add(X0, X1)), sub(sin(sin(mul(neg(X2), neg(3.202)))), X1))
# add(sin(mul(3.187, X2)), add(sin(add(pow(X1, 1.168), X1)), neg(mul(X1, X0))))
# add(sin(add(X0, X1)), sub(sin(sin(sin(mul(neg(X2), neg(3.202))))), X1))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.659, X1), mul(X1, X0)))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(sub(1.680, X1), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(3.187, X2)), sub(pow(X1, 0.045), mul(X1, X0)))
# sub(sub(sin(sin(mul(neg(X2), neg(3.202)))), mul(X1, X0)), neg(0.715))
# add(mul(X0, mul(sub(sin(mul(neg(X2), neg(3.202))), X1), X1)), sin(0.718))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sub(pow(X1, 0.045), mul(X1, X0)))
# add(sin(mul(neg(X2), neg(3.202))), sub(0.793, X1))
# add(mul(X0, mul(sub(sin(neg(3.392)), X1), X1)), sin(mul(neg(X2), neg(3.202))))
# add(sin(sin(mul(neg(X2), neg(3.202)))), sin(add(X1, add(X1, X0))))
#
#    5     9.11      8.70771e+15       11          41.0211          41.0373      2.52m
#    6    10.00      4.69181e+13       15          16.0824          16.1976      2.11m
#    7    13.35      1.45465e+15       14          15.8489          15.9099      1.68m
#    8    16.30      7.06883e+15       14           15.847           15.927      1.19m
#    9    17.91      7.11502e+15       13           13.946          14.3429     36.35s
#
# promising programs:
# add(sub(mul(neg(X0), pow(X1, 1.955)), neg(0.715)), sin(mul(3.170, X2)))
# add(sin(log(mul(neg(3.833), sub(mul(mul(X0, X1), X1), 3.498)))), sub(sin(mul(3.187, X2)), mul(mul(X0, X1), X1)))
# sub(add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0))), neg(sub(X0, X0)))
# add(sin(mul(3.151, X2)), sub(sin(sub(1.680, X1)), mul(X1, X0)))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# add(sin(mul(3.187, X2)), add(sin(0.718), mul(neg(X0), pow(X1, 1.955))))
# sub(add(sin(log(log(neg(sin(add(sub(X1, pow(X2, 2.198)), sin(sin(mul(neg(X2), neg(3.202)))))))))), neg(mul(pow(X1, 1.996), X0))), neg(sin(sin(mul(3.187, X2)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# sub(sin(log(2.105)), neg(add(sin(mul(3.187, X2)), neg(mul(pow(X1, 1.996), X0)))))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sub(sin(log(2.105)), mul(mul(X0, X1), X1)), sin(mul(3.187, X2)))
# add(sin(mul(3.187, X2)), sub(sin(log(2.105)), mul(mul(X0, X1), X1)))
#
#   10    20.02      2.73212e+10       14          6.72017          6.72766      0.00s
#
# D-CODE model:  C - X0*X1**C + sin(C*X2)
#
# building blocks:
# -X0*X1**2
# 0.16215838256749215*X1
# log(-0.16215838256749215*X1)
# X1**2
# sin(X0 + X1)
# 0.24790920821746188
# sin(3.186700227887775*X2)
# X1**1.1684265190435612
# sin(X1 + X1**1.1684265190435612)
# X1**0.04531823176110219
# sin(X0 + 2*X1)
# -sin(X1 - 1.6795866326184206)
# 0.67749455440052803
# 0.7153610709117155
# -X0*X1**1.954775679844595
# sin(3.1703253763918724*X2)
#
# number of building blocks:  16
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [2.33761972 2.20663286 2.03468758 1.83731175 1.62093645 1.39054147
#  1.15584966 0.93121655 0.73044156 0.56163325 0.42605283 0.32065966
#  0.24128169 0.18403423 0.14513293 0.12065073 0.10707052 0.1021016
#  0.10485464 0.11522456]
# [1.14061167 1.25849889 1.38557153 1.52567747 1.67606748 1.82792663
#  1.96916034 2.08786165 2.1750891  2.22637567 2.2420097  2.22630814
#  2.18612231 2.12897942 2.06147464 1.98846692 1.91319974 1.83795358
#  1.76462708 1.69486665]
# [5.00040622 5.06312791 5.10170825 5.1443415  5.19646318 5.25143129
#  5.30302841 5.35100742 5.39879155 5.44872515 5.50018511 5.55128405
#  5.60123342 5.65076967 5.70082299 5.75136315 5.80162881 5.8511668
#  5.90037582 5.95004226]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.42304e+23       14          368.331          369.765      4.95m
#    1     6.01      3.69567e+10       14          324.441          330.453      4.61m
#    2     6.28      6.51605e+15       14          325.147          324.097      4.22m
#
# promising programs:
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1)))), X0)
# mul(mul(mul(mul(X1, X0), 2.688), add(pow(X0, 0.597), neg(X1))), X0)
# sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), X0), add(mul(pow(X0, 1.202), sin(mul(sub(X0, X1), sin(X1)))), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# mul(mul(mul(X1, X0), mul(2.998, X0)), add(pow(X0, 0.597), neg(X1)))
# sub(sub(mul(pow(X1, 3.024), sin(mul(sin(neg(X0)), sin(pow(X0, 1.720))))), neg(pow(X0, 2.850))), pow(X0, 1.207))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1))))
# mul(mul(mul(X1, X0), mul(mul(X1, X0), X0)), add(pow(X0, 0.597), neg(X1)))
#
#    3     7.90      1.27573e+14       31          291.526          294.187      3.63m
#    4     9.39      2.62864e+16       33          283.332          287.343      3.33m
#
# promising programs:
# mul(pow(X0, 1.653), add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(mul(sin(pow(X2, 2.152)), add(2.283, X1)), log(sin(X1)))), X0)
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(mul(X1, X0))), pow(X1, 1.671)), sub(sin(sin(sub(X0, X1))), log(sin(X1))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(sin(X1))))
# sub(mul(mul(mul(pow(X1, mul(X1, X0)), X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1))
# mul(mul(sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(sub(X0, X1), mul(X0, X1)), X1))), pow(X0, 0.868)), X0)
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(mul(mul(X0, X0), sub(X0, X1)), X1), mul(X1, X0))))
# add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), sub(X0, X1)), log(X1)), pow(X1, 2.499)), sub(mul(sub(X0, X1), pow(X0, 1.420)), log(sin(X1))))
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(pow(X0, 1.420))), log(sin(X1)))), X0)
# mul(X0, mul(sub(sub(pow(X0, 1.684), X1), X1), mul(X1, X0)))
# mul(mul(mul(X1, X0), mul(sub(pow(X0, 1.200), mul(sin(mul(sub(X0, X1), mul(X0, X1))), mul(X0, X1))), X0)), add(pow(X0, 0.597), neg(X1)))
# sub(add(mul(mul(sub(X0, X1), pow(X0, 1.720)), mul(X1, X0)), neg(log(pow(X1, 1.934)))), pow(X0, 1.207))
# mul(mul(mul(X1, X0), pow(X0, X1)), add(mul(sin(sub(X0, X1)), pow(X0, 1.420)), neg(X1)))
#
#    5    12.02      1.45472e+16       35          251.079          245.263      3.13m
#    6    15.82      3.56412e+14       36          248.452          252.062      2.78m
#    7    19.77      6.51555e+15       45          195.777          190.578      2.29m
#    8    24.21      1.60529e+12       35          200.077          203.821      1.70m
#    9    29.89      7.64663e+14       35          198.186          220.841      1.02m
#
# promising programs:
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X1, X1))), sin(sub(sub(mul(pow(X0, X0), sub(1.881, mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(log(X0)), log(sin(X1)))), X0))), X1), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# add(mul(pow(X0, X1), sub(X0, X1)), add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(mul(X1, X0))), pow(X1, 1.671)), sub(mul(sin(neg(X0)), sin(mul(3.000, X2))), log(sin(X1)))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(add(pow(X0, 0.597), mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499))))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(mul(X1, pow(X0, 0.597)), mul(X0, X0)), add(pow(X1, 0.670), log(X0))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(pow(X0, 0.597))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# mul(mul(add(mul(mul(mul(mul(mul(X1, X0), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(pow(X2, 1.282)), log(sin(X1)))), X0), X0)
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(add(neg(neg(X1)), neg(X1)))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(mul(X0, X0), sub(X0, X1)), neg(add(mul(mul(mul(mul(pow(X0, 2.850), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(mul(pow(X1, 3.024), sin(mul(sin(neg(X0)), sin(mul(mul(mul(X1, pow(X0, 1.420)), sin(sub(mul(X2, X2), add(pow(X1, 0.670), log(neg(X1)))))), add(sub(X0, X1), neg(X1)))))))), log(sin(X1))))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sub(mul(mul(X0, X0), sub(X0, X1)), neg(add(mul(mul(mul(mul(pow(X0, 2.850), mul(X0, X0)), add(pow(X0, 0.597), neg(X1))), log(X1)), pow(X1, 2.499)), sub(sin(mul(pow(X1, 3.024), sin(log(X1)))), log(sin(X1))))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(log(X1), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(pow(X0, 1.720), log(log(X2)))))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(sub(mul(X2, X2), add(pow(X1, 0.670), X0)))), sin(neg(sin(mul(3.000, X2))))))
# neg(sub(add(sub(neg(sub(mul(mul(X0, X0), sub(mul(sub(X0, X1), mul(X1, mul(X1, X0))), X1)), log(X1))), sin(sub(X2, X2))), sin(3.210)), sin(neg(sin(mul(3.000, X2))))))
#
#   10    35.67      1.28634e+14       81          182.568          200.447      0.00s
#
# D-CODE model:  X0**C*(X0*X1**C*(X0 - X1) - X1) - log(X1) + sin(-X0**X0*(C - X0*(X0**C*X1**C*(X0**C - X1)*log(X1) - log(sin(X1)) + sin(log(X0)))) + X1 + X1**C + log(log(X2))) - sin(sin(C*X2))
#
# building blocks:
# X1**2.498600833205385
# X0*X1
# log(sin(X1))
# X0**0.5974440705033232
# 2.688327179015696*X0*X1
# X0**2
# 2.9980866784556848*X0
# X0**1.2023549501406876
# -sin(X0)
# sin(X0**1.7202848489897984)
# sin(log(X0**1.4204037111558676))
# X0**1.653317240481321
# sin(X0 - X1)
# X1**(X0*X1)
# sin(3.000452122270786*X2)
# -sin(sin(3.000452122270786*X2))
# X0**0.868369908862835
# 3.000452122270786*X2
# X0**1.4204037111558676
# log(X1**1.933823638326436)
# X0**X1
# X1**0.6698384162529611
# X0**X0
# log(log(X2))
# log(X0*X1)
# X2**2
# sin(X2**1.2820478906043982)
# -log(X1)
# -sin(sin(3.000452122270786*X2))
# X0**2*(X0*X1**2*(X0 - X1) - X1)
# sin(-X0**X0*(-X0*(X0**3*X1**3.498600833205385*(X0**0.5974440705033232 - X1)*log(X1) - log(sin(X1)) + sin(log(X0))) + 1.880769351908775) + X1**0.6698384162529611 + X1 + log(log(X2)))
#
# number of building blocks:  31
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.12618013 1.1563143  1.1864209  1.22415442 1.27157488 1.32677478
#  1.38657322 1.44853656 1.51160497 1.57562137 1.64045604 1.70531968
#  1.76860439 1.8282921  1.88261827 1.93047884 1.97129014 2.00453653
#  2.02953575 2.04565985]
# [0.46316475 0.4611573  0.45653788 0.45191938 0.44785587 0.44418405
#  0.4411593  0.4395103  0.43969522 0.44136021 0.44364867 0.44604587
#  0.44888846 0.45304432 0.45911341 0.46692721 0.47575824 0.484948
#  0.49434287 0.50422376]
# [ 9.99709453 10.08027149 10.10830927 10.1417367  10.19429914 10.25374301
#  10.30723699 10.35340051 10.39851865 10.4473497  10.49913833 10.5505608
#  10.60010389 10.64896441 10.69880135 10.74980203 10.80099728 10.85167412
#  10.90191888 10.95199278]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      5.44442e+24       12          287.305           288.61      5.16m
#    1     6.26      5.45513e+10       12          287.485          286.993      4.47m
#    2     7.03      1.31059e+12       24          283.089          283.104      4.59m
#
# promising programs:
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(log(X1)), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(sub(log(2.698), neg(X1)))))), neg(0.681)))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sin(2.516)), 2.288)))))
# sub(neg(sin(mul(3.000, X2))), add(log(X1), sin(X1)))
# neg(add(pow(X1, 0.979), mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), sub(1.891, X1))))
# sub(sin(mul(3.139, X2)), pow(X1, 2.321))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(X1, neg(X0)), sub(sin(X2), sub(1.717, X1))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(pow(X1, 2.415), sin(neg(X1))), 0.640)), pow(X1, 0.650))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(neg(sin(sub(log(add(X1, X1)), neg(log(X1)))))))
# sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(0.681)), log(X1))
# sub(sin(neg(sin(mul(3.000, X2)))), sub(log(add(X1, X1)), neg(log(X1))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(mul(3.000, X2)))), neg(mul(sub(sin(sin(neg(X1))), log(sin(X1))), pow(X0, 0.232))))
# neg(sub(log(add(X1, X1)), neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))))
#
#    3     9.67      8.50939e+14       29          230.321          230.544      4.24m
#    4    13.17      8.34436e+14       45          220.004          219.469      4.17m
#
# promising programs:
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(X1)))))))))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(log(sub(sin(X1), X0)), 2.288)))))), sin(sub(log(add(X1, X1)), neg(log(mul(sin(X0), add(0.482, X1)))))))
# sub(sub(sub(neg(X1), log(X1)), log(add(sin(sub(X0, X1)), pow(X1, X0)))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X1)), sin(pow(X1, 2.288)))))
# sub(sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, sin(neg(X1)))), pow(X2, 0.640)), sin(1.934)))), neg(sin(sin(add(neg(log(pow(X1, 1.519))), neg(X1))))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(log(X1), 0.640)), pow(X1, 0.650))))), neg(sin(sin(neg(X2)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, log(mul(2.703, X1))))))), sub(neg(0.518), log(X1)))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(0.180))), sub(X0, X0)), sub(sin(neg(sin(mul(3.000, X2)))), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# sub(sub(sin(mul(3.139, X2)), sin(X0)), log(X1))
# sub(sin(neg(sin(neg(sub(sin(sub(X0, X0)), mul(3.000, X2)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(mul(3.000, X2))))))
# sub(sin(neg(sin(mul(3.000, X2)))), sin(add(neg(log(neg(pow(mul(3.139, X2), 2.920)))), add(sub(log(X0), neg(X0)), sub(sin(X2), neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X1, 1.506))))))))))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, neg(log(neg(pow(mul(3.139, X2), 2.920))))))))), add(log(X1), sin(X1)))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(1.934)))))), neg(sin(sin(add(neg(log(X1)), add(neg(pow(X1, 1.185)), sub(X0, X0)))))))
# mul(neg(sin(pow(X2, 0.929))), sub(sub(log(X1), sub(X0, X0)), sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, pow(X2, 0.640))))), neg(0.681)), neg(sin(add(log(X0), add(log(mul(X2, X1)), X1)))))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(neg(sin(mul(3.000, X2))))))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
# add(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(2.206))))), sin(add(sub(neg(X1), log(X1)), sin(log(X0)))))
#
#    5    16.75      3.53098e+15       48          199.695           201.83      3.99m
#    6    20.12      8.22352e+15       24          187.846          188.602      3.81m
#    7    25.49       2.9207e+15       27          186.972          188.001      3.62m
#    8    31.51      5.75174e+15       66          182.234          182.453      2.85m
#    9    38.87       4.3625e+15       30          166.766          167.546      1.43m
#
# promising programs:
# mul(sub(neg(neg(log(X1))), X1), add(sin(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(log(neg(X2))))), sin(neg(X1)))), sin(sin(sin(add(neg(log(neg(pow(X1, 2.920)))), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, neg(sin(sin(neg(sin(sub(sub(add(X0, X2), pow(X2, 0.640)), sin(pow(log(X1), sin(mul(3.000, X2)))))))))))), pow(log(X1), 0.640)), pow(X1, 0.650))))), log(X1))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), log(mul(2.703, X1))), pow(log(X1), 0.640)), sin(pow(X1, 2.288))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sin(add(log(X0), add(log(mul(X2, X1)), X1)))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), X1)), sin(add(neg(pow(X1, 1.185)), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(mul(3.139, X2)), log(X1)))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(sub(sub(sub(sin(mul(3.139, X2)), sin(X0)), log(X1)), mul(mul(3.139, X2), X2)), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), log(mul(2.703, X1))), pow(log(X1), 0.640)), sin(add(X0, X0))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(neg(sin(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(mul(pow(X1, 2.415), sin(neg(X1))), 0.640)), pow(X1, 0.650)))))), sin(add(neg(log(add(0.716, X1))), add(sub(add(neg(neg(neg(pow(X1, X0)))), add(sub(log(X0), neg(X0)), sub(sin(X2), sub(sin(mul(3.139, X2)), log(X1))))), neg(X0)), sub(sin(X2), sub(1.717, X1))))))
# sub(sin(sub(sub(sin(mul(3.139, X2)), sub(neg(sin(mul(X2, X2))), sub(0.868, X1))), neg(sin(sub(neg(pow(X1, 1.771)), log(X0)))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(pow(X2, 1.884), X1)))))))))))
# sub(sin(neg(sin(neg(sub(sin(mul(3.139, X2)), pow(X1, 1.733)))))), sin(add(neg(pow(X0, 0.289)), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(2.488, 2.288)))))))))))
# sub(sin(neg(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 1.884)))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(neg(sin(1.431)), 1.884)), pow(X2, 0.640)), sin(sin(pow(2.488, 2.288)))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(sub(sin(mul(3.139, X2)), sin(add(neg(log(neg(sin(sin(pow(X2, 1.427)))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(neg(sin(pow(3.000, X2)))))))))), sin(add(neg(sin(mul(3.139, X2))), add(sub(log(X0), sin(log(X2))), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(mul(X1, sub(mul(3.139, X2), pow(X2, 1.884))))))))))))
# sub(sin(neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(sub(sub(sin(neg(X2)), pow(sin(1.378), 0.640)), pow(X1, 0.400))))))))))), sin(add(neg(log(add(0.716, X1))), add(sub(log(X0), sub(X1, X1)), sub(sin(X2), neg(sin(add(sin(sin(X1)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, sin(sub(sin(neg(neg(mul(3.139, sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(neg(0.681), 1.506))))))), neg(sin(sin(neg(log(X1)))))))))))))))))))
# sub(sub(sin(mul(3.139, X2)), sin(log(sin(sin(sub(sin(sub(sin(mul(2.654, X2)), sin(pow(add(sub(log(X0), neg(X0)), sub(sin(X2), neg(log(X1)))), 2.198)))), sin(log(sin(log(sin(X2))))))))))), sin(add(neg(log(add(log(X2), sin(1.476)))), add(sub(log(X0), neg(X0)), sin(X2)))))
# sub(neg(sin(sub(sub(sub(mul(3.139, X2), pow(pow(X2, 0.640), 1.884)), pow(X2, 0.640)), sin(pow(log(X2), 0.640))))), sin(add(neg(sin(add(sub(neg(X1), log(log(X0))), sin(log(X0))))), add(sub(log(X0), neg(X0)), sub(sin(X2), sin(X0))))))
#
#   10    45.80      1.66854e+15       91          165.836          165.743      0.00s
#
# D-CODE model:  (-X1 + log(X1))*(sin(sin(X1) - sin(-C*X2 + 2*X2**C + sin(log(-X2)))) + sin(sin(sin(X0 + log(X0) + log(X1) - log(-X1**C) + sin(X2) - sin(sin(-C*X2 + X1**C + X2**sin(sin(sin(X0 + X2 - X2**C - sin(log(X1)**sin(C*X2))))) + log(X1)**C))))))
#
# building blocks:
# 3.1394689809108645*X2
# X2**0.6395216888991612
# X1*X2
# X2**0.9293847888625885
# log(X1*X2)
# sin(3.000452122270786*X2)
# sin(X1 + 0.9923542927995774)
# ---------------------------------------------------------------------------
# ValueErrorExpression                      Traceback (most recent call last)
# Cell In[2], line 19
#      17 for T0, T in zip(T0s, Ts):
#      18     print(f'T0: {T0}, T: {T}')
# ---> 19     D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
#
# File ~/Documents/polimi/thesis/repos/EKF-SINDy/Data/auxiliar_functions.py:31, in D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0, T)
#      28 def D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=0, T=15):
#      29     print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
#      30     ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed))
# ---> 31     building_blocks_lambda, function_names = run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed, T0=T0, T=T)
#      32     return building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/run_simulation_vi.py:86, in run(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, seed, n_seed, T0, T)
#      83 start = time.time()
#      85 # find the ODE f:
# ---> 86 f_hat, est_gp, building_blocks_lambda, function_names = run_gp_ode(ode_data, X_ph, y_ph, ode, x_id, s)
#      88 # evaluate the functional form:
#      89 f_true = ode.get_expression()[x_id]
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:201, in run_gp_ode(ode_data, X_train, y_train, ode, x_id, seed)
#     197 building_blocks = get_building_blocks(est_gp, ode)
#     199 additional_bb = list(a_add.args) # additional building blocks
# --> 201 building_blocks_lambda, function_names = get_building_blocks_lambda(building_blocks, ode, additional_bb)
#     203 return a, est_gp, building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:255, in get_building_blocks_lambda(building_blocks, ode, additional_bb, idx)
#     253 strings = []
#     254 for bb in building_blocks:
# --> 255     bb_pysym = gp_to_pysym_with_coef_constants(bb, ode, promising=True)
#     256     building_blocks_pysym.append(bb_pysym)
#     257     strings.append(str(bb_pysym))
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:358, in gp_to_pysym_with_coef_constants(est_gp, ode, tol, tol2, expand, promising)
#     355     f_star_sympy = generator.Generator.infix_to_sympy(f_star_infix, VarDict, "simplify")
#     356     return f_star_sympy
# --> 358 f_star_sympy = generator.Generator.infix_to_sympy(f_star_infix2, VarDict, "simplify")
#     360 if expand:
#     361     f_star_sympy = sympy.expand(f_star_sympy)
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/utils/generator.py:558, in Generator.infix_to_sympy(cls, infix, variables, rewrite_functions, no_rewrite)
#     556     raise ImAccomulationBounds
#     557 if expr.has(sp.I) or expr.has(AccumBounds):
# --> 558     raise ValueErrorExpression
#     559 if not no_rewrite:
#     560     expr = cls.rewrite_sympy_expr(expr, rewrite_functions)
#
# ValueErrorExpression:

# %%
#D-CODE series 2:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      1.54632e+16       10          178.822          178.166      7.88m
#    1     8.50      7.07224e+15       17          151.277          152.463      5.21m
#    2     9.74      4.49882e+15       18          124.763          125.445      6.32m
#
# promising programs:
# sub(add(add(sub(cos(pow(X1, 1.564)), mul(X0, X1)), X0), cos(add(cos(X0), X0))), X0)
# sub(add(add(sub(cos(pow(X1, 1.564)), mul(X0, X1)), X0), cos(add(cos(X0), X0))), X0)
# sub(add(add(sub(cos(pow(X1, 1.564)), mul(X0, X1)), X0), cos(add(cos(X0), X0))), X0)
# neg(add(log(0.582), mul(X1, add(X1, log(X0)))))
# sub(cos(pow(X1, 1.564)), mul(X0, X1))
# sub(cos(div(mul(mul(X0, X1), mul(X1, X1)), neg(add(0.317, X1)))), X1)
# sub(cos(div(mul(mul(X0, X1), mul(X1, X1)), neg(add(0.317, X1)))), X1)
# sub(cos(div(mul(mul(X0, X1), mul(X1, X1)), neg(add(0.317, X1)))), X1)
# sub(cos(X1), mul(X1, X0))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X1, X0))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
#
#    3     9.29      6.92296e+10       18          124.802          125.094      4.28m
#    4    11.52      1.05213e+08        9          118.281          118.204      3.71m
#
# promising programs:
# sub(add(add(sub(cos(sub(0.213, X1)), mul(mul(X0, X1), X1)), X0), cos(add(cos(X0), X0))), X0)
# sub(sin(0.780), mul(add(mul(X0, X1), sub(X2, X2)), X1))
# sub(cos(sub(cos(add(sub(cos(pow(X1, 1.564)), mul(X0, X1)), sub(X2, X2))), X1)), mul(X0, X1))
# sub(cos(sub(cos(sub(X1, sin(add(sub(cos(sin(X2)), X1), sin(mul(log(0.816), log(X0))))))), X1)), mul(X0, X1))
# sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1))
# add(neg(mul(X1, add(X1, log(X0)))), cos(pow(X1, X0)))
# sub(cos(sub(cos(neg(mul(X1, add(X1, log(X0))))), X1)), mul(X0, X1))
# sub(cos(sub(cos(neg(sub(cos(mul(X0, X1)), X1))), X1)), mul(X0, X1))
# neg(add(log(0.582), mul(X1, mul(X1, X0))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
# neg(add(log(0.582), mul(X1, mul(X0, X1))))
#
#    5    13.24      2.51641e+09       20          110.193          109.843      3.24m
#    6    12.07      4.43187e+07       11          44.5857          44.8694      2.21m
#    7    12.54      1.03226e+10       23          9.06507          9.01488      1.73m
#    8    14.18      7.48704e+09       23          9.00445          9.56038      1.30m
#    9    16.39       2.5318e+09       21          8.83749          8.96559     44.04s
#
# promising programs:
# add(sub(cos(cos(cos(mul(X0, X1)))), mul(mul(X1, X1), X0)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(X0, cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(X0, cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(X0, cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(neg(log(log(X1)))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
# add(sub(cos(div(sub(pow(X0, 1.511), cos(sub(3.869, X1))), neg(log(log(X1))))), mul(X0, X1)), sin(mul(3.114, X2)))
#
#   10    21.35       2.7244e+09       17          8.37303          8.36508      0.00s
#
# D-CODE model:  -X0*X1**C + sin(C*X2) + cos(cos(cos(X0*X1)))
#
# building blocks:
# cos(X0 + cos(X0))
# X1**1.5635664329268242
# X0*X1
# cos(X1**1.5635664329268242)
# X1*(X1 + log(X0))
# X1**2
# -0.2033746197894023*log(X0)
# log(log(X1))
# X0**1.5108434660726402
# cos(X1 - 3.8685958840055696)
# X1**X0
# cos(X1**X0)
# 3.1140859125414826*X2
# cos(cos(X0*X1))
# cos(cos(cos(X0*X1)))
# -X0*X1**2
# sin(3.1140859125414826*X2)
#
# number of building blocks:  17
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [2.33761972 2.20663286 2.03468758 1.83731175 1.62093645 1.39054147
#  1.15584966 0.93121655 0.73044156 0.56163325 0.42605283 0.32065966
#  0.24128169 0.18403423 0.14513293 0.12065073 0.10707052 0.1021016
#  0.10485464 0.11522456]
# [1.14061167 1.25849889 1.38557153 1.52567747 1.67606748 1.82792663
#  1.96916034 2.08786165 2.1750891  2.22637567 2.2420097  2.22630814
#  2.18612231 2.12897942 2.06147464 1.98846692 1.91319974 1.83795358
#  1.76462708 1.69486665]
# [5.00040622 5.06312791 5.10170825 5.1443415  5.19646318 5.25143129
#  5.30302841 5.35100742 5.39879155 5.44872515 5.50018511 5.55128405
#  5.60123342 5.65076967 5.70082299 5.75136315 5.80162881 5.8511668
#  5.90037582 5.95004226]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      9.31205e+15        7          417.376          411.077      5.54m
#    1     6.68      6.75363e+15       13          375.765            371.6      5.46m
#    2     6.39      4.34504e+09       13          374.577          382.296      4.46m
#
# promising programs:
# mul(sub(add(div(mul(X0, X1), div(1.130, X0)), sub(cos(X1), mul(X1, X0))), X1), mul(X0, X0))
# add(mul(sin(neg(pow(X0, 2.152))), pow(X1, 3.071)), pow(X0, 1.028))
# add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), sub(neg(X1), neg(X0)))
# mul(add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028)), X0)
# add(div(mul(X0, X1), div(1.130, sub(X0, cos(add(X0, log(cos(X2))))))), sub(sub(1.436, X1), mul(X1, X0)))
# div(sub(sub(pow(X0, X0), cos(sub(mul(X2, X1), cos(sub(sub(X0, X1), X1))))), X1), div(X0, X0))
# add(div(sub(pow(X0, 2.018), X1), div(1.130, X0)), sub(cos(X1), mul(X1, X0)))
# add(div(sub(pow(X0, 2.020), X1), div(1.130, X0)), sub(cos(X1), mul(X1, X0)))
# mul(X0, mul(add(X0, X1), sin(sub(X0, X1))))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028))
# add(div(mul(X0, X1), div(1.130, X0)), sub(add(sub(sin(log(cos(X2))), X1), cos(sin(X0))), mul(X1, X0)))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, 1.028))
#
#    3     7.84      2.59779e+15       20          329.454          324.257      3.83m
#    4     9.12      2.06401e+09       13          314.824           330.46      3.77m
#
# promising programs:
# add(div(mul(sub(sub(X0, X1), cos(1.375)), mul(mul(X1, X0), X0)), div(1.130, X0)), sub(cos(X1), mul(X1, X0)))
# add(sub(pow(X0, 2.364), mul(X1, X0)), sub(mul(cos(sub(log(2.162), mul(X2, X2))), X2), mul(X1, X0)))
# mul(add(div(mul(sub(X0, X1), mul(X0, X1)), div(1.130, X0)), sub(cos(X1), mul(X1, X0))), X0)
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, pow(X0, 1.028)))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, X0))
# add(mul(sin(neg(pow(X0, 1.112))), pow(X1, 3.071)), pow(X0, mul(X1, X0)))
# add(div(mul(X0, X1), div(1.130, sub(pow(X0, 2.364), mul(X1, mul(X1, X0))))), sub(sin(log(cos(X2))), mul(X1, X0)))
# add(mul(sin(neg(pow(X0, 2.246))), pow(X1, 3.071)), mul(sub(X0, X1), mul(mul(X1, X0), X0)))
# mul(add(mul(sin(neg(mul(X0, X0))), pow(X1, 3.071)), pow(X0, 1.028)), X0)
# mul(sub(sin(div(sub(3.698, X1), cos(X2))), sub(X1, X0)), add(mul(X1, X0), mul(X1, X0)))
#
#    5    10.34      2.59499e+07       23          274.025          279.867      3.03m
#    6    12.91      9.85138e+06       13          237.397          231.782      2.93m
#    7    15.77      1.38646e+13       13          236.154          242.973      2.23m
#    8    17.82       2.3628e+09       36          207.569          208.367      1.54m
#    9    19.90      1.17641e+11       27          162.909          162.854     49.48s
#
# promising programs:
# add(div(add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), sub(sin(div(2.364, cos(X2))), sub(X1, X0))), div(1.130, X0)), sub(div(mul(2.051, X0), X2), mul(X1, X0)))
# mul(add(add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), sub(X0, X1)), sub(sin(div(2.364, cos(X2))), mul(X1, X0))), pow(X0, 0.923))
# mul(add(add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), sub(X0, X1)), sub(sin(div(2.364, cos(X2))), mul(X1, X0))), pow(X0, 0.923))
# add(div(mul(sub(sub(sin(div(2.364, cos(X2))), sub(X1, X0)), cos(1.375)), mul(mul(X1, X0), X0)), div(1.130, X0)), sub(cos(X1), mul(X1, X0)))
# add(div(mul(X0, X1), div(1.130, sub(pow(X0, X0), X1))), sub(add(sub(sub(cos(X2), log(pow(X1, 3.391))), mul(mul(sin(X0), cos(3.741)), neg(X0))), cos(sub(sin(div(sub(3.698, X1), cos(X2))), log(mul(sin(neg(pow(X0, 1.112))), sub(X0, X0)))))), mul(X1, X0)))
# add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), mul(sub(sin(div(2.364, cos(X2))), sub(X1, X0)), mul(X0, X0)))
# add(div(mul(X0, X1), div(1.130, add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), mul(X0, sin(sub(sin(div(sub(3.698, X1), cos(X2))), sub(X1, X0))))))), sub(sin(log(cos(X2))), mul(X1, X0)))
# add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), mul(sub(sin(div(sub(3.698, 1.112), cos(X2))), sub(X1, X0)), mul(1.530, X0)))
# add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), mul(sub(sin(div(sub(3.698, 1.112), cos(X2))), sub(X1, X0)), mul(1.530, X0)))
# mul(sub(sin(div(2.364, cos(X2))), sub(X1, X0)), pow(X0, X0))
# mul(sub(sin(div(2.364, cos(X2))), sub(X1, X0)), pow(X0, X0))
# mul(add(add(mul(cos(sub(log(2.162), mul(X2, X2))), X2), 1.112), sub(sin(div(2.364, cos(X2))), mul(X1, X0))), pow(X0, 0.923))
# add(mul(mul(cos(sub(log(div(sin(sin(add(X2, X1))), sub(sin(div(X2, X2)), sin(div(X2, X2))))), mul(X2, X2))), X2), X0), mul(sub(sin(div(sub(3.698, X1), cos(X2))), sub(X1, X0)), X0))
# add(sin(div(sub(3.698, X1), cos(X2))), mul(add(mul(sin(neg(pow(X0, 2.152))), pow(X1, 3.071)), mul(cos(sub(log(X1), mul(X2, X2))), X2)), pow(X0, 0.923)))
# mul(sub(mul(sub(sin(div(sub(3.698, X1), cos(X2))), sub(X1, X0)), mul(X0, X1)), cos(sub(mul(X2, X1), sub(X0, pow(X2, 1.065))))), mul(X0, X1))
#
#   10    23.09      1.65773e+08       33          141.232          142.692      0.00s
#
# D-CODE model:  C*X0*(X0 - X1 + X2*cos(C - X2**C) + sin(C/cos(X2))) + C*X0/X2 - X0*X1
#
# building blocks:
# X0*X1
# X0**2
# 1.1302992685001312/X0
# X1**3.071497806014158
# -sin(X0**2.1520917734478195)
# X0**1.0281444646904045
# X2**2
# -sin(X0**1.1120045337933466)
# X0**1.1120045337933466
# cos(X0 + log(cos(X2)))
# 1
# X0**X0
# sin(X0 - X1)
# log(cos(X2))
# X0**(X0**1.0281444646904045)
# -sin(X0**2)
# (3.6982474648119754 - X1)/cos(X2)
# sin(2.3642157816344285/cos(X2))
# 2.051399280547932*X0/X2
# 2.051399280547932*X0
# X0**0.9228676183999879
# 2.3642157816344285/cos(X2)
# 2.5862429310186288/cos(X2)
# 1.530126672964233*X0
# sin(sin(X1 + X2))
# X2**1.064998572878302
# X1*X2
# 0.88472144313334476*X0*(X0 - X1 + X2*cos(X2**2 - 0.77090911714636241) + sin(2.3642157816344285/cos(X2)))
#
# number of building blocks:  28
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.12618013 1.1563143  1.1864209  1.22415442 1.27157488 1.32677478
#  1.38657322 1.44853656 1.51160497 1.57562137 1.64045604 1.70531968
#  1.76860439 1.8282921  1.88261827 1.93047884 1.97129014 2.00453653
#  2.02953575 2.04565985]
# [0.46316475 0.4611573  0.45653788 0.45191938 0.44785587 0.44418405
#  0.4411593  0.4395103  0.43969522 0.44136021 0.44364867 0.44604587
#  0.44888846 0.45304432 0.45911341 0.46692721 0.47575824 0.484948
#  0.49434287 0.50422376]
# [ 9.99709453 10.08027149 10.10830927 10.1417367  10.19429914 10.25374301
#  10.30723699 10.35340051 10.39851865 10.4473497  10.49913833 10.5505608
#  10.60010389 10.64896441 10.69880135 10.74980203 10.80099728 10.85167412
#  10.90191888 10.95199278]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      1.04534e+16       18          350.912          348.641      6.20m
#    1     7.70      3.94552e+14        5          285.871          285.961      5.50m
#    2     8.30      1.97078e+08       11          265.526          266.027      5.37m
#
# promising programs:
# sub(add(sin(cos(mul(3.065, X2))), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# add(cos(mul(3.065, X2)), cos(add(X1, X1)))
# add(add(neg(X1), cos(X1)), cos(mul(3.065, X2)))
# sub(cos(mul(3.065, X2)), sin(X2))
# add(sin(cos(mul(3.065, X2))), sub(mul(div(X0, X0), sin(3.137)), cos(div(1.416, X1))))
# add(neg(log(X1)), sin(cos(mul(3.065, X2))))
# sub(sin(cos(mul(3.065, X2))), log(X1))
# neg(sub(log(X1), sin(cos(mul(3.065, X2)))))
# sub(sub(sin(add(cos(mul(3.065, X2)), mul(X1, X1))), log(pow(X1, 1.152))), X1)
# sub(cos(mul(3.065, X2)), pow(X1, 1.796))
# sub(sin(cos(mul(3.065, X2))), pow(X1, 1.461))
# sub(cos(mul(3.065, X2)), X1)
# sub(cos(mul(3.065, X2)), X1)
# sub(cos(mul(3.065, X2)), X1)
# add(cos(mul(3.065, X2)), neg(X1))
#
#    3    10.74      1.66919e+15       32          198.126           199.02      5.36m
#    4    14.99      1.87766e+09       31          186.781          188.383      4.89m
#
# promising programs:
# sub(add(cos(mul(3.065, X2)), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(3.559, X0))))))
# sub(add(cos(mul(3.065, X2)), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(cos(mul(3.065, X2)), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(sin(div(sub(cos(mul(3.065, X2)), div(add(pow(X1, 3.009), add(mul(X2, X0), mul(1.490, X1))), pow(X2, 0.299))), sin(sin(1.334)))), cos(sub(sin(2.517), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(sin(cos(mul(3.065, X2))), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(div(cos(X2), sub(add(cos(div(0.649, log(X1))), sin(log(cos(X2)))), cos(log(add(cos(X1), X0)))))))))
# sub(add(sin(cos(mul(3.065, X2))), cos(sub(sin(2.517), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(cos(mul(3.065, X2)), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(cos(X1))))))
# sub(add(sin(cos(mul(3.065, X2))), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(sin(cos(mul(3.065, X2))), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), mul(neg(neg(sin(sin(X2)))), sin(cos(sin(sub(X0, X1))))))
# sub(add(sin(div(cos(mul(3.065, X2)), sin(sin(1.334)))), cos(sub(neg(div(0.481, X2)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(cos(neg(add(X1, X1)))), sin(sin(sin(sub(X0, sin(X1)))))))
# add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0))))
# sub(add(sin(div(sub(cos(mul(3.065, X2)), log(X1)), sin(sin(1.334)))), cos(sub(sin(2.517), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(sin(div(sub(cos(mul(3.065, X2)), log(X1)), sin(sin(1.334)))), cos(sub(sin(2.517), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(sin(div(sub(cos(mul(3.065, X2)), log(X1)), sin(sin(1.334)))), cos(sub(sin(2.517), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
# sub(add(cos(mul(3.065, X2)), cos(sub(neg(pow(X1, 2.557)), mul(mul(X1, X2), mul(2.360, X0))))), add(neg(neg(sin(sin(X2)))), sin(sin(sin(sub(X0, X1))))))
#
#    5    15.87       3.2776e+09       31          184.777          184.219      4.67m
#    6    12.15      4.17019e+14       31          184.744          184.518      3.18m
#    7    17.03      5.19046e+09       29          182.363          182.747      2.28m
#    8    24.86      1.05886e+10       36          177.377          176.798      1.70m
#    9    34.83      9.84289e+09       45          159.182          157.649      1.14m
#
# promising programs:
# sub(sub(sub(sub(cos(mul(3.065, X2)), div(add(pow(X1, 3.009), add(sin(X2), neg(mul(3.065, X2)))), pow(X2, 0.299))), div(log(X0), cos(sin(sin(pow(X0, 1.005)))))), log(X1)), X1)
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(mul(2.360, X0)))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), pow(X1, 3.082)))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(X1)))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X1), sin(X1)))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(sub(X0, X1))))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(div(sub(cos(mul(3.065, X2)), div(cos(mul(3.065, X2)), pow(X2, 0.299))), sin(sin(1.334))))))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sub(X0, X1), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(X1)))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(X1)))))))))))
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(div(sin(1.322), div(X2, X0)), cos(cos(sub(add(sin(cos(mul(3.065, X2))), cos(sub(div(3.699, X2), mul(mul(X1, X2), mul(2.360, X0))))), add(sin(sin(X2)), sin(sin(sin(sub(X0, X1)))))))))))))))
# add(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299)), add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))))
# sub(add(mul(0.785, add(sub(sub(cos(mul(3.065, X2)), X0), log(X1)), cos(sin(cos(sin(neg(neg(sin(sin(X2)))))))))), div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), add(add(log(0.582), mul(X1, X1)), sin(sin(sin(sub(X0, X1))))))
# sub(sub(sub(sub(cos(mul(3.065, X2)), div(add(pow(X1, 3.009), add(mul(X2, X0), neg(mul(3.065, X2)))), pow(X2, 0.299))), div(log(X0), cos(sin(sin(add(X1, X1)))))), log(X1)), X1)
# sub(add(cos(mul(3.065, X2)), cos(mul(add(X1, X1), neg(X0)))), add(neg(div(add(pow(X1, 3.009), mul(3.065, X2)), pow(X2, 0.299))), sin(sin(cos(cos(mul(sub(sin(1.322), div(X2, X0)), cos(cos(sub(mul(X2, X2), sin(X1)))))))))))
# sub(sub(sub(sub(cos(mul(3.065, X2)), div(add(pow(X1, 3.009), add(mul(X2, X0), neg(mul(3.065, X2)))), pow(X2, 0.299))), div(log(X0), cos(sin(sin(pow(X2, 1.005)))))), log(X1)), X1)
#
#   10    42.05      6.11357e+14       35          158.412          159.033      0.00s
#
# D-CODE model:  -X1 - log(X0)/cos(sin(sin(X0**C))) - log(X1) + cos(C*X2) - X2**(-C)*(-C*X2 + X1**C + sin(X2))
#
# building blocks:
# 3.065315558341902*X2
# sin(cos(3.065315558341902*X2))
# sin(sin(X2))
# sin(sin(X0 - X1))
# cos(3.065315558341902*X2)
# cos(2*X1)
# cos(1.4158286053732407/X1)
# 1
# 1.4158286053732407/X1
# X1**1.152030725663237
# X1**2
# X1**1.796369535939418
# X1**1.4613640666749521
# -sin(X0 - 3.55945766776585)
# 0.4808145052562989/X2
# X1*X2
# 2.3601209986886436*X0
# X2**0.29865755493299573
# 0.82603560499185983
# sin(sin(cos(X1)))
# sin(cos(sin(X0 - X1)))
# X0**1.0050651016953445
# cos(sin(sin(X0**1.0050651016953445)))
# X1**3.0087642011251994
# X2/X0
# X2**2
# -2*X0*X1
# 0.9691668197854114*X0/X2
# sin(2*X1)
# cos(sin(sin(X2**1.0050651016953445)))
# -X1
# -log(X1)
# -X2**(-0.29865755493299573)*(X1**3.0087642011251994 - 3.065315558341902*X2 + sin(X2))
# -log(X0)/cos(sin(sin(X0**1.0050651016953445)))
#
# number of building blocks:  34
#
# T0: 15, T: 30
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.05800508 1.05470963 1.03674209 1.01133535 0.98205567 0.94977985
#  0.91437937 0.87592543 0.83512402 0.79329375 0.75216452 0.71354103
#  0.67890345 0.64919751 0.62499372 0.60683831 0.59540754 0.59131565
#  0.594851   0.60599851]
# [0.86098146 0.86178728 0.86131893 0.8621175  0.86285643 0.86136984
#  0.85685661 0.8500116  0.84182186 0.83259188 0.82198915 0.80966988
#  0.79565199 0.78017679 0.76345312 0.74568061 0.72727446 0.70892551
#  0.69133509 0.67485381]
# [14.99457149 15.09300328 15.11024126 15.13616715 15.19021995 15.25385449
#  15.3087389  15.35375598 15.39830643 15.44854936 15.50240521 15.55483018
#  15.60421351 15.65277039 15.70253542 15.75289771 15.80214403 15.85013467
#  15.89853687 15.94870518]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12       3.3276e+16       18          102.572          101.875      5.94m
#    1    10.27      4.69522e+12       26          92.6521          92.6758      5.86m
#    2    10.91      2.07149e+09       12          46.7509          46.7128      4.94m
#
# promising programs:
# mul(sin(add(mul(3.114, X2), X1)), cos(cos(cos(mul(X0, X2)))))
# cos(sub(neg(pow(X1, 1.620)), mul(3.062, X2)))
# sub(cos(sub(neg(sub(sub(0.847, X1), cos(mul(mul(X1, 1.186), add(X1, X0))))), mul(3.062, X2))), mul(sub(cos(X1), add(0.693, X2)), sub(X0, X0)))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), div(sub(cos(X1), X1), div(add(pow(X0, 0.839), neg(add(0.516, X2))), log(mul(pow(X0, 3.956), log(X2))))))
# mul(sin(add(mul(3.114, X2), X1)), cos(mul(X0, X1)))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), div(cos(sub(sub(div(X2, X2), sub(div(cos(X2), cos(X2)), pow(X1, 0.063))), neg(cos(X2)))), div(add(pow(X0, 0.839), neg(add(0.516, X2))), log(mul(pow(X0, 3.956), log(X2))))))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), div(cos(sub(neg(X1), neg(cos(X2)))), div(add(pow(X0, 0.839), neg(add(0.516, X2))), log(mul(pow(X0, 3.956), log(X2))))))
# sub(cos(sub(neg(sub(sin(sub(cos(X1), X1)), neg(X1))), mul(3.062, X2))), mul(sub(cos(X1), add(0.693, X2)), sub(X0, X0)))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), div(cos(sub(sub(div(X2, X2), add(X2, X2)), neg(cos(X2)))), div(add(pow(X0, 0.839), neg(add(0.516, X2))), neg(cos(pow(X2, 0.560))))))
# cos(sub(neg(cos(add(sin(sin(neg(X1))), sub(X2, X2)))), mul(3.062, X2)))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), div(cos(sub(sub(div(X2, X2), add(X2, X2)), neg(cos(X1)))), div(add(pow(X0, 0.839), neg(add(0.516, X2))), log(mul(pow(X0, 3.956), log(X2))))))
# cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2)))
# cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2)))
# cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2)))
# sub(cos(sub(neg(sub(sub(0.847, X1), neg(X1))), mul(3.062, X2))), mul(add(X1, X2), sub(X0, X0)))
#
#    3    11.52      1.84824e+10       13          31.8757          31.9124      5.33m
#    4    11.84      3.46266e+07        9           17.223          17.2641      5.18m
#
# promising programs:
# cos(sub(mul(sin(add(mul(3.114, X2), X1)), X1), add(pow(X0, 0.699), sin(div(1.809, X1)))))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# sin(add(mul(3.114, X2), X1))
# mul(sin(add(mul(3.114, X2), X1)), cos(sub(X1, X1)))
#
#    5    17.55      4.99509e+07       18          17.2274          17.4206      4.59m
#    6    26.96      8.15472e+07       25          13.8771          13.8927      4.26m
#    7    24.37      7.55667e+09       16          10.5731          10.5593      3.04m
#    8    21.07      4.94803e+07       44          9.77264          9.83002      1.73m
#    9    15.57      7.14274e+07       47          8.29665          8.30903     45.37s
#
# promising programs:
# sub(sin(add(mul(3.114, X2), X1)), div(cos(add(X1, mul(X0, X1))), div(neg(div(cos(cos(X2)), mul(sub(X0, X0), mul(X2, X2)))), cos(sin(add(mul(3.114, X2), X1))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), neg(add(X1, X0))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sin(add(mul(3.114, X2), X1))), neg(add(0.516, X2))), log(mul(pow(X2, X1), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(sin(add(mul(3.114, X2), X1)), neg(add(0.516, X2))), log(mul(pow(X0, neg(add(0.516, X2))), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(sub(sub(0.847, X1), cos(add(X1, neg(neg(X1))))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(pow(add(mul(3.114, X2), X1), 3.956), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(mul(X1, 1.186), add(X1, X0))), div(add(cos(sub(sub(sin(add(mul(3.114, X2), X1)), div(sub(cos(X1), X1), div(add(pow(X0, 0.839), neg(add(0.516, X2))), cos(pow(X0, 1.904))))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(pow(mul(3.114, X2), 3.956), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(neg(sub(sub(0.847, X1), cos(pow(X1, neg(div(X0, neg(cos(1.190)))))))), add(pow(X0, 0.839), neg(add(0.516, X2))))), neg(add(0.516, X2))), log(mul(pow(X2, 3.956), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(neg(sub(sub(0.847, X1), sin(add(mul(3.114, X2), X1)))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(pow(log(neg(X0)), 3.956), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(neg(sub(sub(0.847, X1), cos(add(X1, neg(neg(X1)))))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(mul(X2, X2), log(X2))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(sub(pow(X1, 1.164), neg(mul(X0, X1)))), div(add(pow(X0, 0.839), neg(neg(X0))), cos(log(div(X2, cos(X1)))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(mul(neg(sub(mul(0.847, X1), cos(sub(X1, neg(neg(X1)))))), mul(3.062, X2))), neg(add(0.516, X2))), log(add(pow(3.114, X2), X1)))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(neg(sub(sub(0.847, X1), sin(add(mul(3.114, X2), X1)))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(pow(X0, 3.956), pow(X2, 0.774))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(neg(sub(sub(0.847, X1), cos(add(X1, neg(neg(X1)))))), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(add(3.920, X1), add(mul(3.114, X2), X1))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(add(X1, mul(X0, X1))), div(add(X2, neg(add(0.516, X2))), cos(log(neg(X0))))))
# sub(sin(add(mul(3.114, X2), X1)), div(cos(mul(pow(X1, 1.186), add(X1, X0))), div(add(cos(sub(sub(add(mul(3.114, X2), X1), mul(X1, X1)), mul(3.062, X2))), neg(add(0.516, X2))), log(mul(add(mul(3.114, X2), X1), log(X2))))))
#
#   10    25.79      2.23172e+10       34          5.22424          5.26032      0.00s
#
# D-CODE model:  sin(C*X2 + X1)
#
# building blocks:
# cos(X0*X2)
# X0*X2
# 3.1140859125414826*X2
# cos(cos(X0*X2))
# cos(cos(cos(X0*X2)))
# X1**1.6200283031175302
# 3.062253023401464*X2
# sin(X1 + 3.1140859125414826*X2)
# X0**0.8388361438953286
# X0**3.956014108276609
# -sin(X1 - cos(X1))
# X2**0.5600016319418131
# -sin(X1)
# X0**0.6987502342479326
# 1.8086116229025466/X1
# sin(1.8086116229025466/X1)
# X1**1.186116455672333
# X0**(-X2 - 0.5158904257309707)
# 1.186116455672333*X1
# cos(2*X1)
# log(X2/cos(X1))
# cos(log(X2/cos(X1)))
# 3.1140859125414826**X2
# 0.8470328358218749*X1
# cos(log(-X0))
# X1 + 3.1140859125414826*X2
#
# number of building blocks:  26
#
# T0: 20, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.8847791  0.88934426 0.89307867 0.90373045 0.92330836 0.9497428
#  0.97991463 1.01181917 1.04479584 1.07842559 1.11151931 1.14211658
#  1.16826829 1.1886972  1.20273356 1.20975153 1.20880233 1.19883965
#  1.17927357 1.15029467]
# [0.96307461 0.96140043 0.95555174 0.95192465 0.95154928 0.95264399
#  0.95379907 0.95544899 0.95912152 0.96581617 0.97523251 0.986389
#  0.99876102 1.01274785 1.02915277 1.04836445 1.07004414 1.09341339
#  1.11762889 1.14186241]
# [19.99450487 20.10729364 20.11116891 20.12809312 20.18434507 20.25405222
#  20.31134607 20.35422583 20.39584492 20.4453447  20.50021923 20.55319836
#  20.6015589  20.64848922 20.69769519 20.74915377 20.80028674 20.84968066
#  20.89847202 20.94841881]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12       1.3816e+16        6          248.048          247.968      6.00m
#    1     6.12      8.77971e+09       30          231.155          229.506      5.15m
#    2     7.32      6.19855e+09       30           230.97          231.166      4.43m
#
# promising programs:
# sin(mul(3.127, X2))
# mul(sin(add(sin(sub(pow(X0, 2.374), X1)), add(log(log(X1)), pow(X1, X1)))), mul(X0, X0))
# add(sub(cos(pow(X1, 2.991)), cos(mul(sub(X0, X1), cos(div(X0, X0))))), div(sin(pow(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0)))))
# mul(pow(X1, 1.116), add(sub(cos(log(mul(X1, X1))), cos(mul(add(neg(X1), pow(X0, 1.928)), cos(0.588)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(cos(pow(X2, 2.991)), cos(mul(sin(X1), sub(neg(cos(X2)), log(pow(X1, 3.942)))))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(cos(sub(X0, X1)), cos(mul(sin(X1), sub(pow(X0, 2.962), X1)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# sub(cos(sub(log(log(X1)), X1)), cos(sub(mul(pow(X0, 3.321), log(X0)), X1)))
# mul(pow(X1, 1.116), add(sub(cos(sub(X0, X1)), cos(sub(pow(X0, X0), pow(X1, 2.597)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# sub(pow(X0, sub(X0, sin(pow(X0, 2.837)))), add(mul(sin(0.750), sin(log(X0))), mul(X1, X1)))
# mul(pow(X1, 1.116), add(sub(cos(pow(X2, 2.991)), cos(mul(sin(X1), add(pow(X0, 3.080), neg(X0))))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# sub(pow(X0, add(sub(pow(X0, 2.140), X1), mul(X1, X1))), X1)
# mul(pow(X1, 1.116), add(sub(div(mul(X0, X0), sub(2.809, X0)), cos(mul(sin(X1), cos(0.588)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(cos(pow(X2, 2.991)), cos(mul(mul(X0, X0), cos(0.588)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(cos(sub(X0, X1)), cos(sub(X0, X1))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(cos(pow(X2, 2.991)), cos(mul(sin(X1), pow(X0, 2.590)))), div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))
#
#    3     9.46       2.5433e+09        4          193.491          193.935      6.28m
#    4    11.53      1.13107e+10        4          193.109           197.37      4.26m
#
# promising programs:
# add(sub(cos(pow(X2, 2.991)), cos(mul(sin(div(X2, X0)), cos(0.588)))), div(sin(add(sin(mul(pow(X0, pow(X0, 2.118)), neg(0.588))), add(log(log(X1)), pow(X1, 1.131)))), neg(cos(add(2.752, X0)))))
# add(sub(cos(add(sin(neg(pow(X0, 0.231))), log(neg(sin(add(1.334, X2)))))), cos(cos(X2))), div(sin(pow(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0)))))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
# sin(mul(3.127, X2))
#
#    5    16.28      2.42262e+09       38           183.42          183.851      4.72m
#    6    23.76       4.0841e+09       23          140.918          143.431      5.89m
#    7    30.36      1.94815e+10       43          110.242          107.754      4.15m
#    8    31.67      2.73149e+09       17          101.354          100.861      2.57m
#    9    28.52      2.50316e+09       43          96.5654          95.0974      1.09m
#
# promising programs:
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(mul(add(log(X0), sub(div(sub(0.327, X0), neg(X1)), cos(sin(X0)))), cos(sub(neg(X0), cos(0.588)))))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# add(add(add(sin(add(log(sub(cos(neg(cos(add(2.752, X0)))), cos(mul(pow(X0, log(3.433)), log(X0))))), add(X1, X1))), log(div(1.163, X1))), sin(mul(3.127, X2))), cos(add(pow(X0, 3.210), pow(X2, 2.145))))
# mul(pow(X1, 1.116), add(sub(pow(X0, neg(cos(add(2.752, X0)))), cos(mul(add(log(X0), sub(div(sub(0.327, X0), neg(X1)), cos(sin(X0)))), cos(0.588)))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# add(mul(log(X0), pow(X0, 3.651)), sin(add(sub(sin(pow(X2, 2.991)), cos(sub(pow(X0, X0), div(X1, 2.597)))), div(sin(add(mul(3.127, X2), pow(X1, 2.715))), neg(cos(add(2.752, X0)))))))
# add(sub(sin(add(sin(mul(3.127, X2)), pow(X1, 2.715))), cos(mul(sin(div(X2, X0)), cos(0.588)))), div(sin(add(sin(mul(pow(X0, pow(X0, 2.118)), neg(0.588))), add(log(log(X1)), pow(X1, 1.131)))), neg(cos(add(2.752, X0)))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(mul(add(mul(pow(X1, cos(pow(sub(neg(cos(add(2.752, X0))), div(mul(add(X0, X2), sin(X0)), pow(X2, 3.757))), 2.991))), div(cos(neg(mul(log(0.984), neg(2.911)))), cos(mul(sin(div(3.434, X0)), div(add(X1, X2), mul(X2, X2)))))), sub(div(sub(0.327, X0), neg(X1)), cos(sin(X0)))), cos(0.588)))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(cos(X1))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(mul(add(mul(pow(X1, cos(pow(sub(neg(cos(add(2.752, X0))), div(mul(add(X0, X2), sin(X0)), pow(X2, 3.757))), 2.991))), log(X1)), sub(div(sub(0.327, X0), neg(X1)), cos(sin(X0)))), cos(0.588)))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(mul(mul(add(sin(mul(3.127, X2)), neg(pow(X0, 1.890))), cos(div(X0, X0))), neg(X0)))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# add(add(add(sin(add(log(sub(cos(neg(cos(add(2.752, X0)))), cos(mul(pow(X0, 1.849), log(X0))))), add(X1, X1))), log(div(1.163, X1))), sin(mul(3.127, X2))), cos(add(pow(X0, 3.210), pow(X2, 2.145))))
# add(add(add(sin(add(log(sub(cos(neg(cos(add(2.752, X0)))), cos(mul(pow(X0, 1.849), log(X0))))), add(X1, X1))), log(div(1.163, X1))), sin(mul(3.127, X2))), cos(add(pow(X0, 3.210), pow(X2, 2.145))))
# add(add(add(sin(add(log(sub(cos(neg(cos(add(2.752, X0)))), cos(mul(pow(X0, 1.849), log(X0))))), add(X1, X1))), log(div(1.163, X1))), sin(mul(3.127, X2))), cos(add(pow(X0, 3.210), pow(X2, 2.145))))
# add(add(add(sin(add(log(sub(cos(neg(cos(add(2.752, X0)))), cos(mul(pow(X0, 1.849), log(X0))))), add(X1, X1))), log(div(1.163, X1))), sin(mul(3.127, X2))), cos(add(pow(X0, 3.210), pow(X2, 2.145))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(mul(add(log(X0), sub(div(sub(0.327, X0), neg(X1)), cos(sin(X0)))), cos(sub(neg(X0), pow(X0, 0.908)))))), div(sin(add(mul(3.127, X2), cos(mul(log(X0), pow(X0, 3.651))))), neg(cos(add(2.752, X0))))))
# mul(pow(X1, 1.116), add(sub(pow(X0, sub(cos(pow(X2, 2.991)), cos(log(sub(X0, X0))))), cos(log(add(0.991, X0)))), div(sin(add(mul(3.127, X2), cos(div(sin(add(add(X1, X1), pow(X1, 2.715))), neg(cos(add(2.752, X0))))))), neg(cos(add(2.752, X0))))))
#
#   10    32.61      1.92112e+10       57          91.2403          81.6306      0.00s
#
# D-CODE model:  nan
#
# building blocks:
# 3.1265126922881095*X2
# sin(3.1265126922881095*X2)
# X0**2
# log(log(X1))
# sin(X0**2.3740978894149785 - X1)
# X1**X1
# X1**2.7150192936636808
# 1
# cos(X0 + 2.751675890914975)
# log(X1**2)
# X1**2
# log(X1**3.942071454065563)
# X1**1.115988593556729
# cos(X1 - log(log(X1)))
# X0**X0
# 0.6815885503775563*sin(log(X0))
# X0**2.1401865735985512
# cos(X0 - X1)
# X0**(X0**2.118154666949073)
# X2/X0
# X0**0.23069079148528163
# (X0 - 0.326802468622504)/X1
# cos(X0 + 0.8318737023420924)
# sin(3.4340696574879286/X0)
# cos(cos(X1))
# zoo
# nan
# 1.1633520810987625/X1
# cos(cos(X0 + 2.751675890914975))
# log(1.1633520810987625/X1)
# X0**1.8488420456879229*log(X0)
# X0**1.8488420456879229
# X2**2.145221700994967
# X0**0.9080293350079928
#
# number of building blocks:  34
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 17
#      15 for T0, T in zip(T0s, Ts):
#      16     print(f'T0: {T0}, T: {T}')
# ---> 17     D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
#
# File ~/Documents/polimi/thesis/repos/EKF-SINDy/Data/auxiliar_functions.py:31, in D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0, T)
#      28 def D_CODE_simulation(ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=0, T=15):
#      29     print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, seed={}, n_seed={}".format(
#      30     ode_name, param, x_id, freq, n_sample, noise_sigma, seed, n_seed))
# ---> 31     building_blocks_lambda, function_names = run_DCODE(ode_name, param, x_id, freq, n_sample, noise_sigma, seed=seed, n_seed=n_seed, T0=T0, T=T)
#      32     return building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/run_simulation_vi.py:87, in run(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, seed, n_seed, T0, T)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:201, in run_gp_ode(ode_data, X_train, y_train, ode, x_id, seed)
#     197 building_blocks = get_building_blocks(est_gp, ode)
#     199 additional_bb = list(a_add.args) # additional building blocks
# --> 201 building_blocks_lambda, function_names = get_building_blocks_lambda(building_blocks, ode, additional_bb)
#     203 return a, est_gp, building_blocks_lambda, function_names
#
# File ~/Documents/polimi/thesis/repos/D-CODE/D_CODE/gp_utils.py:311, in get_building_blocks_lambda(building_blocks, ode, additional_bb, idx)
#     309 X0, X1, X2 = sp.symbols('X0 X1 X2')
#     310 for bb in building_blocks_pysym:
# --> 311     bb_lambda = sp.lambdify((X0, X1, X2), bb, modules='numpy')
#     312     building_blocks_lambda.append(bb_lambda)
#     313 function_names=[lambda X0, X1, X2, i=i: building_blocks_str[i] for i in range(len(building_blocks_str))]
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/utilities/lambdify.py:848, in lambdify(args, expr, modules, printer, use_imps, dummify)
#     846 else:
#     847     funcprinter = _EvaluatorPrinter(printer, dummify)
# --> 848 funcstr = funcprinter.doprint(funcname, args, expr)
#     850 # Collect the module imports from the code printers.
#     851 imp_mod_lines = []
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1091, in _EvaluatorPrinter.doprint(self, funcname, args, expr)
#    1087 funcbody.extend(self._print_funcargwrapping(funcargs))
#    1089 funcbody.extend(unpackings)
# -> 1091 funcbody.append('return ({})'.format(self._exprrepr(expr)))
#    1093 funclines = [funcsig]
#    1094 funclines.extend('    ' + line for line in funcbody)
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/printing/codeprinter.py:110, in CodePrinter.doprint(self, expr, assign_to)
#     107 self._not_supported = set()
#     108 self._number_symbols = set()  # type: Set[Tuple[Expr, Float]]
# --> 110 lines = self._print(expr).splitlines()
#     112 # format the output
#     113 if self._settings["human"]:
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/printing/printer.py:329, in Printer._print(self, expr, **kwargs)
#     327     printmethod = '_print_' + cls.__name__
#     328     if hasattr(self, printmethod):
# --> 329         return getattr(self, printmethod)(expr, **kwargs)
#     330 # Unknown object, fall back to the emptyPrinter.
#     331 return self.emptyPrinter(expr)
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/printing/pycode.py:233, in AbstractPythonCodePrinter._print_ComplexInfinity(self, expr)
#     232 def _print_ComplexInfinity(self, expr):
# --> 233     return self._print_NaN(expr)
#
# File ~/miniconda3/envs/smart_SINDy/lib/python3.12/site-packages/sympy/printing/pycode.py:72, in _print_known_const(self, expr)
#      71 def _print_known_const(self, expr):
# ---> 72     known = self.known_constants[expr.__class__.__name__]
#      73     return self._module_format(known)
#
# KeyError: 'ComplexInfinity'

# %%
# D-CODE series 1:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [0, 5, 10, 15, 20]
Ts = [15, 20, 25, 30, 35]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 0, T: 15
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.17397889 0.23169947 0.29757568 0.36922221 0.44508813 0.52467356
#  0.60782464 0.69377684 0.78081143 0.86680268 0.95010732 1.02996796
#  1.10611263 1.17800407 1.24447684 1.30408023 1.35578057 1.39938847
#  1.43536159 1.46417805]
# [0.06029929 0.05971708 0.05918716 0.05854538 0.05776145 0.05716147
#  0.05718147 0.05792229 0.0590236  0.06005662 0.06105314 0.06258303
#  0.06523442 0.06899009 0.07313174 0.07678206 0.07957178 0.08183653
#  0.08423222 0.08716984]
# [0.10179969 0.15130422 0.20021525 0.24919071 0.29931958 0.35062889
#  0.40186993 0.45165684 0.4998209  0.54766975 0.59687877 0.64803124
#  0.70015183 0.75163438 0.80165469 0.85074172 0.90004853 0.9501424
#  1.00054501 1.05040794]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      5.17172e+20        8          138.282          138.146      6.23m
#    1     8.01      3.81417e+12        4          127.873          127.185      5.72m
#    2     8.39      1.22782e+16       14          81.2623          80.9308      4.73m
#
# promising programs:
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(X1), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(sin(sin(mul(3.188, X2))), sin(add(sin(1.465), neg(X1))))
# add(sin(sin(sin(neg(sub(mul(3.134, X2), neg(3.828)))))), mul(sin(sin(3.311)), mul(mul(X1, X1), add(X0, X1))))
# add(neg(sub(add(X1, X1), X1)), sub(sin(mul(3.134, X2)), sin(3.879)))
# add(neg(mul(pow(X1, 2.334), X0)), sin(0.800))
# add(add(sub(X0, X0), sin(2.328)), neg(mul(pow(X1, 2.334), X0)))
# sub(sin(2.405), mul(pow(X1, 2.334), X0))
# add(sin(2.295), mul(mul(neg(X1), mul(X1, X0)), 1.117))
# add(add(sub(X0, X0), sin(2.328)), neg(mul(X1, mul(X0, X1))))
#
#    3     8.38      2.00084e+10       14          81.1184          82.2261      4.27m
#    4    11.46      1.52364e+09       17          27.0945          27.1395      4.19m
#
# promising programs:
# add(neg(mul(X1, mul(X0, X1))), sub(sin(mul(3.134, X2)), sin(3.879)))
# add(mul(neg(X1), mul(X1, X0)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(mul(mul(X1, X1), X0)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(neg(mul(X1, mul(X0, X1))), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(mul(neg(X0), mul(X1, X1)), sub(sin(mul(3.157, X2)), sin(3.879)))
# add(add(sin(mul(3.188, X2)), sin(2.328)), neg(mul(X1, mul(X0, X1))))
# add(add(sin(mul(3.188, X2)), sin(2.328)), mul(pow(X1, 2.277), neg(X0)))
# add(add(mul(sub(1.040, X1), X1), sin(2.328)), sub(sin(mul(3.134, X2)), mul(pow(X0, 1.188), X1)))
# sub(sin(mul(3.157, X2)), mul(sub(mul(X1, X0), sin(X0)), add(sub(0.583, X0), add(X0, X1))))
# add(add(mul(sub(1.040, X1), X1), sin(2.328)), sub(sin(mul(3.134, X2)), mul(X0, X1)))
# add(add(mul(sub(1.040, X1), X1), sin(2.328)), sub(sin(mul(3.134, X2)), mul(X0, X1)))
# sub(sin(mul(3.136, X2)), mul(sub(mul(X1, X0), sin(X0)), add(sub(0.583, X0), add(X0, X1))))
# sub(sin(mul(3.134, X2)), mul(sub(mul(X1, X0), sin(X0)), add(sub(0.583, X0), add(X0, X1))))
# sub(sin(mul(3.134, X2)), mul(sub(mul(X1, X0), sin(2.124)), add(sub(0.583, X0), add(X0, X1))))
# sub(sin(mul(3.134, X2)), mul(sub(mul(X1, X0), sin(2.124)), add(sub(0.583, X0), add(X0, X1))))
#
#    5    12.61      1.12544e+10       14          2.25373           2.1987      3.59m
#    6    14.01      1.17704e+10       14          2.24908          2.24053      2.67m
#    7    16.71      1.95585e+12       14          2.24176          2.30637      1.94m
#    8    17.38      2.17481e+09       14           1.8446          1.89248      1.53m
#    9    17.54      7.59857e+09       21          1.63621          1.67301     41.81s
#
# promising programs:
# add(add(add(mul(sin(sub(0.919, X1)), mul(X0, X1)), sin(2.328)), neg(mul(X1, X0))), sin(mul(3.134, X2)))
# add(add(add(mul(sin(sub(0.919, X1)), mul(X0, X1)), sin(2.328)), neg(mul(X1, X0))), sin(mul(3.134, X2)))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X1), X0))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# add(sin(mul(3.136, X2)), sub(sin(2.405), mul(X1, mul(X1, X0))))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X1), X0))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# add(sin(mul(3.136, X2)), sub(sin(2.405), mul(X1, mul(X1, X0))))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X0), X1))
# add(sin(mul(3.136, X2)), sub(sin(2.405), mul(X1, mul(X1, X0))))
# sub(sub(sin(mul(3.136, X2)), sin(3.879)), mul(mul(X1, X1), X0))
# add(mul(neg(X1), mul(X0, X1)), sub(sin(mul(3.136, X2)), sin(3.879)))
#
#   10    16.79      1.61163e+15       21          1.63806          1.65642      0.00s
#
# D-CODE model:  C + X0*X1*sin(C - X1) - X0*X1 + sin(C*X2)
#
# building blocks:
# 3.1574823649574113*X2
# -sin(X1 - 0.99441161578679878)
# -0.1674426330361471
# X1**2.334179435257333
# X0**1.1883865492429204
# X1*(1.0403132273653926 - X1)
# -sin(X1 - 0.918674059379345)
# 0.72666547850315493
# -X0*X1
# -X0*X1*sin(X1 - 0.918674059379345)
# sin(3.1336041796412095*X2)
#
# number of building blocks:  11
#
# T0: 5, T: 20
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [2.33761972 2.20663286 2.03468758 1.83731175 1.62093645 1.39054147
#  1.15584966 0.93121655 0.73044156 0.56163325 0.42605283 0.32065966
#  0.24128169 0.18403423 0.14513293 0.12065073 0.10707052 0.1021016
#  0.10485464 0.11522456]
# [1.14061167 1.25849889 1.38557153 1.52567747 1.67606748 1.82792663
#  1.96916034 2.08786165 2.1750891  2.22637567 2.2420097  2.22630814
#  2.18612231 2.12897942 2.06147464 1.98846692 1.91319974 1.83795358
#  1.76462708 1.69486665]
# [5.00040622 5.06312791 5.10170825 5.1443415  5.19646318 5.25143129
#  5.30302841 5.35100742 5.39879155 5.44872515 5.50018511 5.55128405
#  5.60123342 5.65076967 5.70082299 5.75136315 5.80162881 5.8511668
#  5.90037582 5.95004226]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      9.20621e+20       16          384.074          375.842      5.70m
#    1     6.44      6.47118e+15       20          345.159          343.649      5.45m
#    2     7.38      6.62866e+14       18          306.265          311.224      4.37m
#
# promising programs:
# add(mul(sub(X1, X0), neg(X0)), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# sub(add(add(pow(X0, 2.947), X0), sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sin(X1))), mul(sub(sin(X2), sin(X0)), neg(mul(X0, X1))))
# mul(mul(X1, X0), sub(1.277, sub(X0, sub(sin(neg(X0)), add(pow(X1, 1.624), neg(pow(X0, X0)))))))
# add(sub(mul(X0, pow(X0, 0.921)), X1), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# sub(add(sin(sin(neg(sub(mul(3.134, X2), neg(3.828))))), pow(X0, 2.071)), pow(X1, 0.928))
# mul(add(sub(X1, X0), sin(sub(mul(3.134, X2), neg(3.828)))), neg(X0))
# sub(mul(X0, X0), mul(pow(X1, 3.538), sin(mul(X0, X0))))
# sub(X0, mul(pow(X1, 3.538), sin(mul(X0, X0))))
# sub(X0, mul(pow(X1, 3.538), sin(mul(X0, X0))))
# mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(add(X0, X0), neg(1.806))), X0)
# mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(add(X0, X0), neg(1.806))), X0)
# mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(add(X0, X0), neg(1.806))), X0)
# mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(add(X0, X0), neg(1.806))), X0)
# sub(mul(mul(mul(neg(sin(sin(X0))), pow(X1, 3.974)), sin(add(sin(mul(1.117, X2)), mul(X0, X0)))), X0), neg(X0))
# sub(X0, mul(pow(X1, 3.538), sin(mul(X0, X0))))
#
#    3     9.96      1.31045e+10       15          255.995          255.419      4.47m
#    4    11.39      6.55945e+15       22          220.606          219.879      3.76m
#
# promising programs:
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(add(X0, X0), neg(X0))), X0))
# mul(add(neg(mul(pow(X1, 3.538), sin(pow(X0, 1.920)))), add(X1, sin(neg(sub(mul(3.134, X2), neg(3.828)))))), X0)
# sub(add(sin(sin(sin(neg(sub(mul(3.134, X2), neg(3.828)))))), pow(X0, 2.071)), mul(pow(X1, 3.538), sin(mul(X0, X0))))
# mul(mul(sin(X1), sub(1.277, sub(X0, sub(sin(neg(X0)), add(sub(pow(X1, 1.956), mul(sub(X0, X1), sin(1.997))), neg(add(pow(X0, 1.940), sin(mul(3.134, X2))))))))), pow(X0, 0.943))
# mul(mul(X1, X0), sub(1.277, sub(X0, sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X1, 1.624), neg(mul(X0, X0)))))))
# add(sin(mul(3.134, X2)), mul(pow(X1, 1.729), mul(mul(sub(X0, pow(X1, 1.729)), X0), X0)))
# mul(mul(X1, X0), sub(1.277, sub(X0, sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X1, 1.624), neg(mul(X0, X0)))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(1.277, sub(X0, sub(sin(neg(X0)), add(pow(X1, 1.624), neg(mul(X0, X0))))))))
# sub(mul(mul(mul(neg(X0), sub(X1, X0)), X1), X0), neg(sin(mul(3.134, X2))))
# add(sub(neg(sin(sin(X0))), add(neg(X0), mul(pow(X1, 3.538), sin(sin(mul(X0, X0)))))), sin(neg(sub(mul(3.134, X2), neg(2.753)))))
# add(add(mul(pow(X1, 1.729), sin(neg(mul(X0, X0)))), pow(X0, 1.584)), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# add(add(mul(pow(X1, 1.729), sin(neg(mul(X0, X0)))), pow(X0, 1.584)), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# add(mul(pow(X1, 1.729), sin(neg(X0))), add(pow(X0, 1.940), sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, neg(mul(pow(X1, 3.538), sin(pow(X0, 1.982))))))
# add(sub(pow(X0, X0), X1), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
#
#    5    13.58      6.12018e+16       27          150.757          158.176      3.18m
#    6    16.12      6.47201e+16       25          146.563          148.168      2.87m
#    7    18.63      7.12035e+16       23           131.57          161.794      2.19m
#    8    21.33        4.398e+16       23          133.167          147.422      1.55m
#    9    24.04      6.93128e+16       32          126.474          120.368     50.41s
#
# promising programs:
# add(add(mul(sin(pow(X0, 2.507)), sin(sin(mul(X0, X0)))), sin(mul(3.134, X2))), mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(X1, mul(mul(pow(X1, 3.538), X0), sin(mul(X0, X0))))))
# add(mul(pow(X1, 1.729), sin(neg(X0))), add(mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))), sin(neg(sub(sin(sin(mul(3.134, X2))), neg(3.828))))))
# add(sub(sub(add(sub(sin(add(mul(3.134, X2), mul(sub(0.605, X1), sub(pow(X0, 1.620), add(neg(neg(sin(mul(3.134, X2)))), neg(mul(X0, X0))))))), pow(X0, 3.050)), pow(X0, 3.699)), X0), sin(pow(X2, 3.140))), add(neg(mul(pow(neg(neg(X1)), 3.538), sin(mul(X0, X0)))), sin(sub(2.038, X1))))
# add(sin(pow(X0, 1.982)), add(mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))), sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# add(add(mul(sin(pow(X0, 2.507)), sin(X0)), sin(mul(3.134, X2))), mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))))
# add(add(mul(sin(pow(X0, 2.507)), sin(X0)), sin(mul(3.134, X2))), mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))))
# add(sub(sin(add(add(mul(pow(X1, 2.379), sin(neg(mul(X0, X0)))), sin(neg(sin(neg(X0))))), mul(3.134, X2))), sin(pow(X2, 3.140))), mul(X0, sub(X0, mul(pow(X1, 3.538), sin(mul(X0, X0))))))
# add(mul(pow(X0, 0.961), sub(pow(X0, mul(X1, X0)), mul(X1, add(sub(X1, X1), mul(1.885, X0))))), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# add(mul(mul(pow(X1, 3.538), pow(X0, 1.729)), sin(neg(sin(mul(X0, X0))))), add(sin(sin(mul(3.134, X2))), mul(sin(X0), X0)))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(1.277, mul(mul(pow(X1, 3.538), X0), sin(mul(X0, pow(X0, 0.943)))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(1.277, mul(mul(pow(X1, 3.538), X0), sin(mul(X0, pow(X0, 0.943)))))))
# add(sin(mul(3.134, X2)), mul(neg(mul(pow(X1, 3.412), sin(sin(mul(X0, X0))))), pow(X0, 2.582)))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(1.277, mul(mul(pow(X1, 3.538), X0), sin(pow(X0, 1.920))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X0, sub(1.277, mul(mul(pow(X1, 3.538), X0), sin(pow(X0, 1.920))))))
#
#   10    26.57      1.10136e+17       35          120.392          129.037      0.00s
#
# D-CODE model:  X0**C*(-C*X0*X1 + X0**(X0*X1)) + sin(X0**C)*sin(sin(X0**C)) + sin(C*X2)
#
# building blocks:
# 3.1336041796412095*X2
# X0*X1
# X1**1.62363178250279
# -sin(X0)
# X0**X0
# X0**0.9208345690252983
# X0**1.920834569025298
# X1**0.9280660133274369
# X1**3.537782688476712
# 1.1172983472045295*X2
# sin(3.1336041796412095*X2)
# X0**0.9434483376663311
# sin(sin(X0))
# -sin(X0**2)
# X0**1.5842869119062954
# 1.8849941240392003*X0
# sin(X0**2.506891054404737)
# sin(sin(3.1336041796412095*X2))
# X0**0.9605548457263776
# X0**(X0*X1)
# X0**1.7292021479087565
# X0**0.9605548457263776*(-1.8849941240392003*X0*X1 + X0**(X0*X1))
# sin(X0**2.506891054404737)*sin(sin(X0**2))
#
# number of building blocks:  23
#
# T0: 10, T: 25
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.12618013 1.1563143  1.1864209  1.22415442 1.27157488 1.32677478
#  1.38657322 1.44853656 1.51160497 1.57562137 1.64045604 1.70531968
#  1.76860439 1.8282921  1.88261827 1.93047884 1.97129014 2.00453653
#  2.02953575 2.04565985]
# [0.46316475 0.4611573  0.45653788 0.45191938 0.44785587 0.44418405
#  0.4411593  0.4395103  0.43969522 0.44136021 0.44364867 0.44604587
#  0.44888846 0.45304432 0.45911341 0.46692721 0.47575824 0.484948
#  0.49434287 0.50422376]
# [ 9.99709453 10.08027149 10.10830927 10.1417367  10.19429914 10.25374301
#  10.30723699 10.35340051 10.39851865 10.4473497  10.49913833 10.5505608
#  10.60010389 10.64896441 10.69880135 10.74980203 10.80099728 10.85167412
#  10.90191888 10.95199278]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      2.85796e+21        8          265.123          265.747      4.77m
#    1     7.40      4.20561e+14        8          265.158          265.438      4.25m
#    2     8.03       3.8844e+15       12          247.481          247.647      4.04m
#
# promising programs:
# sub(sin(X0), neg(neg(sub(X1, sin(neg(sub(mul(3.134, X2), neg(3.828))))))))
# neg(add(neg(add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), neg(X0))), sub(sub(sub(X1, X0), neg(X1)), sin(add(X0, X1)))))
# mul(add(sub(0.357, X1), sin(neg(sub(mul(3.134, X2), neg(3.828))))), sin(X0))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X1, X0))
# sin(add(sub(add(X1, X0), sin(mul(3.134, X2))), 1.200))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 1.534))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 1.534))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 1.534))
# add(mul(sin(mul(3.134, X2)), sin(pow(X0, 1.190))), neg(mul(pow(sin(pow(X1, 1.530)), 1.372), sin(pow(X1, 1.977)))))
# sub(sin(sin(sin(mul(3.134, X2)))), mul(sub(add(X1, X0), add(0.487, X0)), add(sub(2.382, X1), pow(X0, 1.501))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 1.105))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(X1, X1))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), neg(mul(X1, X1)))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), X1)
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), X1)
#
#    3    11.07      9.55863e+14       15          235.631           235.91      4.18m
#    4    13.24      8.34434e+14       26          203.877          199.316      3.69m
#
# promising programs:
# add(sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 2.769)), add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1))
# add(sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X1, 2.769)), add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1))
# sub(sin(sin(sin(sin(mul(3.134, X2))))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(sub(sin(X2), add(sin(X0), neg(X2))), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# add(neg(sub(pow(X1, 3.185), sin(mul(sin(neg(sub(mul(3.134, X2), neg(3.828)))), pow(X0, 0.192))))), add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1))
# add(sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sin(X1), add(X1, X0))), sin(2.154))
# add(neg(sub(pow(X1, 3.185), sin(neg(sub(mul(3.134, X2), neg(3.828)))))), add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1))
# sub(pow(X2, 1.149), sub(pow(X2, 0.527), sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# sub(pow(X2, 1.149), sub(pow(X2, 0.527), sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# sub(pow(X2, 1.149), sub(pow(X2, 0.527), sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# neg(add(neg(add(sin(sin(X0)), neg(X0))), sub(sub(pow(X1, 1.846), sin(mul(3.136, X2))), sin(add(X0, X1)))))
# neg(add(neg(add(sin(pow(X1, neg(sin(X2)))), neg(X0))), sub(sub(sub(X1, X0), mul(sin(add(neg(X2), add(X1, X0))), sin(sub(neg(X2), X2)))), sin(sin(mul(3.188, X2))))))
# add(neg(sub(pow(X1, 3.185), sin(sin(neg(sub(mul(3.134, X2), neg(3.828))))))), add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1))
# add(mul(sub(0.662, X1), add(X0, X0)), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# add(mul(sub(0.662, X1), add(X0, X0)), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# sub(sin(add(sub(add(X1, X0), sin(mul(3.134, X2))), 1.200)), mul(X1, X0))
#
#    5    12.69      4.17185e+14       26          202.808          208.934      2.96m
#    6    12.58      4.17518e+14       31           152.25          151.509      2.35m
#    7    16.43      6.53252e+12       31           152.41          150.074      2.71m
#    8    19.15      2.08718e+15       38          132.749          131.903      2.04m
#    9    22.46      5.06052e+15       38          115.147           115.11      1.12m
#
# promising programs:
# sub(sin(sin(sin(sin(mul(3.134, X2))))), sub(pow(X1, 1.956), mul(sub(0.784, sin(neg(sub(sin(mul(3.134, X2)), neg(2.753))))), mul(sub(sin(X2), add(sin(X0), neg(X2))), sin(sub(neg(add(add(X0, add(X1, X0)), mul(X2, X2))), X1))))))
# sub(pow(X2, 1.149), sub(pow(X2, 0.527), mul(add(mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1)))), sin(neg(sub(sub(sin(mul(3.134, X2)), pow(X1, 1.649)), add(pow(X1, 0.322), pow(X0, 1.501)))))), sin(X0))))
# sub(sin(sin(sin(sin(mul(3.134, X2))))), sub(mul(pow(sin(pow(X1, 1.530)), 1.372), mul(pow(X1, 1.822), X0)), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, 2.433), mul(X2, X2))), X1))))))
# sub(sin(sin(sin(sin(mul(3.134, X2))))), sub(pow(X1, 1.956), mul(sub(0.784, sin(neg(sub(sin(mul(3.134, X2)), neg(2.753))))), mul(sub(sin(X2), add(sin(X0), neg(X2))), sin(sub(neg(add(add(X0, sub(X2, sub(mul(pow(X2, 3.627), sin(pow(X2, 3.610))), sin(neg(sub(mul(3.134, X2), neg(3.828))))))), mul(X2, X2))), X1))))))
# sub(sin(sin(sin(sin(mul(3.134, X2))))), sub(sub(neg(neg(X1)), sin(1.327)), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, sub(neg(add(add(sin(X1), sin(X0)), sin(sin(1.937)))), sub(mul(pow(X2, 3.627), sin(pow(X2, 3.610))), sin(X0)))), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X2, mul(3.134, X2))), neg(3.134)))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(sin(sin(mul(3.134, X2)))), sub(sub(sub(X1, X0), sin(add(sin(X0), mul(X2, X2)))), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, 1.319), mul(X2, X2))), X1))))))
# sub(sin(add(sub(add(X1, X0), sin(mul(3.134, X2))), 1.200)), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, add(X1, X0)), mul(X2, X2))), X1))))))
# sub(sin(sin(sin(mul(3.134, X2)))), sub(sub(sub(X1, X0), sin(add(add(sin(add(sin(sub(X2, X0)), mul(X2, pow(X1, 2.822)))), X1), mul(X2, X2)))), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(sin(sin(mul(3.134, X2)))), sub(sub(sub(X1, X0), sin(add(sub(pow(X2, 1.149), sub(pow(X2, 0.527), sin(sin(sin(neg(sub(mul(3.134, X2), neg(3.828)))))))), mul(X2, X2)))), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X2, 0.527)), neg(3.134)))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X2, 0.527)), neg(3.134)))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X2, 0.527)), neg(3.134)))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X2, 0.527)), neg(3.134)))), sub(pow(X1, 1.956), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
# sub(sin(neg(sub(add(sub(add(X1, X0), sin(mul(3.134, X2))), pow(X1, 1.231)), neg(3.134)))), sub(sin(pow(X2, 3.731)), mul(sub(0.784, X1), mul(mul(3.134, X2), sin(sub(neg(add(add(X0, X0), mul(X2, X2))), X1))))))
#
#   10    27.46      1.50614e+16       46          102.455          100.599      0.00s
#
# D-CODE model:  -X1**C - (C + sin(C + sin(C*X2)))*(X2 - sin(X0) + sin(X2))*sin(C*X0 + C*X1 + X2**C) + sin(sin(sin(sin(C*X2))))
#
# building blocks:
# 3.1336041796412095*X2
# sin(X0 + X1)
# X0*X1
# X1**1.5340448770328972
# sin(X0**1.190398624006245)
# sin(sin(3.1336041796412095*X2))
# X1**1.104589549491893
# -sin(X0 - X2)
# X1**2.821846986689459*X2
# X0**0.19203581812113282
# (X0 + X1)*sin(X1)
# X2**0.5269144058402923
# X2**1.1485856392764742
# X1**1.8464499266972658
# X1**(-sin(X2))
# sin(X1**(-sin(X2)))
# X1**0.3219953063086322
# X2**2
# X1**1.2311984829708393
# -X1**1.9560097617034937
# -(sin(sin(3.1336041796412095*X2) + 2.752933697024726) + 0.7843918065925901)*(X2 - sin(X0) + sin(X2))*sin(2*X0 + 2*X1 + X2**2)
# sin(sin(sin(sin(3.1336041796412095*X2))))
#
# number of building blocks:  22
#
# T0: 15, T: 30
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.05800508 1.05470963 1.03674209 1.01133535 0.98205567 0.94977985
#  0.91437937 0.87592543 0.83512402 0.79329375 0.75216452 0.71354103
#  0.67890345 0.64919751 0.62499372 0.60683831 0.59540754 0.59131565
#  0.594851   0.60599851]
# [0.86098146 0.86178728 0.86131893 0.8621175  0.86285643 0.86136984
#  0.85685661 0.8500116  0.84182186 0.83259188 0.82198915 0.80966988
#  0.79565199 0.78017679 0.76345312 0.74568061 0.72727446 0.70892551
#  0.69133509 0.67485381]
# [14.99457149 15.09300328 15.11024126 15.13616715 15.19021995 15.25385449
#  15.3087389  15.35375598 15.39830643 15.44854936 15.50240521 15.55483018
#  15.60421351 15.65277039 15.70253542 15.75289771 15.80214403 15.85013467
#  15.89853687 15.94870518]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      8.52825e+21        8          24.6279          24.5355      6.36m
#    1     9.26      3.84558e+15        8          24.6023          24.7659      6.70m
#    2     8.45      6.21653e+11        8          23.1161          23.1192      5.65m
#
# promising programs:
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(sub(0.787, X1), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# sin(add(sub(add(X1, X0), sin(mul(3.134, X2))), 1.200))
# sin(sub(sub(0.640, X1), add(sub(mul(3.134, X2), neg(3.828)), sin(sub(neg(1.956), sin(X0))))))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X2, 0.244)))
# sin(neg(sub(mul(3.134, X2), neg(3.809))))
# sin(sub(mul(3.188, X2), pow(X2, 2.742)))
# sin(sin(neg(sub(mul(3.130, X2), neg(3.828)))))
# sin(neg(sub(mul(3.134, X2), neg(3.828))))
# sin(neg(sub(mul(3.134, X2), neg(3.828))))
#
#    3     8.75      1.47991e+10       16          12.3491          12.4338      5.00m
#    4    10.50      1.37462e+10       16          10.2713          10.1795      4.42m
#
# promising programs:
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), sub(X0, X0)))))
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), sub(X0, X0)))))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
#
#    5     9.15      9.12821e+09       16          10.2546          10.3301      3.22m
#    6     8.75       1.5265e+12       16          10.2426          10.4378      2.13m
#    7    10.91      1.87764e+13       20           5.5894          5.57606      1.73m
#    8    13.83        8.602e+09       20          5.40767          5.48131      1.34m
#    9    16.07      1.51277e+10       22          4.19793          4.25762     40.81s
#
# promising programs:
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), neg(mul(pow(X1, 2.195), X0))))))
# add(add(sin(neg(sub(mul(3.134, X2), 2.753))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(0.787, X1), sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), neg(mul(X1, X0)))))))
# add(sub(0.787, X1), sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(add(neg(1.956), pow(sin(sub(mul(3.130, X2), sub(neg(mul(2.777, X2)), neg(3.828)))), 0.244))))))
# add(sub(pow(X1, 0.163), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(0.787, X1), add(add(sin(mul(3.134, X2)), sin(pow(X2, 1.436))), neg(mul(X1, X0))))
# add(add(add(sin(mul(3.134, X2)), sin(add(X1, X0))), neg(mul(X1, X0))), sub(0.817, X1))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.494)))), sin(X0)), neg(mul(X1, X0)))
# add(sub(0.787, X1), add(add(sin(sin(mul(3.134, X2))), sin(pow(X2, 2.310))), neg(mul(X1, X0))))
#
#   10    16.89      1.13012e+09       22         0.762535         0.746542      0.00s
#
# D-CODE model:  C - X0*X1**C + sin(C*X2 + C)
#
# building blocks:
# X0*X1
# 3.1336041796412095*X2
# -sin(sin(X0) + 1.9563682898761154)
# 3.188300659775743*X2
# X1**0.24365985743252838
# X2**0.24365985743252838
# X2**2.7423310443255287
# X2**1.4360848158976107
# sin(X0 + X1)
# 0.72666547850315493
# -X0*X1**2
# sin(3.1336041796412095*X2 + 0.2472900523964841)
#
# number of building blocks:  12
#
# T0: 20, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [0.8847791  0.88934426 0.89307867 0.90373045 0.92330836 0.9497428
#  0.97991463 1.01181917 1.04479584 1.07842559 1.11151931 1.14211658
#  1.16826829 1.1886972  1.20273356 1.20975153 1.20880233 1.19883965
#  1.17927357 1.15029467]
# [0.96307461 0.96140043 0.95555174 0.95192465 0.95154928 0.95264399
#  0.95379907 0.95544899 0.95912152 0.96581617 0.97523251 0.986389
#  0.99876102 1.01274785 1.02915277 1.04836445 1.07004414 1.09341339
#  1.11762889 1.14186241]
# [19.99450487 20.10729364 20.11116891 20.12809312 20.18434507 20.25405222
#  20.31134607 20.35422583 20.39584492 20.4453447  20.50021923 20.55319836
#  20.6015589  20.64848922 20.69769519 20.74915377 20.80028674 20.84968066
#  20.89847202 20.94841881]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      8.44577e+21        8          180.193          177.035      5.66m
#    1     5.81      2.36972e+10        8          179.555          182.776      5.10m
#    2     7.45       1.3782e+15        8          179.204          185.934      4.74m
#
# promising programs:
# sub(mul(sin(sin(mul(3.134, X2))), pow(X1, 1.659)), add(pow(X0, 2.174), neg(pow(X0, 3.663))))
# add(sin(neg(add(X2, add(add(X2, X1), X2)))), add(sub(pow(X0, 2.765), X0), mul(neg(X0), sub(X0, X0))))
# sub(pow(X0, 2.646), add(add(0.966, sin(X0)), add(sin(add(X2, add(add(X2, X1), X2))), neg(0.853))))
# add(sin(sin(sub(neg(X2), add(X2, X2)))), mul(pow(X0, 2.390), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
# add(sin(sin(sub(neg(X2), add(X2, X2)))), mul(sub(X0, neg(sub(sub(X0, X1), sub(0.624, X1)))), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
# sub(pow(X0, 0.493), sub(pow(X1, 3.259), sin(mul(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sin(X0)))))
# add(sin(sin(sub(neg(X2), add(X2, X2)))), mul(mul(pow(X0, 2.567), sin(X1)), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
# add(add(neg(sin(add(X2, add(add(X2, X1), X2)))), pow(X0, 2.038)), neg(X1))
# add(sin(sin(sub(neg(X2), add(X2, X2)))), mul(sub(X0, neg(X0)), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
# add(sin(neg(add(X2, add(add(X2, X1), X2)))), sub(pow(X0, 1.604), pow(X1, 1.366)))
# sub(sin(neg(add(X2, add(add(X2, X1), X2)))), neg(sub(X0, X1)))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sub(sin(pow(X0, 2.928)), mul(pow(X1, 2.249), sub(X0, X1))))
# add(neg(sin(sub(mul(3.134, X2), neg(3.828)))), pow(X0, 2.038))
# sub(pow(X0, 1.896), neg(sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# sub(sin(X0), sub(sin(pow(X0, 2.014)), mul(neg(neg(X0)), sin(mul(3.134, X2)))))
#
#    3     9.97      6.50937e+09       18          142.913          142.697      4.54m
#    4    14.09      5.04962e+09       17          104.184           104.84      4.34m
#
# promising programs:
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(pow(X0, pow(X0, 1.773)), sub(X0, sin(0.747))))
# add(sin(sin(sin(neg(sub(mul(3.134, X2), neg(3.828)))))), neg(add(neg(pow(X0, mul(X0, X0))), pow(X1, X1))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, pow(X0, 1.579))))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X0, 2.174), neg(pow(X0, 3.663))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X0, 2.174), neg(pow(X0, 3.663))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X0, 2.174), neg(pow(X0, 3.663))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), add(pow(X0, 2.174), neg(pow(X0, 3.663))))
# sub(neg(sub(X1, pow(X0, mul(X0, X0)))), neg(sin(neg(sub(mul(3.134, X2), neg(3.828))))))
# neg(neg(add(sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sin(pow(X0, 2.892))), X0)))
# add(sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sin(pow(X0, 2.892))), X0)
# add(sin(sin(sin(neg(sub(mul(3.134, X2), neg(3.828)))))), mul(sub(X0, sin(pow(X2, 3.963))), sub(pow(X0, 3.345), add(neg(X0), mul(X0, X0)))))
# add(pow(X0, X1), add(sin(sin(neg(sub(mul(3.134, X2), neg(3.828))))), mul(mul(sin(add(X0, X0)), sin(X1)), sub(add(pow(X0, 2.174), neg(pow(X0, 3.663))), pow(X0, 0.465)))))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sub(sin(pow(X0, 2.928)), pow(pow(X0, 1.873), 0.502)))
# sub(sin(neg(sub(mul(3.134, X2), neg(3.828)))), sub(sin(pow(X0, 2.928)), neg(neg(pow(X0, 1.895)))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, neg(X0)), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
#
#    5    18.17      1.53342e+10       19          99.5732          98.4675      3.70m
#    6    17.33      9.42847e+11       24          92.5642          91.9116      2.87m
#    7    20.80      6.38312e+12       30          81.2394          82.2356      2.29m
#    8    23.37      1.03353e+10       52          75.1319          78.4611      1.59m
#    9    25.51      9.03752e+09       44           69.035           71.237     47.97s
#
# promising programs:
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X0, 2.765))), sub(mul(mul(sin(mul(X0, X2)), mul(neg(X0), sin(0.633))), sub(sin(2.698), add(neg(X0), mul(X1, pow(X0, 0.502))))), add(neg(X0), mul(X1, X0)))))
# add(sin(sin(neg(sub(mul(3.134, X2), neg(3.828))))), mul(sub(X0, sin(neg(neg(mul(X0, add(sub(pow(X0, 2.765), X0), mul(sub(sin(pow(X0, 1.937)), add(sin(sin(pow(X1, 3.598))), sub(X0, X1))), sub(X0, X0)))))))), sub(sin(mul(mul(sin(mul(X0, X2)), mul(neg(X0), sin(0.633))), sub(sin(2.698), add(neg(X0), mul(X1, pow(X0, 0.502)))))), add(neg(X0), mul(X1, X0)))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sin(sub(X0, sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sin(mul(X1, X0))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(pow(X0, pow(X0, 1.773)), sub(sin(mul(mul(sin(mul(X0, X2)), sin(neg(sub(mul(3.134, X2), neg(3.828))))), sub(sin(2.698), add(neg(X0), mul(X1, pow(X0, 0.502)))))), add(neg(X0), mul(X1, X0)))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sub(X0, X1)), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sin(sub(X0, sin(pow(sin(0.747), 3.963))))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(pow(X2, pow(X1, 1.222))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, sub(X0, X1)))), neg(neg(mul(X0, add(sin(sin(X1)), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(add(sub(pow(X0, 2.765), X0), mul(neg(X0), sin(mul(X0, X2)))), sub(sin(mul(X2, X2)), add(neg(X0), mul(X1, X0)))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(pow(X2, 3.392)), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sin(sub(neg(X1), neg(neg(3.828))))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(sin(sub(X0, sin(pow(mul(X0, X0), 3.963))))), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
# add(sin(neg(sub(mul(3.134, X2), neg(3.828)))), mul(sub(X0, sin(pow(X2, 3.963))), neg(neg(mul(X0, add(sin(mul(X2, X2)), mul(sub(X0, sin(X2)), sub(sin(mul(sin(mul(3.134, X2)), X2)), add(neg(X0), mul(X1, X0))))))))))
#
#   10    29.79      1.31579e+09       51          63.1697          65.3884      0.00s
#
# D-CODE model:  X0*(X0 - sin(X2**C))*(-X0*X1 + X0 + (X0 - sin(X2))*(-X0*X1 + X0 + sin(X2*sin(C*X2))) + sin(X2**C)) - sin(C*X2 + C)
#
# building blocks:
# sin(sin(3.1336041796412095*X2))
# X0**2.1742636293962283
# 3.1336041796412095*X2
# sin(3.1336041796412095*X2)
# X0**2.7646721714620766
# sin(X2**2)
# X0**0.4931195381787162
# X1**1.3660915809311864
# X0**1.6039320367320402
# X0**1.8963956607307737
# sin(X0**2.014084555787318)
# X0**1.773025735097914
# X0**(X0**1.773025735097914)
# X0**(X0**2)
# X0**X1
# sin(2*X0)
# X0**0.94058295774295058
# -0.5918688086801999*X0
# X0**0.5015850220981812*X1
# X0**0.5015850220981812
# X2*sin(3.1336041796412095*X2)
# 0.21612700546911420
# sin(X2**(X1**1.2215059152203829))
# X2**(X0 - X1)
# sin(X2**(X0 - X1))
# -sin(3.1336041796412095*X2 + 3.8275478297437684)
# X0*(X0 - sin(X2**3.9629504705485266))*(-X0*X1 + X0 + (X0 - sin(X2))*(-X0*X1 + X0 + sin(X2*sin(3.1336041796412095*X2))) + sin(X2**2))
#
# number of building blocks:  27

# %%
# D-CODE single shot:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=15)
# Out:
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# g
# (301, 50)
# c
# (50, 50)
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.27      8.52825e+21        8          24.6279          24.5355     14.95m
#    1     9.26      3.84558e+15        8          24.6023          24.7659     10.87m
#    2     8.45      6.21653e+11        8          23.1161          23.1192      9.49m
#
# promising programs:
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(sub(0.787, X1), sin(neg(sub(mul(3.134, X2), neg(3.828)))))
# sin(add(sub(add(X1, X0), sin(mul(3.134, X2))), 1.200))
# sin(sub(sub(0.640, X1), add(sub(mul(3.134, X2), neg(3.828)), sin(sub(neg(1.956), sin(X0))))))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X1, 0.244)))
# sin(sub(mul(3.188, X2), pow(X2, 0.244)))
# sin(neg(sub(mul(3.134, X2), neg(3.809))))
# sin(sub(mul(3.188, X2), pow(X2, 2.742)))
# sin(sin(neg(sub(mul(3.130, X2), neg(3.828)))))
# sin(neg(sub(mul(3.134, X2), neg(3.828))))
# sin(neg(sub(mul(3.134, X2), neg(3.828))))
#
#    3     8.75      1.47991e+10       16          12.3491          12.4338      9.74m
#    4    10.50      1.37462e+10       16          10.2713          10.1795      9.31m
#
# promising programs:
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), sub(X0, X0)))))
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), sub(X0, X0)))))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(mul(3.134, X2)), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0)))
#
#    5     9.15      9.12821e+09       16          10.2546          10.3301      8.47m
#    6     8.75       1.5265e+12       16          10.2426          10.4378      7.88m
#    7    10.91      1.87764e+13       20           5.5894          5.57606      7.79m
#    8    13.83        8.602e+09       20          5.40767          5.48131      8.92m
#    9    16.07      1.51277e+10       22          4.19793          4.25762      7.56m
#
# promising programs:
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
# sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), neg(mul(pow(X1, 2.195), X0))))))
# add(add(sin(neg(sub(mul(3.134, X2), 2.753))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(pow(X1, 0.244), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(0.787, X1), sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(sub(neg(1.956), neg(mul(X1, X0)))))))
# add(sub(0.787, X1), sub(sin(mul(3.134, X2)), add(mul(X1, X0), sin(add(neg(1.956), pow(sin(sub(mul(3.130, X2), sub(neg(mul(2.777, X2)), neg(3.828)))), 0.244))))))
# add(sub(pow(X1, 0.163), X1), add(add(sin(neg(sub(mul(3.134, X2), neg(3.134)))), sin(2.328)), neg(mul(X1, X0))))
# add(sub(0.787, X1), add(add(sin(mul(3.134, X2)), sin(pow(X2, 1.436))), neg(mul(X1, X0))))
# add(add(add(sin(mul(3.134, X2)), sin(add(X1, X0))), neg(mul(X1, X0))), sub(0.817, X1))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.494)))), sin(X0)), neg(mul(X1, X0)))
# add(sub(0.787, X1), add(add(sin(sin(mul(3.134, X2))), sin(pow(X2, 2.310))), neg(mul(X1, X0))))
#
#   10    16.89      1.13012e+09       22         0.762535         0.746542      7.25m
#   11    18.81      7.96641e+10       22         0.759137         0.777122      5.63m
#   12    20.63      2.62887e+11       22         0.759124         0.777232      5.84m
#   13    21.48       9.7783e+13       22         0.447365         0.428071      5.23m
#   14    23.93       4.0301e+10       22         0.445965         0.440672      4.31m
#
# promising programs:
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.381)))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.381)))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.381)))), sin(2.328)), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(X1, mul(X1, X0))))
#
#   15    26.70      9.11336e+15       22         0.444448         0.454319      3.96m
#   16    31.02      1.29175e+18       22         0.444458         0.454234      3.24m
#   17    38.13      5.03801e+15       21         0.344305          0.33431      2.22m
#   18    33.61      8.30487e+09       21         0.344129         0.335896      1.02m
#
# promising programs:
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(add(sin(3.624), sub(mul(3.134, X2), neg(3.828))))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.381)))), 0.691), neg(mul(pow(X1, 1.977), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(mul(3.134, X2), neg(3.381)))), 0.691), neg(mul(X1, mul(X1, X0))))
# add(add(sin(neg(add(neg(sub(mul(3.134, X2), neg(3.381))), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
# add(add(sin(neg(sub(neg(sub(neg(sub(mul(3.134, X2), neg(3.381))), 3.134)), neg(3.134)))), sin(2.328)), neg(mul(pow(X1, 1.846), X0)))
#
#   19    26.68      2.75834e+18       21         0.308666         0.320389      0.00s
#
# D-CODE model:  C - X0*X1**C - sin(C*X2 + C)
#
# building blocks:
# X0*X1
# 3.1336041796412095*X2
# -sin(sin(X0) + 1.9563682898761154)
# 3.188300659775743*X2
# X1**0.24365985743252838
# X2**0.24365985743252838
# X2**2.7423310443255287
# X1**2.1951567489773476
# X2**1.4360848158976107
# sin(X0 + X1)
# sin(sin(3.1336041796412095*X2))
# X1**1.8464499266972658
# 0.72666547850315493
# -sin(3.1336041796412095*X2 + 3.3636642674770715)
# -X0*X1**1.8464499266972658
#
# number of building blocks:  15
# ([<function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>,
#   <function _lambdifygenerated(X0, X1, X2)>],
#  [<function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=0)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=1)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=2)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=3)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=4)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=5)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=6)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=7)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=8)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=9)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=10)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=11)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=12)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=13)>,
#   <function D_CODE.gp_utils.get_building_blocks_lambda.<locals>.<lambda>(X0, X1, X2, i=14)>])

# %% [markdown]
# ### Oscillating Sel'kov Dynamic

# %% [markdown]
# ##### SR-T

# %%
# SR-T series 5:

# setting:
ode_name = 'OscillatingSelkovODE_d' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 20 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [23, 25, 27, 29, 31]
Ts = [33, 35, 37, 39, 41]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 23, T: 33
# Running with: ode_name=OscillatingSelkovODE_d, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# 22.99899357507509
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.97781e+09       10         0.228442         0.225835      1.78m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     4.73          312.539       10         0.227197         0.232181      1.33m
#    2     3.69          1094.37        9         0.201264         0.210018     57.16s
#
# promising programs:
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
#
#    3     3.90          19681.2        9         0.201473         0.208139     37.45s
#    4     3.22          89.9547        6         0.223091         0.240865     17.22s
#
# promising programs:
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
# sub(0.831, X1)
#
#    5     3.16          2400.17        3         0.244089         0.277464      0.00s
#
# SR-T model:  C - X1
#
# building blocks:
#
# number of building blocks:  0
#
# T0: 25, T: 35
# Running with: ode_name=OscillatingSelkovODE_d, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# 25.000673726466808
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      2.11371e+09       10         0.336068          0.33008      1.51m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     4.73          291.891        7         0.328964          0.31741      1.39m
#    2     3.15          1363.52        7         0.327109         0.334108     56.72s
#
# promising programs:
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.751, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.711, X1)
#
#    3     3.14            22947        6         0.326076         0.343402     35.39s
#    4     3.20          97.1186        3         0.335836         0.367046     17.40s
#
# promising programs:
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.751, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.717, X1)
# sub(0.751, X1)
# sub(0.717, X1)
# sub(0.751, X1)
#
#    5     3.16          2547.08        3         0.335509         0.369995      0.00s
#
# SR-T model:  C - X1
#
# building blocks:
#
# number of building blocks:  0
#
# T0: 27, T: 37
# Running with: ode_name=OscillatingSelkovODE_d, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# 26.993687322077683
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      2.24959e+09       20         0.353397         0.346141      1.51m
#    1     4.64          225.409        9         0.314157          0.31403      1.25m
#    2     3.60          1329.83       17         0.308455         0.305041      1.01m
#
# promising programs:
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# sin(neg(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# sin(sub(0.028, mul(3.241, X2)))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(sub(log(1.025), mul(3.241, X2)))
# sin(sub(log(1.025), mul(3.241, X2)))
# sin(sub(log(1.025), mul(3.241, X2)))
# sin(sub(log(1.025), mul(3.241, X2)))
#
#    3     3.79          63356.8       10         0.299377         0.297169     37.87s
#    4     4.59          95.5937        9         0.297616         0.308218     18.57s
#
# promising programs:
# sin(sub(sub(0.831, X1), sin(mul(3.241, X2))))
# sin(sub(sub(0.831, X1), sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(sin(neg(mul(3.241, X2))))
# sin(sub(sub(0.868, X1), sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(neg(sin(mul(3.241, X2))))
# sin(sin(neg(mul(3.241, X2))))
#
#    5     6.91           91.031        9          0.26138         0.274732      0.00s
#
# SR-T model:  -sin(-C + X1 + sin(C*X2))
#
# building blocks:
# sin(3.2410061383495*X2)
# -sin(3.2410061383495*X2)
# -sin(3.2410061383495*X2 - 0.02828476182376061)
#
# number of building blocks:  3
#
# T0: 29, T: 39
# Running with: ode_name=OscillatingSelkovODE_d, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# 29.044026985729506
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      2.38851e+09       10         0.334838         0.332578      1.71m
#    1     4.46          181.814        7         0.309492         0.302929      1.33m
#    2     4.08          1376.65        7         0.237408         0.248811     56.96s
#
# promising programs:
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.085, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.085, mul(3.241, X2)))
# sin(sub(0.085, mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
# neg(sin(mul(3.241, X2)))
#
#    3     4.53          70084.4        7          0.23706         0.251937     39.09s
#    4     6.70          86.4056       20         0.212557         0.206678     22.01s
#
# promising programs:
# sin(sub(0.126, mul(3.241, X2)))
# sin(sub(0.126, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.126, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
# sin(sub(0.104, mul(3.241, X2)))
#
#    5     7.44          53.8635       20         0.210878         0.221793      0.00s
#
# SR-T model:  sin(sin(-C*X2 + C + 2*X2**C) - sin(log(X1)))
#
# building blocks:
# -sin(3.2410061383495*X2 - 0.10373752213223322)
# -sin(3.2410061383495*X2 - 0.0846752211517049)
# sin(3.2410061383495*X2)
# -sin(3.2410061383495*X2 - 0.12560776620610997)
#
# number of building blocks:  4
#
# T0: 31, T: 41
# Running with: ode_name=OscillatingSelkovODE_d, ode_param=[0.8, 0.1], x_id=0, freq=20, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (201, 50, 3)
# 31.048978609082962
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      2.52387e+09       10         0.336487         0.349087      1.71m
#    1     4.23          211.354        7         0.231004         0.238234      1.32m
#    2     3.74          1568.51        7          0.22552         0.224913      1.03m
#
# promising programs:
# sin(sub(0.175, mul(3.241, X2)))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.209), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(sin(0.202), mul(3.241, X2)))
# sin(sub(log(1.190), mul(3.241, X2)))
# sin(sub(log(1.190), mul(3.241, X2)))
# sin(sub(sin(0.167), mul(3.241, X2)))
#
#    3     4.71          76469.3       16         0.216507         0.222766     40.60s
#    4     7.22          47.1136       18         0.181364         0.188523     20.60s
#
# promising programs:
# sin(sub(0.202, mul(3.241, X2)))
# sin(sub(0.202, mul(3.241, X2)))
# sin(sub(0.202, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.265, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.162, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
# sin(sub(0.162, mul(3.241, X2)))
# sin(sub(0.175, mul(3.241, X2)))
#
#    5     7.35          54.7141       18         0.181608         0.183287      0.00s
#
# SR-T model:  sin(-C*X2 + C + 2*X2**C)
#
# building blocks:
# -sin(3.2410061383495*X2 - 0.17461618862005224)
# sin(3.1394689809108645*X2)
# -sin(3.2410061383495*X2 - 0.20225388594721674)
# -sin(3.2410061383495*X2 - 0.2648142106347563)
# -sin(3.2410061383495*X2 - 0.16215838256749215)
#
# number of building blocks:  5

# %% [markdown]
# ##### D-CODE

# %%
#D-CODE series 5:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [23, 25, 27, 29, 31]
Ts = [38, 40, 42, 44, 46]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 23, T: 38
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.24852904 1.2460336  1.23328118 1.21565962 1.1935417  1.16560088
#  1.13175921 1.09382912 1.05426386 1.01478292 0.97610412 0.93862042
#  0.90311531 0.87093098 0.8436595  0.82269469 0.8088858  0.80244077
#  0.80318318 0.81105709]
# [0.7140677  0.72196156 0.7229266  0.72242304 0.72277208 0.72381009
#  0.72439381 0.72358301 0.7209973  0.71662151 0.71057429 0.70306614
#  0.69442895 0.68504919 0.67521234 0.66499791 0.65432646 0.64313267
#  0.63154388 0.61992797]
# [22.99514079 23.11464696 23.11143786 23.12470298 23.18311771 23.25582126
#  23.31294217 23.3529984  23.39229741 23.44208414 23.49921531 23.55423772
#  23.60294289 23.64882109 23.69697903 23.74844782 23.80053468 23.85088089
#  23.89981393 23.94908192]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.63888e+24        8          175.751          175.881      2.82m
#    1     5.80      3.24239e+09        7          127.343          126.862      2.26m
#    2     7.48       6.8487e+11        8          116.091           115.65      1.83m
#
# promising programs:
# sub(sin(sub(neg(X1), mul(3.241, X2))), mul(1.574, X1))
# sub(sin(neg(mul(3.241, X2))), pow(X1, 1.253))
# neg(add(sin(mul(3.241, X2)), X1))
# sub(sin(sin(neg(mul(3.241, X2)))), pow(X1, 2.321))
# mul(sub(log(0.253), sin(mul(3.241, X2))), X1)
# sub(neg(X1), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X0))))
# sub(sin(sin(sub(sub(pow(X2, 2.592), pow(X2, 3.188)), mul(3.241, X2)))), pow(X1, 2.654))
# sub(sin(sub(neg(X1), mul(3.241, X2))), pow(X1, 2.664))
# add(sub(sin(sin(sub(neg(pow(X1, 2.195)), mul(3.241, X2)))), pow(X1, 0.427)), sub(log(X0), X1))
# sub(sin(sub(neg(X1), mul(3.241, X2))), X1)
# add(sin(sub(neg(X1), mul(3.241, X2))), neg(pow(X1, 2.975)))
# add(neg(X1), sin(sub(sub(0.473, pow(X1, 1.733)), mul(3.241, X2))))
# neg(sub(add(sub(neg(sin(sub(neg(X1), mul(3.241, X2)))), sin(2.314)), 2.501), neg(sin(log(add(X1, X1))))))
# neg(neg(neg(add(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X1))), X1))))
# mul(X1, neg(add(sin(X1), sub(sin(mul(3.241, X2)), log(X0)))))
#
#    3     9.61      3.58505e+15       11          80.7389          80.9631      1.34m
#    4    11.51      1.01452e+12       26          78.1186          79.8529     42.38s
#
# promising programs:
# sub(sin(sub(sin(sin(sub(mul(sin(sub(sub(X0, X2), sub(X2, X0))), pow(X1, 0.646)), mul(3.241, X2)))), mul(3.241, X2))), X1)
# sub(sin(sub(sin(neg(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)))), mul(3.241, X2))), pow(X1, 2.150))
# sub(sin(sub(neg(pow(sin(sub(neg(pow(X1, 2.362)), mul(3.241, X2))), 3.760)), mul(3.241, X2))), pow(X1, 2.321))
# sub(sin(sub(mul(3.139, X2), sin(sub(log(mul(3.314, X2)), mul(3.241, X2))))), X1)
# add(add(sub(sub(0.806, X1), log(2.745)), mul(neg(X1), sin(2.423))), sin(sub(neg(sin(X1)), mul(3.241, X2))))
# sub(sin(mul(X2, add(X0, X0))), add(X1, sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(mul(X1, 2.288))))))
# add(neg(X1), sin(sub(sin(sin(mul(3.314, X2))), mul(3.241, X2))))
# sub(sin(sub(neg(log(X0)), mul(3.241, X2))), X1)
# sub(sin(sub(neg(log(X0)), mul(3.241, X2))), X1)
# sub(sin(sub(sin(neg(sub(pow(X1, 3.470), sin(sub(sub(1.204, X1), mul(3.241, X2)))))), mul(3.241, X2))), pow(X1, 0.967))
# sub(sin(sub(sin(sub(sin(sub(neg(X1), mul(3.241, X2))), mul(3.241, X2))), mul(3.241, X2))), pow(X1, 0.967))
# sub(sin(sub(sin(neg(sub(pow(X1, 3.470), sin(mul(3.314, X2))))), mul(3.241, X2))), pow(X1, 0.967))
# sub(sin(mul(X2, add(X0, X0))), add(X1, sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(neg(3.999))))))
# sub(sin(mul(X2, add(X0, X0))), add(X1, sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(sub(log(X0), X1), 2.288))))))
# sub(sin(sin(sub(sub(pow(X2, 2.592), pow(1.033, 3.188)), mul(3.241, X2)))), pow(X1, X0))
#
#    5    13.57      2.77589e+09       25          71.4947          71.0841      0.00s
#
# D-CODE model:  -X1 - sin(C*X2 + sin(sin(C*X2 - X1**C*sin(C*X0 - C*X2))))
#
# building blocks:
# -sin(3.2410061383495*X2)
# X1**1.2531171289857501
# sin(3.2410061383495*X2)
# X1**2.3212949240427094
# X1**0.4274455689922869
# log(2*X1)
# X1**0.6464982887465436
# X2**0.6395216888991612
# X1**0.9665117631834098
# X1**X0
#
# number of building blocks:  10
#
# T0: 25, T: 40
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.71830236 1.72111597 1.70640769 1.6846331  1.65863356 1.62697272
#  1.58841024 1.54412127 1.49684965 1.44881111 1.40070205 1.35256917
#  1.30533864 1.26130048 1.22305214 1.19199295 1.16787233 1.14980189
#  1.13768446 1.1326488 ]
# [0.58972652 0.59876811 0.60606541 0.61485532 0.62516784 0.63550709
#  0.64477005 0.65294844 0.66049379 0.66740893 0.67310983 0.6770826
#  0.67949481 0.68106057 0.68233175 0.68319799 0.68311438 0.68179073
#  0.67961687 0.67740413]
# [24.99288971 25.12129708 25.11331664 25.1222171  25.18068218 25.25566496
#  25.31438071 25.35460404 25.39349319 25.44289437 25.49938244 25.55323998
#  25.60087621 25.64683542 25.69646701 25.7497265  25.80245611 25.85186117
#  25.89927851 25.94791675]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.43394e+25       20          317.469           315.31      2.63m
#    1     6.38      1.74567e+10        9          272.597          272.879      2.11m
#    2     7.93      3.15209e+12       10          228.729          228.506      1.76m
#
# promising programs:
# add(neg(pow(X1, 3.363)), sin(sub(sub(0.473, pow(X1, 1.733)), mul(3.241, X2))))
# add(sin(sub(neg(pow(X1, 3.760)), mul(3.241, X2))), neg(mul(X1, X1)))
# sub(sin(sin(sin(sub(neg(pow(X1, 3.760)), mul(3.241, X2))))), pow(X1, 2.654))
# add(sin(sub(mul(sin(X1), neg(X1)), mul(3.241, X2))), neg(sin(pow(X1, 3.265))))
# sub(sin(sub(mul(2.988, X2), X1)), mul(pow(X1, 3.952), mul(X0, X0)))
# sin(sub(neg(log(X1)), mul(3.241, X2)))
# sin(sub(neg(log(X1)), mul(3.241, X2)))
# sin(sub(sin(sub(sub(X0, X0), log(X1))), mul(3.241, X2)))
# sin(sub(neg(sub(log(X1), neg(sin(sin(log(X1)))))), mul(3.241, X2)))
# sin(sub(sin(sub(log(sub(neg(sin(0.371)), pow(X1, 1.093))), sin(add(pow(X1, 1.961), sub(sin(X1), log(2.197)))))), mul(3.241, X2)))
# sin(sub(mul(log(X1), neg(1.999)), mul(3.241, X2)))
# sin(sub(mul(log(X1), neg(1.999)), mul(3.241, X2)))
# sin(sub(neg(add(neg(1.270), mul(X1, X0))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(log(neg(1.971)), pow(X0, 3.051)))), mul(3.241, X2)))
# sin(sub(add(pow(X1, 3.336), mul(neg(X0), pow(X1, 3.953))), mul(3.241, X2)))
#
#    3     9.93      3.30674e+15       15          201.651          201.657      1.30m
#    4    12.35      2.71151e+09       17          194.458          194.866     41.18s
#
# promising programs:
# mul(X0, neg(add(sub(mul(log(3.887), neg(0.072)), sin(sin(sub(sub(pow(X1, 0.882), mul(3.241, X2)), sin(pow(X1, 3.949)))))), mul(mul(X1, X0), pow(X1, 3.570)))))
# sub(sin(sin(sub(sub(pow(log(neg(X2)), 0.882), mul(3.241, X2)), X1))), mul(pow(X1, 3.952), pow(X0, 2.827)))
# add(mul(neg(pow(X1, 3.760)), pow(X0, 1.420)), sin(sub(mul(log(X1), neg(1.999)), mul(3.241, X2))))
# sub(sin(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, neg(X1))), pow(X0, 0.289))))), mul(pow(X1, 3.952), mul(X0, X0)))
# sub(sin(add(sub(sin(sub(sub(pow(X1, 0.882), mul(3.241, X2)), X1)), pow(X1, 2.443)), X1)), mul(pow(X1, 3.952), mul(X0, X0)))
# sub(sin(sub(sin(mul(3.314, X2)), mul(3.241, X2))), mul(pow(X1, 3.952), mul(X0, X0)))
# neg(sub(pow(mul(X1, X0), 3.924), sin(sin(sub(mul(pow(X1, 2.415), mul(sub(X0, X0), neg(X1))), mul(3.241, X2))))))
# neg(sub(pow(mul(X1, X0), 3.924), sin(sin(sub(neg(mul(0.080, X0)), mul(3.241, X2))))))
# sub(sin(sin(sub(log(X0), mul(3.241, X2)))), mul(pow(X1, 3.952), mul(X0, X0)))
# sub(sin(sub(mul(3.139, X2), neg(pow(X1, 3.760)))), neg(sub(sub(sub(X2, X2), pow(X1, 3.925)), log(0.968))))
# neg(sub(mul(pow(X1, 3.549), pow(X0, pow(X1, 2.148))), sin(sub(sub(0.473, pow(sin(X1), 1.733)), mul(3.241, X2)))))
# sub(sin(sub(sub(sin(sub(pow(X1, 0.920), sub(X2, X2))), pow(X1, 0.646)), mul(3.241, X2))), mul(pow(X1, 3.952), mul(X0, X0)))
# neg(sub(mul(pow(X0, 0.502), pow(X1, 3.660)), sin(sin(sub(sin(sub(sub(log(1.181), log(X1)), mul(X1, X1))), mul(3.241, X2))))))
# neg(sub(mul(X1, pow(X1, 3.246)), sin(sin(sub(mul(3.139, X2), sub(sub(2.080, X1), add(X1, X1)))))))
# sub(sin(sub(neg(log(X1)), mul(3.241, X2))), pow(mul(mul(X1, X1), X0), 3.828))
#
#    5    14.51      2.48277e+09       31          162.345          161.675      0.00s
#
# D-CODE model:  X0*(C - X0*X1**C - sin(sin(C*X2 - X1**C + sin(X1**C))))
#
# building blocks:
# X1**3.3630855414679175
# -sin(X1 - 2.988101990757486*X2)
# sin(sin(log(X1)))
# sin(log(X1))
# X1**0.8823768547569695
# X0**1.4204037111558676
# X0**0.28887042172271554
# X2**(-X1)
# X0**0.502385516788158
#
# number of building blocks:  9
#
# T0: 27, T: 42
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.63665495 1.60186102 1.54970284 1.49061992 1.42669263 1.35627302
#  1.27901776 1.19753964 1.11558444 1.03561269 0.95838385 0.88446122
#  0.81553616 0.75404231 0.70166529 0.65851867 0.62382026 0.59717786
#  0.57908434 0.5703053 ]
# [0.88734271 0.91799521 0.94672176 0.97609638 1.0056959  1.03404731
#  1.06017515 1.08381173 1.10470389 1.12207306 1.13480827 1.14211313
#  1.14396481 1.14105482 1.13437496 1.12479835 1.1128631  1.09878264
#  1.08264815 1.06475671]
# [26.99292461 27.12783828 27.11538942 27.12103563 27.17983647 27.25604945
#  27.31458999 27.35358481 27.39191476 27.44226616 27.50042212 27.55527048
#  27.60256741 27.64731186 27.69580113 27.74865768 27.80178047 27.8519447
#  27.89989571 27.94844243]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      2.54533e+25        6          204.357          203.524      2.63m
#    1     6.71      9.26962e+12        6          204.142          205.467      2.16m
#    2     7.76      6.88917e+12       18          180.252            182.3      1.82m
#
# promising programs:
# sin(sub(sin(neg(add(log(sin(X1)), sin(mul(pow(X0, 2.575), sin(sub(sub(neg(pow(X1, 3.757)), X0), mul(sin(X2), sub(X2, X0))))))))), mul(3.241, X2)))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(sin(add(X0, mul(X2, X1))), mul(3.241, X2)))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(neg(log(pow(X2, 0.796))), 2.288)))))
# sin(sub(sin(sin(sub(neg(sub(mul(X2, X1), sin(X0))), neg(pow(X1, 3.660))))), mul(3.241, X2)))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X2, 2.288)))))
# sin(neg(neg(neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), X1))))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, 2.288)))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 2.885)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
#
#    3     9.89      5.46504e+15       30          159.243          158.559      1.31m
#    4    11.99      5.68197e+09       25          125.194          124.901     40.72s
#
# promising programs:
# sub(mul(neg(sub(log(sin(X1)), X0)), sin(sub(sub(sin(sub(sin(pow(X1, 1.256)), mul(3.241, X2))), X0), mul(sin(X2), sub(X2, X0))))), sin(mul(3.241, X2)))
# sub(mul(neg(sub(log(sin(X1)), X0)), sin(sub(sub(sub(X0, X0), X0), mul(sin(X2), sub(X2, X0))))), sin(mul(3.241, X2)))
# sub(mul(neg(sub(log(sin(X1)), X0)), sin(sub(sub(sub(X0, X0), X0), mul(sin(X2), sub(X2, X0))))), sin(mul(3.241, X2)))
# sub(mul(neg(sub(log(sin(X1)), X0)), sin(sub(sub(sin(X0), X0), mul(sin(X2), sub(X2, X0))))), sin(mul(3.241, X2)))
# sub(mul(neg(sub(log(sin(X1)), X0)), sin(sub(sub(sin(sub(sub(pow(X1, 3.138), X1), mul(3.241, X2))), X0), mul(sin(X2), sub(X2, X0))))), sin(mul(3.241, X2)))
# sin(sub(mul(X1, mul(neg(mul(X1, log(1.896))), sub(log(mul(1.506, X1)), mul(pow(X0, 2.575), sin(sub(sub(pow(X1, 2.384), X0), mul(sin(X2), sub(X2, X0)))))))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(neg(sub(mul(X2, X1), sub(sub(sub(mul(3.139, X2), pow(X2, 2.885)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), neg(pow(X1, 3.660))))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(neg(sub(mul(X2, X1), sub(sub(sub(mul(3.139, X2), pow(X2, 2.885)), pow(X2, 3.241)), sin(pow(X1, 2.288))))), neg(pow(X1, 3.660))))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(neg(sub(mul(X2, X1), sub(sub(sub(mul(3.139, X2), pow(X2, 2.885)), pow(X2, 0.640)), sin(pow(X1, 2.288))))), neg(pow(X1, 3.660))))), mul(3.241, X2)))
# sin(sub(mul(sin(pow(X1, 0.429)), sin(add(sub(sin(sub(sub(sin(sin(X1)), X0), mul(sin(X2), sub(X2, X0)))), pow(X1, 3.925)), pow(X1, 3.452)))), mul(3.241, X2)))
# sin(sub(sin(neg(add(log(sin(X1)), sin(mul(pow(X0, 2.575), sin(sub(sub(neg(pow(X1, 3.757)), X0), mul(sin(X2), sub(X2, X0))))))))), mul(3.241, X2)))
# sin(sub(mul(neg(sub(sin(sub(mul(2.988, X2), X1)), X0)), sin(sub(sub(pow(X2, 0.085), X0), mul(sin(X2), sub(X2, X0))))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(sub(sub(X2, X0), X0), mul(sin(X2), sub(X2, X0))))), mul(3.241, X2)))
# sin(sub(sin(sub(mul(2.988, X2), X1)), sin(mul(3.241, X2))))
# sin(sub(sin(mul(X0, sin(add(X0, mul(X2, X1))))), mul(3.241, X2)))
#
#    5    12.66      5.04997e+09       31          111.425          109.132      0.00s
#
# D-CODE model:  (-X0 + log(sin(X1)))*sin(X0 + (-X0 + X2)*sin(X2) + sin(C*X2 - sin(X1**C))) - sin(C*X2)
#
# building blocks:
# X1**3.7565039934876245
# X1**0.8823768547569695
# X2**0.6395216888991612
# sin(X0 + X1*X2)
# log(X2**0.796421088263547)
# X2**0.796421088263547
# sin(3.2410061383495*X2)
# X1**1.2561710702941271
# log(sin(X1))
# sin(sin(X1))
# sin(X1**0.4290098192325041)
# -sin(X1 - 2.988101990757486*X2)
# X2**0.08525667547259062
#
# number of building blocks:  13
#
# T0: 29, T: 44
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.10257576 1.08150237 1.04863091 1.01067788 0.9690735  0.92306847
#  0.87290191 0.82064068 0.76882787 0.71894834 0.6713432  0.62634411
#  0.58515905 0.54957515 0.52097792 0.49982867 0.48603466 0.47960802
#  0.48085712 0.49008164]
# [0.98864171 1.00186054 1.01054503 1.01758559 1.02288267 1.02554942
#  1.02525813 1.02218304 1.01640545 1.00775176 0.99612577 0.98175173
#  0.96501787 0.9462191  0.9255825  0.90350504 0.88063225 0.85764763
#  0.83503643 0.81308632]
# [28.99097541 29.13425847 29.11768197 29.11990129 29.1794191  29.25807657
#  29.31780873 29.35608412 29.39302017 29.44253748 29.50056192 29.55542538
#  29.60253362 29.64702265 29.69538748 29.7481295  29.8008922  29.8504978
#  29.89809568 29.94682169]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.69105e+25       20          97.2711           97.077      2.64m
#    1     6.89      1.25897e+13       20          97.2474            97.29      2.19m
#    2     8.14      9.59312e+12       18          77.1952           77.136      2.05m
#
# promising programs:
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# neg(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, 2.288)))))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X1, 0.016)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(add(0.586, sin(pow(X1, 3.442)))))
# sin(sub(sub(pow(X1, 2.170), add(sin(log(X2)), X1)), mul(3.241, X2)))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(mul(3.139, X2))
# sin(add(sub(log(X1), log(mul(X1, X2))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182))))
# sin(sin(mul(3.139, X2)))
# sin(sub(neg(sin(log(X2))), mul(3.241, X2)))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))), neg(X1))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(sin(log(mul(X1, X2))), 0.640)), pow(X1, 0.178))), neg(0.681))
# sin(sub(sub(log(X1), neg(0.465)), mul(3.241, X2)))
# sin(sub(sub(log(X1), neg(0.465)), mul(3.241, X2)))
# mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(add(X0, X1)))), neg(0.681))
#
#    3     9.91      8.89274e+15       16          67.4079          67.2534      1.52m
#    4    11.41      1.25735e+10       16          67.3722          67.5743     45.45s
#
# promising programs:
# sin(sub(pow(X1, sin(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, sin(log(sub(add(mul(X2, mul(3.139, X2)), X1), sin(neg(sub(pow(X0, 1.085), pow(X2, 1.819)))))))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(0.099, sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(X1))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X1, 0.016))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, sin(log(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, X1))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(sub(pow(X1, 0.882), sub(sub(mul(3.139, X2), pow(X2, 0.640)), pow(X2, 0.640))))
#
#    5    13.69      1.22676e+10       27          64.6679          64.4484      0.00s
#
# D-CODE model:  sin(-C*X2 + X1**sin(C*X2 - 2*X2**C) + 2*X2**C)
#
# building blocks:
# X2**1.8842541798778392
# X1**0.8823768547569695
# X2**0.6395216888991612
# sin(log(X2))
# sin(3.1394689809108645*X2)
# log(X1*X2)
# sin(X0 + X1)
# X1**0.01618881769529612
# X2**X1
#
# number of building blocks:  9
#
# T0: 31, T: 46
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# [1.40477666 1.40836686 1.39688931 1.37797306 1.35370782 1.32368808
#  1.28820434 1.24911592 1.20859819 1.16781625 1.12705024 1.08686155
#  1.04878787 1.01480199 0.98625326 0.9634985  0.94653436 0.93583169
#  0.93245647 0.93740957]
# [0.65463604 0.66004476 0.66371865 0.66820977 0.67312706 0.67701886
#  0.67904393 0.67943599 0.6789507  0.67811431 0.67686357 0.67464002
#  0.67076468 0.66493308 0.65759307 0.64983738 0.64267242 0.63616322
#  0.62932771 0.62109745]
# [30.99059528 31.13707076 31.11567582 31.1155519  31.17638383 31.25705032
#  31.31739258 31.35526615 31.39223343 31.44282707 31.50230117 31.55790509
#  31.60452007 31.64759349 31.69446315 31.74651044 31.79979943 31.85076655
#  31.89949557 31.94812601]
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.67933e+25        8            163.2          163.615      3.21m
#    1     7.54      3.92332e+16        8          160.393          160.448      2.70m
#    2     8.42      9.76891e+12        8          148.477          148.115      2.05m
#
# promising programs:
# sin(sub(add(log(sin(X0)), log(pow(X2, 2.078))), mul(3.241, X2)))
# sin(sub(mul(mul(add(X0, X0), log(X1)), sub(sub(0.717, X1), sin(X1))), mul(3.241, X2)))
# sin(sub(neg(sin(3.568)), mul(3.241, X2)))
# sin(sub(neg(sin(3.568)), mul(3.241, X2)))
# sin(sub(log(pow(X2, 2.428)), mul(3.241, X2)))
# sin(sub(log(log(sub(X2, X2))), mul(3.241, X2)))
# sin(sub(0.630, mul(3.241, X2)))
# sin(sub(mul(mul(add(X0, X0), log(X1)), sub(log(X0), 0.919)), mul(3.241, X2)))
# sin(sub(log(add(X0, X1)), mul(3.241, X2)))
# sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), pow(X2, 3.392))))
# sin(sub(pow(sin(2.488), 0.882), mul(3.241, X2)))
# sin(sub(log(1.934), mul(3.241, X2)))
# sin(sub(mul(sub(sub(neg(log(sub(X2, X1))), pow(X1, 3.314)), X1), neg(0.072)), mul(3.241, X2)))
# sin(sub(3.434, sub(pow(neg(3.336), 0.882), mul(3.241, X2))))
# sin(sub(sub(sub(sub(X0, X1), log(X0)), log(X1)), mul(3.241, X2)))
#
#    3    10.10      8.83024e+15       13          140.892          140.772      1.46m
#    4    11.68      6.48259e+09       13          131.731          132.744     44.68s
#
# promising programs:
# sub(sin(sin(sub(0.640, mul(3.241, X2)))), log(mul(X0, X1)))
# sub(sin(sub(pow(X1, 0.882), mul(3.241, X2))), log(mul(X0, X1)))
# sub(sin(sub(pow(X1, 0.882), mul(3.241, X2))), log(mul(X0, X1)))
# sub(sin(sub(pow(X1, 0.882), mul(3.241, X2))), log(mul(X0, X1)))
# neg(sub(mul(log(3.887), sin(mul(add(X2, X2), pow(X0, 0.767)))), sin(sin(sub(sin(pow(X2, 3.996)), mul(3.241, X2))))))
# sin(sub(sin(add(add(pow(X2, 2.509), neg(sin(mul(3.241, X2)))), add(pow(X0, 0.616), sin(mul(X2, X0))))), mul(3.241, X2)))
# sin(sub(sin(mul(X0, mul(mul(pow(X0, 2.880), log(2.896)), pow(X1, 3.863)))), mul(3.241, X2)))
# sin(sub(pow(sub(0.793, mul(pow(X1, 1.671), add(sin(X2), mul(0.915, X1)))), 0.882), mul(3.241, X2)))
# sin(sub(pow(sin(sin(sin(sub(sub(X0, log(X2)), log(neg(X2)))))), 0.882), mul(3.241, X2)))
# neg(sin(sub(sub(mul(3.241, X2), sub(X1, X1)), sin(add(sin(sub(sub(X0, mul(3.241, X2)), mul(3.241, X2))), X0)))))
# sin(sub(sin(X0), sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640))))
# sin(add(mul(3.241, X2), neg(log(sub(X2, X1)))))
# sin(sub(mul(3.241, X2), log(X2)))
# sin(sub(mul(3.241, X2), log(X2)))
# sin(sub(neg(sub(neg(log(1.121)), sin(mul(mul(add(X0, X0), log(X1)), sub(sub(0.717, X1), sin(X1)))))), mul(3.241, X2)))
#
#    5    11.24      6.48932e+09       12           128.95          128.958      0.00s
#
# D-CODE model:  -log(X0*X1) - sin(sin(C*X2 - C))
#
# building blocks:
# log(sin(X0))
# X2**2.077932084261351
# log(X2**2.4279431152383992)
# -sin(3.2410061383495*X2 - 0.6296438776739179)
# log(X0 + X1)
# X2**0.6395216888991612
# log(-X1 + X2)
# log(X0*X1)
# X1**0.8823768547569695
# X0**0.7666759256367731
# sin(3.2410061383495*X2)
#
# number of building blocks:  11

# %%
#D-CODE series 5:

# setting:
ode_name = 'OscillatingSelkovODE' # help="name of the ode", type=str
ode_param = '0.8,0.1' # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

T0s = [23, 25, 27, 29, 31, 33]
Ts = [33, 35, 37, 39, 41, 43]

for T0, T in zip(T0s, Ts):
    print(f'T0: {T0}, T: {T}')
    D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed, T0=T0, T=T)
# Out:
# T0: 23, T: 33
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 22.995080990368738
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      3.35611e+24       17           230.51          231.383      2.83m
#    1     5.72      5.65459e+09        7          205.996          205.858      2.07m
#    2     6.33      1.34453e+12       21          193.367          193.513      1.58m
#
# promising programs:
# neg(mul(sin(X2), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), neg(sin(X2)))), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# sin(sub(mul(log(pow(X0, 1.722)), sin(log(mul(sin(pow(X0, 3.445)), sin(pow(X2, 2.889)))))), mul(3.241, X2)))
# sin(sub(sin(sin(mul(sin(log(pow(X0, 3.827))), neg(mul(sub(X1, X2), sub(X0, X1)))))), mul(3.241, X2)))
# sin(sub(neg(neg(sin(add(sub(neg(X1), pow(X2, 2.935)), mul(log(2.840), pow(X0, 2.842)))))), mul(3.241, X2)))
# sin(sub(sin(sub(pow(log(X1), 0.882), mul(3.241, X2))), mul(3.241, X2)))
# sin(sub(add(log(X0), mul(X0, sin(log(X1)))), mul(3.241, X2)))
# sin(sub(sin(log(mul(X1, X0))), mul(3.241, X2)))
# sin(sub(sin(log(sub(sub(X0, X1), sin(mul(log(X1), pow(X0, 3.945)))))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(pow(X1, 0.882), mul(3.241, X2)))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(pow(X1, 0.882), mul(3.241, X2)))), mul(3.241, X2)))
# sin(sub(sin(sin(sub(pow(X1, 0.882), mul(3.241, X2)))), mul(3.241, X2)))
# sin(sub(sin(sub(pow(X1, 0.882), mul(3.241, X2))), mul(3.241, X2)))
# sin(sub(mul(sin(log(mul(sin(pow(X2, 3.252)), X0))), pow(X1, X0)), mul(3.241, X2)))
# sin(sub(sin(sub(pow(X1, X2), mul(3.241, X2))), mul(3.241, X2)))
#
#    3     9.42      2.24403e+15       14          160.736          164.534      1.28m
#    4    12.41      1.32853e+09       15          157.666          156.645     39.79s
#
# promising programs:
# neg(mul(sin(add(add(mul(3.241, X2), add(X1, X2)), neg(sin(X2)))), mul(add(pow(X0, 0.880), sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(mul(3.241, X2), add(X1, X2)), neg(sin(X2)))), mul(add(pow(X0, 0.880), sub(X2, X0)), sin(mul(X2, X2)))))
# mul(sub(sin(sin(sub(sin(sub(sin(sin(sub(0.119, mul(3.241, X2)))), mul(3.241, X2))), mul(3.241, X2)))), sin(mul(log(X1), pow(X0, 3.945)))), mul(X0, X1))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), log(X1))), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(log(X1), add(X1, X2)), neg(sin(X2)))), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), neg(mul(0.486, X1)))), mul(add(pow(X0, 0.880), sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(X2), mul(add(X0, sub(X2, mul(pow(X0, 3.625), sub(mul(pow(X0, 3.625), log(sin(X0))), sin(mul(3.241, X2)))))), sin(mul(X2, X2)))))
# neg(mul(sin(sin(X2)), mul(add(X0, sub(X2, 1.403)), sin(mul(X2, X2)))))
# neg(mul(sin(sin(X2)), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(sin(X2)), mul(add(X0, sub(X2, 3.322)), sin(mul(X2, X2)))))
# neg(mul(sin(sin(X2)), mul(add(X0, sub(X2, sub(X0, X1))), sin(mul(X2, X2)))))
# neg(mul(sin(sin(X2)), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), neg(sin(sin(neg(mul(3.241, X2))))))), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), sin(mul(3.241, X2)))), mul(add(pow(X0, 0.880), sub(X2, X0)), sin(mul(X2, X2)))))
# neg(mul(sin(add(add(neg(X1), add(X1, X2)), neg(mul(3.241, X2)))), mul(add(X0, sub(X2, X0)), sin(mul(X2, X2)))))
#
#    5    12.40      2.86914e+09       26          138.167          140.181      0.00s
#
# D-CODE model:  (X0 - X0**C - X2)*sin(X2**C)*sin(C*X2 + X1 - sin(X2))
#
# building blocks:
# sin(X2**2)
# log(X0**3.826774906266134)
# sin(log(X1))
# sin(log(X0*X1))
# log(X0*X1)
# X1**0.8823768547569695
# X1**X0
# X1**X2
# X0**0.8804243836000308
# sin(3.2410061383495*X2)
# log(sin(X0))
# sin(sin(X2))
# -sin(3.2410061383495*X2)
#
# number of building blocks:  13
#
# T0: 25, T: 35
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 24.991679275871984
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34       2.2193e+23       17          462.306          465.276      2.73m
#    1     6.48      5.75821e+08       15          432.683          433.212      2.12m
#    2     6.21      1.46747e+10       17          407.134          406.402      1.99m
#
# promising programs:
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(sin(X0)), pow(X0, 3.314)), sub(sin(sub(neg(pow(X1, 3.760)), mul(3.241, X2))), sin(add(pow(X1, 3.386), pow(X0, 2.431))))))
# sub(pow(X0, mul(2.194, X0)), sin(mul(neg(1.583), add(sub(X1, X1), add(X2, X2)))))
# sub(pow(X0, mul(2.194, X0)), sin(mul(neg(1.583), add(sub(X1, X1), add(X2, X2)))))
# sub(pow(X0, mul(2.194, X0)), sin(mul(neg(1.583), add(sub(X1, X1), add(X2, X2)))))
# sub(pow(X0, mul(2.194, X0)), sin(mul(neg(1.583), add(sub(X1, X1), add(X2, X2)))))
# mul(sub(mul(sin(pow(X0, 3.955)), sin(sin(neg(X2)))), sub(log(X2), sub(neg(sin(sub(pow(X1, X1), mul(X2, X2)))), sub(mul(neg(sin(X0)), mul(add(X0, X1), mul(X0, X0))), neg(sin(sin(X1))))))), X0)
# sub(pow(X0, pow(X0, 2.547)), sin(mul(neg(1.583), add(sub(X1, X1), add(X2, X2)))))
# sub(pow(X0, 3.447), sub(neg(neg(3.628)), sin(sub(neg(pow(X1, 3.760)), mul(3.241, X2)))))
# sub(pow(X0, 3.447), sub(neg(sin(mul(X1, mul(X0, pow(X0, 3.657))))), add(sub(pow(X0, 2.466), log(X0)), sin(sub(X2, X1)))))
# add(pow(X0, 3.989), log(log(log(sin(neg(X2))))))
# sub(neg(sin(sub(mul(neg(X2), X1), pow(X0, 2.852)))), add(sub(sin(add(sin(X0), X2)), sub(add(pow(X0, 3.829), X0), neg(sin(mul(X2, X2))))), sin(log(sub(mul(X0, X2), pow(X0, 3.744))))))
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(log(X1), mul(add(X0, X1), mul(X0, X0))), neg(sin(sub(pow(X1, X1), mul(X2, X2))))))
# add(pow(X0, 3.966), log(log(log(sin(neg(X2))))))
# add(sub(add(pow(X0, 3.693), X0), neg(sin(mul(X2, X2)))), sin(sin(log(sin(neg(add(add(2.724, X1), sin(sub(pow(X1, 3.152), mul(X2, X2))))))))))
# sub(neg(sin(sub(pow(X1, X1), mul(X2, X2)))), sub(mul(neg(sin(X0)), mul(add(X0, X1), mul(X0, X0))), neg(sin(sub(pow(X1, 3.152), mul(X2, X2))))))
#
#    3    10.47       2.1801e+14       36          381.687          381.831      1.39m
#    4    16.12      7.25671e+07       10            308.5          326.792     49.19s
#
# promising programs:
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(add(X1, X0)), mul(sin(mul(X2, X2)), add(pow(X0, pow(X0, 2.548)), X0))), neg(sin(mul(X0, X0)))))
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(sin(mul(X2, X2))), X2), neg(sin(sin(X1)))))
# mul(sin(mul(X2, X2)), add(pow(X0, pow(X0, 3.349)), X0))
# mul(sin(mul(X2, X2)), add(X2, X0))
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(sin(mul(X2, X2))), mul(add(X0, X1), add(sin(log(X2)), pow(X0, 3.791)))), neg(sin(sin(X1)))))
# add(sub(add(mul(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), pow(X0, 3.727)), X0), neg(sin(mul(X2, X2)))), add(sin(sub(pow(X0, 3.106), sub(3.293, X2))), neg(neg(pow(X0, 3.959)))))
# sub(mul(sub(mul(add(neg(sin(sub(pow(X1, sin(pow(X0, 3.625))), mul(X2, X2)))), mul(X0, pow(X0, 3.104))), sin(sin(mul(X2, X2)))), sub(X0, pow(X0, 3.582))), X0), neg(sin(mul(X2, X2))))
# neg(mul(add(pow(X0, 2.323), add(X0, X1)), sub(pow(X0, 3.349), add(sub(add(pow(X0, 3.350), X0), neg(sin(mul(X2, X2)))), sin(mul(X2, X2))))))
# add(sub(pow(X0, 3.867), neg(mul(sin(mul(X2, X2)), add(pow(X0, 3.578), 3.902)))), sin(sin(pow(X1, 0.458))))
# add(sub(pow(X0, pow(X0, 2.413)), neg(mul(sin(mul(X2, X2)), add(pow(X0, 3.578), 3.902)))), sin(log(sub(sin(log(X0)), X0))))
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(neg(sin(sub(pow(X1, 3.152), mul(X2, X2))))), mul(add(X0, X1), pow(X0, 2.567))), neg(sin(sin(X1)))))
# add(sub(add(pow(X0, mul(2.194, X0)), X0), sub(mul(neg(sin(mul(X2, X2))), mul(add(X0, X1), pow(X0, 2.567))), neg(sin(sin(X1))))), sub(X0, X0))
# add(sub(pow(X0, 3.829), neg(mul(sin(mul(X2, X2)), add(pow(X0, 3.693), X0)))), sin(sin(pow(X0, 3.986))))
# sub(neg(sin(sub(pow(X1, 3.152), mul(X2, X2)))), sub(mul(neg(sin(mul(X2, X2))), mul(add(X0, X1), mul(X0, X0))), add(sin(pow(X0, 3.868)), pow(X0, 3.791))))
# sub(neg(sin(sub(pow(X1, pow(X0, 3.970)), mul(X2, X2)))), sub(mul(neg(sin(mul(X2, X2))), pow(X0, 3.314)), sub(sin(sub(neg(pow(X1, 3.760)), mul(3.241, X2))), sin(add(pow(X1, 3.386), pow(X0, 2.431))))))
#
#    5    21.12      4.32647e+11       33          185.436          178.493      0.00s
#
# D-CODE model:  (X0 + X0**(X0**C))*(X0 + X1)*sin(X2**C) - sin(X0**C) - sin(X1**C - X2**C)
#
# building blocks:
# X1**3.759656445339891
# X0**(2.194034619602884*X0)
# sin(sin(X1))
# X1**X1
# X0**(X0**2.5469649530806264)
# -sin(X1 - X2)
# -sin(X2)
# sin(X1**0.4576687854449333)
# log(-X0 + sin(log(X0)))
# sin(log(X0))
#
# number of building blocks:  10
#
# T0: 27, T: 37
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 26.99378201569408
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      6.55727e+24       20           219.18          220.836      2.66m
#    1     6.42      2.22043e+12        7          193.708          194.762      3.00m
#    2     7.66      1.71842e+12       11           189.31          188.303      1.80m
#
# promising programs:
# sin(sub(sub(mul(0.459, sin(add(neg(X2), pow(X2, 0.486)))), sin(pow(X0, 3.454))), mul(3.241, X2)))
# sin(sub(sin(neg(pow(X0, 3.649))), mul(3.241, X2)))
# sin(sub(sin(neg(pow(X0, 3.649))), mul(3.241, X2)))
# sub(mul(pow(X0, 2.436), sin(mul(sub(add(X1, X1), add(X0, X1)), mul(mul(X2, X0), sin(2.210))))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sin(sub(sub(neg(X1), mul(3.241, X2)), log(add(sub(X2, X0), sub(1.760, X2))))), X1)
# sin(sub(neg(sin(mul(log(X1), pow(X0, 3.945)))), mul(3.241, X2)))
# sub(mul(log(sin(2.247)), sub(pow(X1, 1.496), sin(mul(sin(pow(X1, 1.455)), X2)))), sin(mul(3.241, X2)))
# sin(sub(sin(add(sin(X2), mul(sin(neg(X2)), X2))), mul(3.241, X2)))
# sin(sub(sub(0.473, sin(pow(X0, 3.445))), mul(3.241, X2)))
# add(sin(sin(sub(neg(sub(mul(X2, X1), sin(X0))), mul(log(sin(X2)), sub(log(sin(2.224)), neg(X1)))))), sin(mul(3.535, X2)))
# add(sin(neg(sub(sin(X1), sin(mul(3.314, X2))))), sin(mul(3.535, X2)))
# sin(sub(mul(mul(add(X0, X0), log(X1)), sub(log(X0), pow(X1, 3.470))), mul(3.241, X2)))
# sin(sub(sin(sin(sin(mul(pow(X1, 3.307), sub(X1, X2))))), mul(3.241, X2)))
# sin(sub(mul(mul(add(X0, X0), log(X1)), sub(log(add(X1, X0)), sin(X1))), mul(3.241, X2)))
# sin(sub(sub(0.473, pow(X1, sin(sub(pow(X1, 2.945), mul(3.241, X2))))), mul(3.241, X2)))
#
#    3    10.67      3.31473e+15       19          172.725          173.184      1.59m
#    4    12.22      1.34802e+09       14          168.769          168.631     50.20s
#
# promising programs:
# sub(mul(pow(X0, 2.436), sin(mul(sub(sin(pow(X1, 2.593)), add(X0, X1)), mul(mul(X2, X0), sin(2.210))))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# sub(sin(sub(sin(mul(3.535, X2)), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), 0.640)))), sin(pow(X0, 3.454)))
# add(log(sin(mul(X0, X0))), sin(sin(sub(sub(0.473, pow(X1, 1.733)), mul(3.241, X2)))))
# add(sub(neg(0.715), sin(mul(log(X1), pow(X0, 3.945)))), sin(sin(sub(sin(log(sin(X0))), mul(3.241, X2)))))
# sub(mul(pow(X0, 2.436), sin(mul(add(X0, X1), mul(mul(X2, X0), sin(2.210))))), sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288)))))
# neg(sub(mul(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, 2.288)))), X0), sin(neg(pow(X0, 3.649)))))
# mul(sin(sin(sub(sin(mul(3.535, X2)), mul(3.241, X2)))), mul(X0, X0))
# mul(X0, sub(sin(sub(sin(sub(log(X1), mul(3.241, X2))), mul(3.241, X2))), sin(mul(log(X1), pow(X0, 3.945)))))
# neg(sub(sub(log(sin(2.247)), mul(sin(neg(X1)), X1)), sin(sub(sin(add(pow(X1, 0.891), mul(sin(neg(X2)), X2))), mul(3.241, X2)))))
# add(sub(neg(0.715), sin(mul(log(X1), pow(X0, 3.945)))), sin(sub(neg(X1), mul(3.241, X2))))
# sub(log(sin(mul(X0, X0))), sin(sub(sub(sub(mul(3.139, X2), pow(X0, 1.884)), pow(X2, 2.182)), sub(neg(X0), neg(1.239)))))
# add(log(sin(mul(X0, X0))), sin(sin(sub(sub(pow(X1, 0.882), mul(3.241, X2)), X1))))
# add(sin(sin(sub(neg(sub(mul(X2, X1), sin(X0))), mul(log(sin(X2)), sub(log(sin(2.224)), neg(X1)))))), sin(neg(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), sin(pow(X0, 1.141))), add(sub(X1, X1), pow(X1, 3.452))))))
# sin(sub(neg(sin(mul(sin(sin(X0)), pow(X0, 3.945)))), mul(3.241, X2)))
# sin(sub(neg(sin(mul(sin(sin(X0)), pow(X0, 3.945)))), mul(3.241, X2)))
#
#    5    13.69      7.22099e+09       38          145.287          138.988      0.00s
#
# D-CODE model:  X0**C*sin(C*X0*X2*(-X0 - X1 + sin(X1**C))) + sin(-C*X2 + 2*X2**C + sin(X1**C))
#
# building blocks:
# sin(X0**3.4537640046936846)
# X2**0.48594710942032954
# X2**0.6395216888991612
# sin(X1**1.454593403438689)
# -sin(X2)
# sin(3.5351494645756585*X2)
# log(X0 + X1)
# log(sin(X0**2))
# sin(log(sin(X0)))
# log(sin(X0))
# -sin(X1)
# X1**0.8913034902824555
# sin(sin(X0))
#
# number of building blocks:  13
#
# T0: 29, T: 39
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 28.990845851152525
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.31095e+25       20           179.02          177.579      3.76m
#    1     7.19      1.37198e+13        7           162.74          162.767      2.35m
#    2     9.34      3.38896e+12       15          161.617          161.512      2.28m
#
# promising programs:
# sin(sub(sub(log(X1), log(X2)), sub(mul(3.139, X2), sin(sub(mul(sub(neg(pow(X1, 0.022)), sub(3.561, X2)), log(pow(X0, 0.736))), sub(sin(neg(X2)), add(add(X0, X2), mul(2.235, X0))))))))
# neg(sin(add(sub(sub(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 0.640)), sin(pow(X1, 2.288))), X0), neg(X0)), neg(sin(pow(X0, 3.828))))))
# sin(sub(sin(mul(mul(neg(1.128), sub(log(X0), X0)), sub(sin(mul(X0, X2)), sub(mul(X1, X2), neg(X0))))), mul(3.241, X2)))
# sin(sub(sin(sin(mul(mul(X2, X0), log(2.323)))), mul(3.241, X2)))
# sin(sub(mul(sin(sub(sub(X0, X2), sub(X2, X2))), sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(X0, sub(sin(X1), mul(X0, X1)))))), mul(3.241, X2)))
# sin(sin(sub(sin(sin(sin(mul(sub(add(X1, X2), sub(neg(pow(X1, 2.071)), X1)), sin(log(X0)))))), mul(3.241, X2))))
# sin(sub(sin(sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(mul(log(1.941), mul(X1, X1)), sub(sin(X1), add(X1, X0)))))), mul(3.241, X2)))
# sin(sub(sin(add(sub(mul(X0, X2), sin(pow(X1, 2.965))), X2)), mul(3.241, X2)))
# sin(sub(mul(X1, mul(neg(mul(X1, log(1.896))), sub(log(mul(1.506, X1)), sin(pow(X0, 3.578))))), mul(3.241, X2)))
# sin(sub(mul(sin(sub(sub(X0, X2), sub(X2, X2))), sin(log(X1))), mul(3.241, X2)))
# sin(sub(sin(sub(X1, log(add(1.384, X0)))), mul(3.241, X2)))
# sin(neg(sub(sin(sub(sub(sub(mul(3.139, X2), pow(X2, 1.884)), pow(X2, 2.182)), sin(pow(X1, 2.288)))), sin(mul(3.314, X2)))))
# sin(sub(mul(sin(mul(2.714, X0)), add(log(2.790), neg(X1))), mul(3.241, X2)))
# sin(sub(mul(sin(mul(2.714, X0)), add(log(2.790), neg(X1))), mul(3.241, X2)))
# sin(sub(mul(sin(mul(2.714, X0)), add(log(2.790), neg(X1))), mul(3.241, X2)))
#
#    3    12.12      2.44977e+15       37          154.003          154.037      1.66m
#    4    13.05      2.65652e+09       17          145.641          145.137     41.14s
#
# promising programs:
# sub(sin(sub(pow(X1, 3.738), mul(sub(sin(2.636), mul(3.241, X2)), neg(add(0.058, X2))))), sin(mul(3.241, X2)))
# sin(sub(sin(sub(mul(sub(neg(log(2.660)), sub(3.561, X2)), log(pow(X0, 0.736))), sub(sin(sub(X2, X0)), add(add(X0, X2), mul(2.235, X0))))), mul(3.241, X2)))
# sin(sub(mul(sin(sin(mul(sub(X2, X0), add(X0, X1)))), X0), mul(3.241, X2)))
# sin(sub(sin(sub(mul(sub(neg(log(2.660)), sub(3.561, X2)), log(pow(X0, 0.736))), sub(sin(neg(log(1.121))), add(add(X0, X2), mul(2.235, X0))))), mul(3.241, X2)))
# sin(sub(sin(sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(mul(log(1.941), mul(X1, X1)), sub(neg(sub(X2, X2)), sin(mul(3.314, X2))))))), mul(3.241, X2)))
# sin(sub(sin(sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(mul(log(1.941), mul(X1, X1)), sub(sin(sub(neg(0.186), mul(3.241, X2))), sin(mul(3.314, X2))))))), mul(3.241, X2)))
# sin(sub(sin(sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(mul(log(1.941), add(add(X1, X0), sub(X2, X2))), sub(sin(X1), sin(mul(3.314, X2))))))), mul(3.241, X2)))
# sin(sub(mul(sin(sub(add(pow(X1, 1.477), log(X0)), sub(X2, X2))), sin(mul(sin(mul(mul(X2, X0), log(2.323))), sub(X0, sub(sin(X1), sin(sub(pow(X1, 0.882), mul(3.241, X2)))))))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(sin(X1)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(pow(X1, 3.442)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(pow(X1, 3.442)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(pow(X1, 3.442)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(pow(X1, 3.442)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(sin(add(mul(add(X0, X2), log(X0)), mul(mul(sin(pow(X1, 3.442)), neg(X1)), log(X1)))), mul(3.241, X2)))
# sin(sub(neg(mul(mul(sin(sub(mul(sub(X1, X0), add(X2, X1)), sin(pow(X1, pow(X1, 2.054))))), neg(0.681)), neg(mul(sin(X0), sin(X0))))), mul(3.241, X2)))
#
#    5    14.16      6.86828e+07       21          144.321          145.762      0.00s
#
# D-CODE model:  -sin(C*X2) + sin(X1**C - (-C - X2)*(-C*X2 + C))
#
# building blocks:
# X0**3.8278655382866287
# sin(log(X0))
# sin(log(X1))
# sin(3.3140172432269743*X2)
# sin(2.714444910888955*X0)
# X0**0.7358232429926678
# -sin(X0 - X2)
# sin(sin(X1))
#
# number of building blocks:  8
#
# T0: 31, T: 41
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 30.990576361917363
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      1.30776e+25       11          250.798          250.586      2.68m
#    1     6.73      1.14941e+14       11           238.78          238.807      2.08m
#    2     7.88      1.00102e+11       11           238.76          238.978      1.78m
#
# promising programs:
# mul(mul(neg(add(mul(X1, X0), neg(X0))), sin(add(add(sub(add(X1, X2), log(X0)), sub(mul(3.086, X2), mul(X0, X1))), pow(X1, 0.080)))), log(log(log(sin(sin(mul(sub(sin(sub(X0, X1)), neg(add(add(X1, X2), pow(X0, 0.433)))), pow(X0, 1.272))))))))
# sin(sub(sin(mul(neg(pow(X0, 3.148)), sin(sin(sin(sub(log(mul(mul(X0, X0), X1)), sin(sub(log(X0), log(X1))))))))), mul(3.241, X2)))
# mul(neg(pow(X0, 1.709)), mul(sub(sin(add(pow(X1, 2.338), add(sub(1.651, mul(X2, X0)), X2))), log(X1)), neg(sin(mul(3.100, X1)))))
# neg(sub(mul(neg(sin(sin(mul(log(X0), neg(X2))))), mul(log(X1), neg(1.999))), sin(mul(3.314, X2))))
# neg(mul(sin(add(add(sub(add(X1, X2), log(neg(log(X1)))), sub(mul(3.086, X2), pow(X0, 1.920))), pow(X1, 0.080))), sub(log(X1), X0)))
# sin(sub(mul(mul(neg(add(mul(X1, X0), neg(X0))), sin(mul(sin(X0), mul(X0, X0)))), log(log(log(neg(X2))))), mul(3.241, X2)))
# mul(mul(neg(add(mul(X1, X0), neg(X0))), sin(mul(sin(X0), sub(X2, add(log(X1), pow(X2, 0.081)))))), log(log(log(sin(mul(log(X0), sub(X1, X2)))))))
# sin(sub(sin(mul(sub(sub(sub(X2, X1), sub(1.009, X0)), mul(add(0.039, X1), sub(2.891, X0))), pow(X0, 0.767))), mul(3.241, X2)))
# sin(sub(mul(sub(log(X1), sub(X0, X1)), log(mul(X1, X1))), mul(3.241, X2)))
# sub(sin(add(add(pow(X2, 2.509), neg(sin(X2))), add(pow(X0, 0.616), sin(mul(X2, X0))))), sin(add(log(sin(pow(X1, sin(sin(sin(sub(1.654, X2))))))), mul(3.241, X2))))
# sin(sub(neg(log(pow(X1, sub(X1, mul(add(X0, X0), log(X1)))))), mul(3.241, X2)))
# neg(mul(sub(sin(add(add(pow(X2, 2.509), neg(sin(X2))), add(pow(X0, 0.616), sin(mul(X2, X0))))), sin(add(log(sin(pow(X1, sin(sin(sin(pow(X0, 3.815))))))), sub(sub(log(X2), pow(X1, 3.110)), mul(log(X0), sin(X1)))))), sub(log(X1), X0)))
# sin(sub(neg(mul(add(neg(X0), sub(0.305, X0)), sub(sin(X0), X1))), mul(3.241, X2)))
# sin(sub(neg(mul(neg(log(X1)), sub(log(X1), X0))), mul(3.241, X2)))
# sin(sub(mul(log(log(sub(mul(add(log(2.967), X1), add(X1, X1)), sin(pow(X2, 1.832))))), sub(sin(mul(sin(log(X0)), log(sub(X1, X1)))), sub(X0, X1))), mul(3.241, X2)))
#
#    3    11.40      4.07679e+15       50          207.037            208.3      1.28m
#    4    13.55       9.2839e+09       33          197.899          197.977     42.34s
#
# promising programs:
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), add(log(3.931), X1))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sub(sin(add(add(pow(X2, 2.509), neg(sin(X2))), add(pow(X0, 0.616), sin(mul(X2, X0))))), sin(add(log(sin(pow(X1, 2.145))), mul(3.241, X2)))), log(X1)))))
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), sin(sub(sin(mul(neg(pow(X0, 3.148)), sin(sin(sin(sub(log(mul(mul(X0, X0), X1)), sin(sub(log(X0), log(X1))))))))), mul(3.241, X2))))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sin(mul(sin(X1), sin(mul(3.314, X2)))), log(X1)))))
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), add(log(3.931), X1))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sin(mul(sin(X1), sin(mul(3.314, X2)))), log(X1)))))
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), add(log(3.931), X1))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sin(mul(sin(X1), sin(mul(3.314, X2)))), log(X1)))))
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), add(log(3.931), X1))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sin(mul(sin(X1), sin(mul(3.314, X2)))), log(X1)))))
# mul(sub(neg(pow(X0, 3.350)), mul(log(log(3.113)), add(log(3.931), X1))), sub(log(mul(mul(X0, X0), X1)), sin(sub(sin(mul(sin(X1), sin(mul(3.314, X2)))), log(X1)))))
# mul(sub(sin(add(sub(log(add(X0, X0)), sub(log(X1), sin(sub(X2, X1)))), sub(neg(neg(X2)), mul(sin(X0), mul(X0, X2))))), mul(log(X1), log(3.124))), sub(X0, sin(log(X1))))
# neg(sub(mul(sin(mul(neg(X2), sub(0.505, X0))), mul(add(neg(X0), sub(0.305, X0)), sub(sin(X0), X1))), sin(mul(3.314, X2))))
# neg(sub(mul(sin(mul(neg(X2), sub(0.505, X0))), mul(add(neg(X0), sub(0.305, X0)), sub(sin(X0), X1))), sin(mul(3.314, X2))))
# neg(sub(mul(sin(mul(neg(X2), sub(0.505, X0))), mul(add(neg(X0), sub(0.305, X0)), sub(sin(X0), X1))), sin(mul(3.314, X2))))
# sin(sub(mul(sin(sub(sub(X0, sin(X1)), sub(X2, X2))), mul(mul(neg(add(mul(X1, X0), neg(X0))), sin(mul(sin(X0), mul(X0, X0)))), log(log(log(sin(mul(log(X0), sub(X1, X2)))))))), mul(3.241, X2)))
# mul(sub(sin(add(sub(log(add(X0, X0)), sub(log(X1), sin(sub(X2, X1)))), sub(neg(neg(X2)), mul(sin(X0), mul(X0, X2))))), mul(log(X1), log(3.124))), sub(pow(X1, 0.371), neg(pow(X0, 3.350))))
# mul(neg(pow(X0, 1.709)), mul(sub(sin(add(pow(X1, sin(mul(3.314, X2))), add(sub(1.651, mul(X2, X0)), X2))), log(X1)), neg(sin(mul(3.100, X1)))))
# mul(neg(pow(X0, 1.709)), mul(sub(sin(add(pow(sin(sub(sub(pow(X1, 0.882), mul(3.241, X2)), X1)), 2.338), add(sub(1.651, mul(X2, X0)), X2))), log(X1)), neg(sin(mul(3.100, X1)))))
# mul(neg(pow(X0, 1.709)), mul(sub(sin(add(sin(sin(X0)), add(sub(1.651, mul(X2, X0)), X2))), log(X1)), neg(sin(mul(3.100, X1)))))
#
#    5    15.19       2.7013e+09       53          187.245          188.915      0.00s
#
# D-CODE model:  (log(X0**C*X1) + sin(log(X1) + sin(C*X2 + log(sin(X1**C))) - sin(X0**C + X2**C - sin(X2) + sin(X0*X2))))*(-C*X1 - C - X0**C)
#
# building blocks:
# X0**0.4334306144012471
# sin(X0 - X1)
# X1**0.08020983645230642
# X0**3.1477992004590765
# sin(3.3140172432269743*X2)
# -sin(X2*log(X0))
# log(-log(X1))
# X2**0.08110161226599467
# X0**0.7666759256367731
# log(X1**2)
# -sin(X2 - 1.653887470463329)
# -sin(sin(sin(X2 - 1.653887470463329)))
# -sin(sin(X2 - 1.653887470463329))
# log(X0**2*X1)
# -sin(X1 - X2)
# sin(log(X1))
# X1**0.371479443001005
# log(2*X0)
# sin(3.1003885276129344*X1)
# X1**0.8823768547569695
#
# number of building blocks:  20
#
# T0: 33, T: 43
# Running with: ode_name=OscillatingSelkovODE, ode_param=[0.8, 0.1], x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# (301, 50, 3)
# Dataset shape:  (301, 50, 3)
# 32.9905438181021
# Functions set:  {'sub': 1, 'mul': 1, 'add': 1, 'neg': 1, 'sin': 1, 'pow': 1, 'log': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     8.34      6.52278e+24       11           228.42          229.219      2.76m
#    1     6.92      3.93581e+10       11          210.673          210.246      2.21m
#    2     8.63      4.92959e+10       10          202.064          203.398      1.63m
#
# promising programs:
# neg(sub(log(pow(X1, 3.074)), sin(neg(mul(sin(mul(3.314, X2)), neg(X0))))))
# neg(sub(mul(pow(X0, 0.588), log(pow(X1, 3.771))), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.074)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.273)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 2.976)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.273)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.325)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.325)), sin(mul(3.314, X2))))
# sub(neg(sin(sub(sin(pow(X2, 0.407)), add(mul(3.314, X2), X1)))), mul(neg(log(X1)), neg(add(X0, X1))))
# neg(sub(log(pow(X1, 3.325)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.074)), neg(sub(mul(sub(X0, X1), neg(0.072)), sin(mul(3.314, X2))))))
# sub(sin(sub(X0, sub(mul(X1, X0), sin(mul(3.314, X2))))), sin(neg(mul(3.746, X1))))
# add(mul(neg(X0), log(pow(X1, 2.727))), sin(sub(0.860, mul(3.241, X2))))
# neg(sub(log(pow(X1, 3.645)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 2.617)), sin(neg(sub(mul(log(3.887), log(X1)), sin(mul(3.314, X2)))))))
#
#    3    11.95      3.81526e+15       15          199.609          199.633      1.22m
#    4    12.97      2.29048e+09       12           193.18          192.293     37.95s
#
# promising programs:
# add(mul(neg(log(X1)), pow(X0, 3.628)), add(sin(log(sin(mul(1.139, X2)))), sin(mul(3.314, X2))))
# mul(neg(sub(mul(log(3.887), log(X1)), sin(mul(3.314, X2)))), log(log(log(log(sub(X0, X1))))))
# add(mul(neg(log(X1)), pow(X0, 3.628)), add(sin(log(sin(mul(1.139, X2)))), sin(sub(sub(X0, X1), mul(3.241, X2)))))
# neg(sub(mul(sub(1.700, add(X1, X1)), mul(pow(X0, 2.965), neg(X0))), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 3.273)), sin(sub(sub(sin(sin(sub(mul(X2, pow(X1, 3.402)), pow(X1, 3.007)))), sin(log(pow(X1, 3.273)))), mul(3.241, X2)))))
# add(sin(sub(pow(X2, 3.070), mul(3.241, X2))), add(mul(sub(X1, X0), log(pow(X1, 2.843))), sin(log(sin(mul(1.139, X2))))))
# add(sin(sub(sin(pow(log(X1), 0.882)), mul(3.241, X2))), neg(sub(log(pow(X1, 3.074)), sin(neg(mul(mul(X0, X2), neg(X0)))))))
# neg(sub(sub(log(pow(X1, 3.074)), sin(neg(mul(mul(X0, X2), neg(X0))))), sin(mul(3.314, X2))))
# add(add(neg(sub(log(pow(X1, 3.074)), sin(neg(sub(mul(pow(X1, 3.402), log(X1)), sin(mul(3.314, X2))))))), neg(sin(neg(log(X2))))), sin(sub(mul(neg(sub(X2, X0)), add(pow(X1, 3.659), pow(X1, 0.196))), sin(log(log(X1))))))
# add(mul(mul(neg(pow(X0, 2.127)), sin(X0)), log(pow(X1, 2.727))), sin(neg(log(sin(sin(sub(0.882, mul(3.241, X2))))))))
# neg(sub(mul(add(add(sin(log(sin(mul(1.139, X2)))), add(pow(X0, 1.411), neg(mul(X1, X1)))), X0), log(X1)), sin(mul(3.314, X2))))
# neg(sub(log(pow(X1, 2.617)), sin(neg(mul(sin(sin(sub(pow(log(X1), 0.882), mul(3.241, X2)))), neg(X0))))))
# add(neg(sin(sub(sin(pow(X2, 0.407)), add(2.995, X1)))), add(sin(log(sin(mul(1.139, X2)))), add(mul(sub(neg(sin(mul(3.314, X2))), X0), log(pow(X1, 2.727))), neg(mul(X1, X1)))))
# add(sin(sub(sin(sin(add(add(X1, X1), log(X1)))), mul(3.241, X2))), neg(sub(log(pow(X1, 3.074)), sin(neg(mul(mul(X0, X2), neg(X0)))))))
# neg(sub(mul(neg(neg(add(pow(X1, 3.273), mul(sin(log(3.574)), pow(X0, 3.645))))), log(X1)), sin(mul(3.314, X2))))
#
#    5    13.99      1.68789e+10       19          175.863          177.376      0.00s
#
# D-CODE model:  -X0**C*log(X1) + sin(C*X2) + sin(log(sin(C*X2)))
#
# building blocks:
# log(X1**3.0742403911480958)
# X1**3.770980752092803
# sin(3.3140172432269743*X2)
# log(X1**3.770980752092803)
# X0**0.5878249949544383
# log(X1**3.2729696870560265)
# log(X1**2.975657216270497)
# log(X1**3.3246094514813405)
# X2**0.406762994817093
# -sin(3.746490065434555*X1)
# log(X1**2.726973032267852)
# -sin(3.2410061383495*X2 - 0.8600011312002894)
# log(X1**3.645308432311883)
# log(X1**2.617197856230026)
# sin(log(sin(1.1389042827740496*X2)))
# sin(1.1389042827740496*X2)
# log(sin(1.1389042827740496*X2))
# log(log(X0 - X1))
# sin(log(X1**3.2732231190603076))
# log(X1**2.8427049092103687)
# sin(log(log(X1)))
# X1**0.19644351349775316
# -sin(log(X2))
#
# number of building blocks:  23
