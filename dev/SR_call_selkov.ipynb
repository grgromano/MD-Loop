# %% [markdown]
# ##### import:

# %%
from Data.auxiliar_functions import SRT_simulation, D_CODE_simulation, set_param_freq

# %% [markdown]
# ## STD:

# %% [markdown]
# #### SR-T

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 2)
# [0.15497447 0.22434137 0.30058598 0.37387917 0.43877929 0.52140358
#  0.58472977 0.65524893 0.7164979  0.78411389 0.85167523 0.91517052
#  0.97801657 1.04296754 1.11238172 1.18807045 1.23653777 1.28930867
#  1.35667788 1.42279   ]
# [0.07044481 0.06345729 0.05250388 0.05364209 0.05527703 0.06456816
#  0.05349966 0.05281981 0.04949822 0.06421471 0.05957287 0.06260956
#  0.0646228  0.07433533 0.07632686 0.06975253 0.08006543 0.09206071
#  0.09950482 0.10216487]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79          62673.8       12         0.166613         0.158029      1.02m
#    1     5.45          62.8276       21          0.10559         0.105365     41.04s
#    2     4.74          317.767       21         0.104602         0.114256     20.05s
#
# promising programs:
# sub(sin(0.735), mul(mul(X0, X1), X1))
# sub(sin(0.735), mul(mul(X0, X1), X1))
# sub(0.638, mul(add(mul(0.893, X1), log(X0)), X1))
# sin(sub(0.639, mul(mul(X0, X1), X1)))
# sub(0.640, mul(add(mul(0.893, X1), log(X0)), X1))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(sub(0.346, X1)), mul(X1, X0))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
#
#    3     4.35          16.1666        8        0.0726267        0.0752973      0.00s
# sympy:
#
# -X0*X1**2 + 0.6702409484045361
#
# SR-T model:  C - X0*X1**2
#
# building blocks:
# X0*X1
# X0*X1**2
# 0.8926102299118411*X1
# cos(X1 - 0.34636101539428155)
# 0.6702409484045361
# -X0*X1**2
#
# number of building blocks:  6

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 2)
# [0.15497447 0.22434137 0.30058598 0.37387917 0.43877929 0.52140358
#  0.58472977 0.65524893 0.7164979  0.78411389 0.85167523 0.91517052
#  0.97801657 1.04296754 1.11238172 1.18807045 1.23653777 1.28930867
#  1.35667788 1.42279   ]
# [0.07044481 0.06345729 0.05250388 0.05364209 0.05527703 0.06456816
#  0.05349966 0.05281981 0.04949822 0.06421471 0.05957287 0.06260956
#  0.0646228  0.07433533 0.07632686 0.06975253 0.08006543 0.09206071
#  0.09950482 0.10216487]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79          62673.7       26         0.141245         0.139705     56.64s
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     5.48          79.7859        8         0.119471         0.117816     35.41s
#    2     3.93          291.239        8        0.0676473        0.0686272     18.41s
#
# promising programs:
# mul(X1, sub(mul(X0, X1), sin(X1)))
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(X1, sub(mul(X0, X1), sin(X1)))
#
#    3     4.90          52.1748       13        0.0603424        0.0621971      0.00s
# sympy:
#
# X0*X1**2 - X1*sin(X1**0.7943250077213431) - 0.021935213318760246*X1
#
# SR-T model:  -C*X1 + X0*X1**2 - X1*sin(X1**C)
#
# building blocks:
# X0*X1
# -0.021935213318760246*X1
# X0*X1**2
# -X1*sin(X1**0.7943250077213431)
#
# number of building blocks:  4

# %% [markdown]
# #### D-CODE

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 2)
# [0.15345595 0.18902692 0.22601871 0.2629156  0.29916586 0.33506656
#  0.37113832 0.40752473 0.44385582 0.47957149 0.5143465  0.5482792
#  0.58177606 0.61528152 0.6490367  0.68298834 0.71689464 0.75056486
#  0.7840423  0.8175438 ]
# [0.05994732 0.0564394  0.05392707 0.05239886 0.05151318 0.05099364
#  0.05075649 0.05079127 0.05102391 0.05132008 0.0515786  0.05178189
#  0.05196836 0.05219531 0.05253473 0.05306748 0.05385338 0.05492143
#  0.05630524 0.05804741]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79      3.85206e+16        6          9.78787          9.73844      3.33m
#    1     9.26       2.0252e+09       10          8.78123           8.7435      3.37m
#    2     9.15      1.44052e+11       21           5.9229          5.90096      2.75m
#
# promising programs:
# sub(sin(0.735), mul(mul(X1, X0), X1))
# sub(sin(0.735), mul(mul(X1, X0), X1))
# sub(sub(cos(mul(neg(X1), mul(X0, X1))), log(cos(cos(X1)))), pow(X0, 0.208))
# sub(0.527, mul(X1, mul(X1, X0)))
# sub(cos(pow(X1, pow(X0, 0.408))), mul(X0, X1))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# mul(pow(X1, 0.148), sub(cos(X1), mul(X0, X1)))
# sub(sin(sin(add(0.845, add(sub(div(X0, X0), pow(X1, 0.692)), sub(cos(X1), sin(X0)))))), mul(X1, X0))
# sub(cos(sub(pow(X1, 0.419), mul(mul(0.710, X1), add(X1, X0)))), mul(X1, X0))
# neg(mul(sub(mul(X0, X1), cos(X1)), cos(log(X0))))
# sub(0.640, mul(add(mul(0.893, X1), log(X0)), X1))
#
#    3     9.80      1.49486e+07        8          1.71017          1.70644      1.40m
#    4    10.55      3.00994e+09        7          1.19381          1.19777     38.24s
#
# promising programs:
# sub(0.639, mul(X1, mul(X1, X0)))
# sub(0.640, mul(mul(X0, X1), X1))
# sub(0.640, mul(mul(X1, X0), X1))
# sub(0.640, mul(mul(X1, X0), X1))
# sub(0.640, mul(mul(X1, X0), X1))
# sub(0.640, mul(mul(X1, X0), X1))
# sub(0.640, mul(mul(X1, X0), X1))
# sub(0.640, mul(mul(X0, X1), X1))
# sub(0.647, mul(X1, mul(X0, X1)))
# sub(0.656, mul(X1, mul(X1, X0)))
# sub(0.656, mul(X1, mul(X0, X1)))
# sub(0.656, mul(X1, mul(X1, X0)))
# sub(sin(0.721), mul(mul(X0, X1), X1))
# add(cos(0.970), mul(mul(X1, pow(X1, cos(0.493))), neg(X0)))
# add(cos(0.970), mul(mul(X1, X1), neg(X0)))
#
#    5     8.71      3.87131e+07        7          1.18068          1.17987      0.00s
#
# -X0*X1**2 + 0.6387358987732742
#
# D-CODE model:  C - X0*X1**2
#
# building blocks:
# X0*X1
# X0*X1**2
# cos(cos(X1))
# X0**0.20780722320226552
# log(cos(cos(X1)))
# cos(X1**(X0**0.4080334338428045))
# X1**(X0**0.4080334338428045)
# X0**0.4080334338428045
# X1**0.14816683449691767
# X1**0.4187823353504542
# 0.7100156363487055*X1
# cos(log(X0))
# 0.8926102299118411*X1
# X1**0.88099756292582486
# X1**1.8809975629258249
# X1**2
# 0.6387358987732742
# -X0*X1**2
#
# number of building blocks:  18

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 2)
# [0.15345595 0.18902692 0.22601871 0.2629156  0.29916586 0.33506656
#  0.37113832 0.40752473 0.44385582 0.47957149 0.5143465  0.5482792
#  0.58177606 0.61528152 0.6490367  0.68298834 0.71689464 0.75056486
#  0.7840423  0.8175438 ]
# [0.05994732 0.0564394  0.05392707 0.05239886 0.05151318 0.05099364
#  0.05075649 0.05079127 0.05102391 0.05132008 0.0515786  0.05178189
#  0.05196836 0.05219531 0.05253473 0.05306748 0.05385338 0.05492143
#  0.05630524 0.05804741]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.79      3.85206e+16       26          9.42021          9.39591      3.08m
#    1     8.50      1.68832e+10       27          7.16507          7.17526      2.54m
#    2     8.78      6.21148e+08       10          2.41369          2.36688      1.90m
#
# promising programs:
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(X1)), neg(neg(X1)))
# mul(mul(pow(X1, 0.225), sub(mul(X1, X0), sin(X1))), pow(X1, 0.751))
# mul(sub(mul(X0, X1), sin(X1)), pow(X1, 0.901))
# mul(mul(0.911, X1), sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.751))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.745))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.745))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.745))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.745))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.745))
# mul(sub(mul(X1, X0), sin(X1)), pow(X1, 0.698))
# mul(sin(sub(mul(X0, X1), sin(X1))), X1)
# div(sub(sub(mul(X1, X0), cos(X0)), mul(neg(0.622), sub(X1, X1))), sub(sub(div(0.553, X1), neg(X0)), mul(log(X1), div(X0, X1))))
# mul(neg(X1), sub(0.890, mul(X0, X1)))
#
#    3    11.10      2.17166e+08       10           1.1247          1.13302      1.41m
#    4    14.78      3.14333e+09       12         0.999686          1.00821     48.08s
#
# promising programs:
# mul(X1, sub(neg(mul(neg(X0), X1)), sin(pow(X1, 0.687))))
# mul(X1, sub(neg(mul(neg(X0), X1)), sin(pow(X1, 0.687))))
# mul(X1, sub(neg(mul(neg(X0), X1)), sin(pow(X1, 0.687))))
# mul(X1, sub(neg(mul(neg(X0), X1)), sin(pow(X1, 0.687))))
# mul(X1, sub(neg(mul(neg(X0), X1)), sin(pow(X1, 0.687))))
# mul(sub(mul(X1, X0), sin(pow(X1, 0.738))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X1, X0), sin(pow(X1, 0.794))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.794))), X1)
#
#    5    17.57      4.00503e+06       12          1.00003          1.00514      0.00s
#
# X0*X1**2 - X1*sin(X1**0.6871383876106895)
#
# D-CODE model:  X0*X1**2 - X1*sin(X1**C)
#
# building blocks:
# X1**0.7943250077213431
# X0*X1
# X1**0.751433895026138
# X1**0.9013525629384965
# 0.9113615032796276*X1
# X1**0.7450798705955934
# X1**0.6979859103208252
# X0*log(X1)/X1
# 0.5530796327100012/X1
# -X0*X1
# X1**0.6871383876106895
# sin(X1**0.738313045523661)
# X0*X1**2
# -X1*sin(X1**0.6871383876106895)
#
# number of building blocks:  14

# %% [markdown]
# ## parameter $\rho$:

# %% [markdown]
# #### SR-T

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE_rho' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_rho, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.14981783 0.23310612 0.31456448 0.38300336 0.4684289  0.54520498
#  0.6069051  0.68617913 0.74402328 0.82639971 0.90354882 0.96789434
#  1.03218884 1.10593864 1.1780383  1.24079364 1.30571005 1.36406019
#  1.44238944 1.49670289]
# [0.0575199  0.06521222 0.05138028 0.0575364  0.05368962 0.05135575
#  0.0549983  0.05390059 0.04980796 0.06447111 0.06032239 0.07497278
#  0.07141386 0.0808736  0.06835776 0.0858758  0.08972761 0.10008734
#  0.09141637 0.10664898]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          28102.6        6         0.228498         0.223527      1.07m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     5.51          17.5214        7         0.189557         0.192872     40.94s
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    2     4.48          6.92037        6         0.173639         0.176318     18.06s
#
# promising programs:
# sub(sin(X2), mul(mul(X1, X0), X1))
# sub(sin(X2), mul(mul(X0, X1), X1))
# sub(cos(X2), mul(mul(X1, X0), X1))
# sub(X2, mul(mul(X0, X1), X1))
# sub(sin(0.841), mul(mul(X1, X0), X1))
# sub(sin(0.841), mul(mul(X1, X0), X1))
# sub(cos(mul(X2, X1)), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X0, X1))
#
#    3     3.76          3.70498        8         0.078228        0.0804948      0.00s
# sympy:
#
# SR-T model:  -X0*X1**2 + sin(X2)
#
# building blocks:
# X0*X1
# X0*X1**2
# X1*X2
# cos(X1*X2)
# -X0*X1**2
# sin(X2)
#
# number of building blocks:  6

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE_rho' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_rho, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.14981783 0.23310612 0.31456448 0.38300336 0.4684289  0.54520498
#  0.6069051  0.68617913 0.74402328 0.82639971 0.90354882 0.96789434
#  1.03218884 1.10593864 1.1780383  1.24079364 1.30571005 1.36406019
#  1.44238944 1.49670289]
# [0.0575199  0.06521222 0.05138028 0.0575364  0.05368962 0.05135575
#  0.0549983  0.05390059 0.04980796 0.06447111 0.06032239 0.07497278
#  0.07141386 0.0808736  0.06835776 0.0858758  0.08972761 0.10008734
#  0.09141637 0.10664898]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          28102.5        8         0.197703         0.203034      3.41m
#    1     5.41          39.1121       16         0.118015         0.114113      2.92m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    2     3.79          41.9316       14         0.106528         0.108465      2.54m
#
# promising programs:
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(X1, mul(sin(X1), sub(X0, X2)))
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
# mul(mul(sin(X1), sub(X0, X2)), X1)
#
#    3     4.43          52.8963       14         0.106036         0.112889      2.61m
#    4     5.52          39.0171        8        0.0684833        0.0712037      2.44m
#
# promising programs:
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(X1, sub(mul(X0, X1), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
#
#    5     6.47          16.3631       15        0.0655409         0.066269      1.94m
#    6     7.51          8.77168       15        0.0653149        0.0683028      1.38m
#    7     8.39          48.8512       19        0.0539155        0.0551362      1.00m
#    8     8.11          2.52798       10        0.0606414        0.0598541     36.44s
#    9     7.91          3.15065       10        0.0546721        0.0533375     17.35s
#
# promising programs:
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X0, X1), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
# mul(sub(mul(X1, X0), sin(X1)), X1)
# mul(X1, sub(mul(X1, X0), sin(X1)))
#
#   10     7.91          3.21718       10        0.0576561        0.0595303      0.00s
# sympy:
#
# X0*X1**2 - X1*sin(X1**0.6170434121553142)
#
# SR-T model:  X0*X1**2 - X1*sin(X1**C)
#
# building blocks:
# (X0 - X2)*sin(X1)
# X0*X1
# X0*X1**2
# -X1*sin(X1**0.6170434121553142)
#
# number of building blocks:  4

# %% [markdown]
# #### D-CODE

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE_rho' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_rho, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 3)
# [0.12789842 0.16652566 0.20642063 0.2450745  0.282308   0.3196351
#  0.35834546 0.39802314 0.43686003 0.47341957 0.50808182 0.54272073
#  0.57894685 0.61667283 0.65436768 0.69062565 0.72543357 0.75998609
#  0.79542587 0.83183101]
# [0.04809699 0.04704538 0.0469786  0.04716487 0.04673204 0.04544041
#  0.04391412 0.04313774 0.0436329  0.04501382 0.04631134 0.04679293
#  0.04656235 0.04640984 0.04706249 0.04854291 0.0502383  0.05157893
#  0.05260949 0.05385612]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12       5.6407e+15       12          19.5554            21.81      2.97m
#    1     9.22      1.17165e+10        7          11.0737          11.3151      2.28m
#    2     8.35      4.11655e+06        8           5.6548          6.55425      1.99m
#
# promising programs:
# sub(sin(X2), mul(X1, mul(X1, X0)))
# sub(0.542, div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
# sub(cos(X2), mul(mul(X1, X0), X1))
# sub(sin(0.841), mul(mul(X1, X0), X1))
# add(mul(neg(X1), mul(X0, X1)), X2)
# sub(X2, mul(mul(X1, X1), X0))
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X1, X0)), X2)
# sub(X2, div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
# add(mul(neg(X1), mul(X0, X1)), X2)
# add(mul(neg(X1), mul(X0, X1)), 0.494)
#
#    3     8.18      1.87015e+06        8          2.75884          2.74088      1.26m
#    4    10.07      7.09563e+07       12          2.16908          2.20956     34.64s
#
# promising programs:
# add(cos(pow(X2, 0.280)), neg(mul(pow(X1, 0.859), mul(X0, X1))))
# sub(cos(pow(X2, 0.324)), mul(mul(X0, X1), pow(X1, 0.990)))
# sub(cos(pow(X2, 0.324)), mul(mul(X0, X1), pow(X1, 0.990)))
# sub(cos(pow(X2, 0.324)), mul(mul(X0, X1), pow(X1, 0.990)))
# add(cos(sin(neg(log(sub(X1, X1))))), neg(mul(pow(X1, 0.859), mul(X0, X1))))
# sub(cos(pow(X2, 0.324)), mul(mul(X0, X1), X1))
# sub(cos(cos(neg(sin(add(log(X2), div(X1, X0)))))), mul(mul(X0, X1), pow(X1, 0.990)))
# sub(cos(cos(sin(sub(sin(0.841), pow(X1, sin(X0)))))), mul(mul(X0, X1), X1))
# sub(cos(pow(X2, 0.542)), mul(mul(X0, X1), X1))
# sub(mul(X2, X2), mul(mul(X0, X1), pow(X1, 0.990)))
# sub(cos(cos(sub(0.694, X1))), mul(mul(X0, X1), X1))
# sub(cos(0.956), div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
# sub(cos(0.956), div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
# sub(cos(0.956), div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
# sub(cos(0.956), div(neg(neg(X2)), div(div(X2, X1), mul(X1, X0))))
#
#    5    10.24      2.79521e+07       13          1.92926          1.54709      0.00s
#
# -X0*X1**1.858669248832049 + cos(X2**0.28015991338702234)
#
# D-CODE model:  -X0*X1**C + cos(X2**C)
#
# building blocks:
# X0*X1
# X0*X1**2
# X2/X1
# -X0*X1**2
# X1**2
# X2**0.28015991338702234
# X1**0.8586692488320489
# cos(X2**0.28015991338702234)
# cos(X2**0.3239902927173931)
# X2**0.3239902927173931
# X1**0.9897174196249718
# nan
# X1/X0
# X1**sin(X0)
# X2**0.5419124719004187
# cos(X2**0.5419124719004187)
# X2**2
# cos(X1 - 0.6943002138388048)
# cos(cos(X1 - 0.6943002138388048))
# -X0*X1**1.858669248832049
#
# number of building blocks:  20

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE_rho' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_rho, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 3)
# [0.12789842 0.16652566 0.20642063 0.2450745  0.282308   0.3196351
#  0.35834546 0.39802314 0.43686003 0.47341957 0.50808182 0.54272073
#  0.57894685 0.61667283 0.65436768 0.69062565 0.72543357 0.75998609
#  0.79542587 0.83183101]
# [0.04809699 0.04704538 0.0469786  0.04716487 0.04673204 0.04544041
#  0.04391412 0.04313774 0.0436329  0.04501382 0.04631134 0.04679293
#  0.04656235 0.04640984 0.04706249 0.04854291 0.0502383  0.05157893
#  0.05260949 0.05385612]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12       5.6407e+15        8          15.1239          15.3709      2.87m
#    1     8.64      1.43897e+10       16          5.59672          7.94253      2.51m
#    2     9.43      7.99359e+09       16          4.63207          5.03895      1.98m
#
# promising programs:
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), neg(neg(X1)))
# mul(sin(sin(sub(add(mul(X0, X1), sub(X0, X0)), cos(log(add(pow(X2, 0.897), mul(0.968, X0))))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), sub(X0, X0)), cos(log(add(div(sin(X2), sin(X1)), sin(X0))))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), log(pow(X0, 0.255))), cos(log(X1))))), X1)
# mul(sin(sin(sub(mul(X0, X1), sin(pow(X1, 0.577))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(0.053, X0)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), log(pow(X0, 0.255))), cos(neg(X2))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(0.053, X0)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(0.053, X0)), cos(mul(0.267, X0))))), X1)
# add(sin(mul(X1, add(log(X1), log(X0)))), 0.149)
# add(sin(mul(X1, add(log(X1), log(X0)))), 0.149)
# add(sin(mul(X1, add(log(X1), log(X0)))), 0.297)
# add(sin(mul(X1, add(log(X1), log(X0)))), 0.149)
# add(sin(mul(X1, add(log(X1), log(X0)))), 0.149)
# sin(mul(sub(mul(X1, X0), sin(X1)), X1))
#
#    3    10.21      2.45013e+08       12           1.5423          1.40837      1.25m
#    4    13.66      7.34765e+07       10          1.50074          1.78237     39.18s
#
# promising programs:
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.577))))
# mul(sub(add(mul(X0, X1), sub(X0, X0)), cos(log(add(div(sin(X2), sin(X1)), sin(X0))))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.577))))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), neg(neg(X1)))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.577))))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.577))))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), neg(neg(X1)))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.577))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.577))))
#
#    5    14.57      2.34125e+06       20          1.37807          1.13785      0.00s
#
# D-CODE model:  X1*(X0*X1 - cos(log(sin(X0) + sin(X2)/sin(X1))))
#
# building blocks:
# sin(X1**0.5773118489297618)
# X1**0.5773118489297618
# X0*X1
# X2**0.897342752913479
# 0.9680109080601397*X0
# sin(X2)/sin(X1)
# log(X0**0.2549142101116669)
# cos(log(X1))
# 0.05269904064221812*X0
# 0.26712866263871804*X0
# cos(X2)
# cos(0.26712866263871804*X0)
# X1
# X0*X1 - cos(log(sin(X0) + sin(X2)/sin(X1)))
#
# number of building blocks:  14

# %% [markdown]
# ## parameter $\sigma$:

# %% [markdown]
# #### SR-T

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE_sigma' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_sigma, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.1458281  0.22550465 0.30372498 0.36929588 0.45222032 0.52685951
#  0.58678486 0.66464485 0.7214351  0.80311812 0.87993572 0.94431418
#  1.00900995 1.08353457 1.15678935 1.22108843 1.28794723 1.34865029
#  1.42975685 1.48728799]
# [0.05698795 0.0638393  0.04889081 0.05368449 0.04825584 0.04414406
#  0.04583328 0.04262488 0.03627968 0.04856156 0.04191379 0.05395608
#  0.04768672 0.0543384  0.03891978 0.05344138 0.05420244 0.06137477
#  0.04941576 0.061254  ]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          32586.7        6         0.243252         0.235975     52.58s
#    1     4.15          13.3079       14         0.234038         0.227651     39.02s
#    2     4.00          12.7774       10         0.199591         0.194794     19.41s
#
# promising programs:
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(pow(X2, 0.165), mul(X1, mul(X0, X1)))
# sub(pow(X2, 0.165), mul(X1, mul(X0, X1)))
# sub(sin(0.841), mul(mul(X1, X0), X1))
# sub(cos(X1), mul(X1, X0))
# sub(cos(sub(0.577, X1)), mul(X1, X0))
# sub(cos(sub(0.700, X1)), mul(X1, X0))
# sub(cos(sub(0.700, X1)), mul(X0, X1))
# sub(cos(sub(0.700, X1)), mul(X0, X1))
# sub(cos(sub(0.700, X1)), mul(X0, X1))
# sub(cos(sub(0.738, X1)), mul(X1, X0))
# sub(cos(sub(0.700, X1)), mul(X0, X1))
# sub(cos(sub(0.699, X1)), mul(X1, X0))
# sub(cos(sub(0.700, X1)), mul(X0, X1))
# sub(cos(sub(0.715, X1)), mul(X1, X0))
#
#    3     4.02          4.16253       10        0.0741805         0.072347      0.00s
# sympy:
#
# -X0*X1**2 - X2 + 0.7636866460567714
#
# SR-T model:  C - X0*X1**2 - X2
#
# building blocks:
# X0*X1**2
# X0*X1
# X2**0.16469815417251044
# cos(X1 - 0.5768728740085401)
# cos(X1 - 0.699982888506386)
# cos(X1 - 0.7384681902262121)
# cos(X1 - 0.7152257446674678)
# 0.7636866460567714
# -X2
# -X0*X1**2
#
# number of building blocks:  10

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE_sigma' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
alg = 'tv' # help="name of the benchmark", type=str, default='tv', choices=['tv', 'spline', 'gp']
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
SRT_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, alg, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_sigma, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, alg=tv, seed=100, n_seed=1
# Dataset shape:  (151, 50, 3)
# [0.1458281  0.22550465 0.30372498 0.36929588 0.45222032 0.52685951
#  0.58678486 0.66464485 0.7214351  0.80311812 0.87993572 0.94431418
#  1.00900995 1.08353457 1.15678935 1.22108843 1.28794723 1.34865029
#  1.42975685 1.48728799]
# [0.05698795 0.0638393  0.04889081 0.05368449 0.04825584 0.04414406
#  0.04583328 0.04262488 0.03627968 0.04856156 0.04191379 0.05395608
#  0.04768672 0.0543384  0.03891978 0.05344138 0.05420244 0.06137477
#  0.04941576 0.061254  ]
# Numerical differentiation: Done.
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12          32586.6        5         0.207141          0.18726      3.15m
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
# /Users/grgromano/Documents/polimi/thesis/repos/gplearn/gplearn/functions.py:132: RuntimeWarning: overflow encountered in power
#   return np.where(np.logical_and(np.minimum(x1, x2) >= 0, np.maximum(x1, x2) <= 10), np.power(x1, x2), 1000)
#    1     4.20          19.2495       12         0.152736         0.158434      2.50m
#    2     2.76          13.0388       12         0.150414         0.179334      2.20m
#
# promising programs:
# mul(sin(X1), sub(mul(X0, X1), X1))
# mul(sin(X1), sub(mul(X0, X1), X1))
# mul(sin(X1), sub(mul(X0, X1), X1))
# mul(sin(X1), sub(mul(X0, X1), X1))
# mul(sin(X1), add(mul(X0, X1), neg(X1)))
# sin(mul(sin(X1), log(X0)))
# mul(sub(mul(X0, X1), mul(0.769, X1)), sin(X1))
# mul(sin(X1), add(neg(X1), mul(X1, X0)))
# sin(mul(sin(X1), log(X0)))
# sin(mul(sin(X1), log(X0)))
# sin(mul(sin(X1), log(X0)))
# sin(mul(sin(X1), sub(mul(X0, X1), X1)))
# mul(sin(X1), log(X0))
# sin(mul(sin(X1), log(X0)))
# mul(sin(X1), log(X0))
#
#    3     3.94          45.6601       10         0.148749         0.149238      2.26m
#    4     5.05          44.8716       10         0.118687         0.124331      1.92m
#
# promising programs:
# mul(sub(mul(X0, X1), sin(X1)), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.883))), X1)
# mul(sub(mul(X0, X1), sin(X1)), pow(X1, 0.883))
# mul(sub(mul(X0, X1), sin(X1)), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
# sub(mul(mul(X0, X1), X1), X1)
#
#    5     5.89          15.3007       10         0.075807        0.0717507      1.57m
#    6     6.81          8.36964       10        0.0746483        0.0821795      1.25m
#    7     7.98          51.8298       10        0.0752427        0.0768297     51.78s
#    8     7.65          36.3729        9         0.069056        0.0671465     33.53s
#    9     7.58          8.68639       10         0.061477        0.0643076     17.21s
#
# promising programs:
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# sub(mul(mul(X0, X1), X1), sub(X1, X2))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.576))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.576))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.576))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.576))), X1)
# mul(sub(mul(X0, X1), sin(pow(X1, 0.617))), X1)
# mul(X1, sub(mul(X0, X1), sin(pow(X1, 0.683))))
# mul(sub(mul(X0, X1), sin(pow(X1, 0.430))), X1)
#
#   10     7.96          3.74584       13        0.0582507        0.0574658      0.00s
#
# X0*X1**0.8165373464701753*X2 + X0*X1**1.816537346470175 - X1
#
# SR-T model:  X0*X1**C*X2 + X0*X1**C - X1
#
# building blocks:
# X0*X1
# log(X0)*sin(X1)
# sin(log(X0)*sin(X1))
# 0.7689574090217561*X1
# X1**0.8829324290942291
# X0*X1**2
# X1**0.5760047570712437
# sin(X1**0.5760047570712437)
# X1**0.6170434121553142
# sin(X1**0.6170434121553142)
# sin(X1**0.6828300760775391)
# sin(X1**0.4303434090884801)
# X1**0.4303434090884801
# -X1
# X0*X1**1.816537346470175
# X0*X1**0.8165373464701753*X2
#
# number of building blocks:  16

# %% [markdown]
# #### D-CODE

# %% [markdown]
# ##### eq. 1:

# %%
# setting:
ode_name = 'SelkovODE_sigma' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 0 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_sigma, ode_param=None, x_id=0, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 3)
# [0.10798811 0.14461006 0.18162461 0.21726778 0.25210083 0.28789552
#  0.32558013 0.36408205 0.40118186 0.4355942  0.46823856 0.50141322
#  0.53667643 0.57352933 0.61012873 0.6451742  0.67902867 0.71309871
#  0.74833014 0.78439601]
# [0.04647978 0.04554194 0.04472698 0.04406684 0.04308168 0.0413505
#  0.03906664 0.03705445 0.03614866 0.03644126 0.03710994 0.03706667
#  0.03588465 0.03414376 0.0328644  0.03259091 0.0330211  0.03348442
#  0.03368041 0.03387087]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      6.12532e+15        6          34.3757          25.0332      3.40m
#    1     8.23      9.41281e+09        6          17.8446          13.8441      2.51m
#    2     9.78      4.02921e+08        6          16.7966          23.2763      1.99m
#
# promising programs:
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), mul(X1, X0)))
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# add(cos(neg(neg(pow(X2, mul(X1, X0))))), sub(cos(sub(pow(pow(X1, 0.879), div(X1, X1)), sin(mul(0.666, X2)))), add(mul(X0, X1), pow(X2, 0.012))))
# add(mul(add(0.431, X0), sub(X2, X1)), sin(add(0.837, X1)))
# sub(cos(sub(cos(sub(X1, X2)), pow(X1, 0.694))), mul(X0, X1))
# sub(pow(X2, 0.165), mul(X1, mul(X0, X1)))
# div(add(neg(sub(cos(X1), mul(sub(X0, X0), X0))), mul(X1, X0)), sub(neg(cos(X2)), cos(div(div(pow(X1, 0.430), div(X1, X1)), sub(X2, cos(X2))))))
# sub(sin(0.841), mul(mul(X1, X0), X1))
# sub(cos(X1), mul(X0, X1))
# sub(cos(X1), mul(X1, X0))
# sub(cos(X1), mul(X0, X1))
# sub(sin(log(sub(pow(X2, 0.432), div(0.568, X1)))), mul(X0, X1))
# sub(cos(X1), mul(X1, X0))
# sub(cos(neg(X1)), mul(X1, X0))
# sub(cos(X1), mul(X1, X0))
#
#    3     8.09      6.35444e+06       11          12.8739          14.3039      1.26m
#    4     9.49      1.00672e+07       15            10.43          7.67225     34.47s
#
# promising programs:
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(0.557, mul(0.788, mul(mul(X1, X0), X1)))
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(pow(X2, 0.165), mul(pow(X1, 0.892), pow(add(mul(X1, X0), X2), 0.935)))
# sub(pow(X2, 0.165), mul(X1, pow(add(mul(X1, X0), X2), 0.935)))
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(sub(cos(0.702), mul(X1, mul(X0, X1))), X2)
# sub(sub(sin(cos(sin(0.576))), mul(X1, mul(X0, X1))), X2)
# sub(sub(0.720, mul(X1, mul(X0, X1))), X2)
#
#    5    10.22      1.04578e+10       15          9.47525          16.2645      0.00s
#
# -X1**0.8924996630113889*(X0*X1 + X2)**0.9351023187747841 + X2**0.16469815417251044
#
# D-CODE model:  -X1**C*(X0*X1 + X2)**C + X2**C
#
# building blocks:
# X0*X1
# X1**0.8924996630113889
# X2**0.16469815417251044
# X0*X1**2
# X1**0.8791702600683412
# sin(0.6660429543781583*X2)
# X2**0.011835358734055392
# X2**(X0*X1)
# 1
# sin(X1 + 0.8365891726631353)
# X1**0.6938660023863905
# X2**0.43208166449001173
# 0.5677719064200911/X1
# cos(X1)
# 0.8551725399486004
# 0.7546841288101646
# -X1**0.8924996630113889*(X0*X1 + X2)**0.9351023187747841
#
# number of building blocks:  17

# %% [markdown]
# ##### eq. 2:

# %%
# setting:
ode_name = 'SelkovODE_sigma' # help="name of the ode", type=str
ode_param = None # help="parameters of the ode (default: None)", type=str, default=None
x_id = 1 # help="ID of the equation to be learned", type=int, default=0
freq = 10 # help="sampling frequency", type=float, default=10
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_sigma = 0.01 # help="noise level (default 0)", type=float, default=0.
seed = 100 # help="random seed", type=int, default=0
n_seed = 1 # help="random seed", type=int, default=10
ode_param, freq = set_param_freq(ode_param, freq)

# run simulation:
D_CODE_simulation(ode_name, ode_param, x_id, freq, n_sample, noise_sigma, seed, n_seed)
# Out:
# Running with: ode_name=SelkovODE_sigma, ode_param=None, x_id=1, freq=10, n_sample=50, noise_sigma=0.01, seed=100, n_seed=1
# Dataset shape:  (301, 50, 3)
# [0.10798811 0.14461006 0.18162461 0.21726778 0.25210083 0.28789552
#  0.32558013 0.36408205 0.40118186 0.4355942  0.46823856 0.50141322
#  0.53667643 0.57352933 0.61012873 0.6451742  0.67902867 0.71309871
#  0.74833014 0.78439601]
# [0.04647978 0.04554194 0.04472698 0.04406684 0.04308168 0.0413505
#  0.03906664 0.03705445 0.03614866 0.03644126 0.03710994 0.03706667
#  0.03588465 0.03414376 0.0328644  0.03259091 0.0330211  0.03348442
#  0.03368041 0.03387087]
# Functions set:  {'neg': 1, 'mul': 1, 'log': 1, 'add': 1, 'sub': 1, 'div': 1, 'pow': 1, 'sin': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.12      6.12532e+15       10            20.43          23.1215      2.84m
#    1     6.92      1.97466e+10       16          13.6602          22.3168      2.13m
#    2     7.10      3.56949e+09       16          13.4396          14.7649      1.66m
#
# promising programs:
# sub(neg(mul(X0, neg(sub(X1, X2)))), sin(X1))
# sub(neg(mul(X0, neg(sub(X1, X2)))), sin(X1))
# mul(sin(sin(sub(add(mul(X0, X1), div(sin(X2), sin(X1))), cos(X2)))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(pow(X2, 0.745), X0)))), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(X2)))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(mul(0.267, pow(X0, 0.461)))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(log(cos(0.148)), log(add(X2, X0)))), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(mul(0.521, X2), X0)))), cos(mul(mul(X0, X2), X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(mul(0.521, X2), pow(X0, 0.473))))), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(mul(0.521, X2), pow(X0, 0.217))))), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(X0, X2)), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), sub(X0, X0)), cos(mul(0.267, X0))))), X1)
#
#    3     8.01      1.00369e+07       10           11.852          11.7883      1.18m
#    4    11.68       1.3361e+07       29          10.9805          16.0118     38.58s
#
# promising programs:
# mul(sub(log(pow(X0, 0.541)), sub(cos(add(neg(X1), cos(X0))), cos(sin(mul(pow(X0, 0.463), sub(mul(X0, X1), mul(0.769, X1))))))), X1)
# mul(sub(mul(X1, X0), pow(X1, 0.271)), pow(X1, 0.600))
# mul(sub(mul(mul(X1, X0), cos(X2)), pow(X1, 0.271)), pow(X1, 0.600))
# mul(sin(sin(sub(add(mul(X0, X1), div(sin(X2), sin(X1))), cos(X2)))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(pow(X2, 0.745), X0)))), cos(X2)))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(add(neg(sin(0.950)), mul(0.555, cos(X2))), mul(add(sub(0.416, X1), div(X2, X2)), sub(mul(0.521, X2), X0)))), cos(mul(mul(X0, X2), X0))))), X1)
# sub(neg(mul(X0, neg(sub(X1, X2)))), sin(X1))
# add(mul(mul(X0, X1), X1), sub(X2, X1))
# mul(sub(mul(mul(X1, X0), cos(X2)), pow(X1, 0.271)), cos(add(log(neg(X2)), sin(sin(sub(0.664, X1))))))
# mul(sub(mul(X1, X0), pow(X1, 0.271)), cos(add(log(neg(X2)), sin(sin(sub(0.664, X1))))))
# mul(sin(sin(sub(add(mul(X0, X1), sin(mul(X0, X2))), cos(mul(0.267, X0))))), X1)
# mul(sin(sin(sub(add(mul(X0, X1), mul(pow(X2, 0.491), mul(add(sub(cos(pow(X0, 0.473)), X1), div(X2, X2)), sub(X0, pow(X0, 0.217))))), cos(mul(0.267, X0))))), X1)
# sub(neg(mul(X0, neg(sub(X1, X2)))), sin(X1))
# mul(sin(sin(sub(add(mul(X0, X1), neg(div(sub(pow(X0, 0.377), mul(X0, X1)), div(add(0.948, X1), log(0.753))))), cos(mul(0.267, X0))))), X1)
# sub(neg(mul(X0, neg(sub(X1, X2)))), sin(X1))
#
#    5    18.29      3.02827e+09       27          10.7771           14.343      0.00s
#
# 0.5409451755926489*X1*log(X0) - X1*cos(X1 - cos(X0)) + X1*cos(sin(0.7689574090217561*X0**0.4627322232613775*X1 - X0**1.462732223261378*X1))
#
# D-CODE model:  C*X1*log(X0) - X1*cos(X1 - cos(X0)) + X1*cos(sin(C*X0**C*X1 - X0**C*X1))
#
# building blocks:
# X0*(-X1 + X2)
# sin(X2)/sin(X1)
# cos(0.26712866263871804*X0)
# X2**0.745324697054009
# X0*X1
# 0.26712866263871804*X0
# X0*X2
# X0**0.46124618027838066
# -0.011017776823576495
# log(X0 + X2)
# 0.5547955379037481*cos(X2)
# 0.5210988620525617*X2
# cos(X1 - cos(X0))
# X0**0.4627322232613775
# 0.7689574090217561*X1
# X0**0.5409451755926489
# X1**0.2710294431686936
# X1**0.5999494073029139
# X0*X1**2
# -sin(X1 - 0.6635264170302746)
# log(-X2)
# -sin(sin(X1 - 0.6635264170302746))
# X0**0.2167743072194737
# X0**0.47270173347624456
# X0**0.376887524088509
# X1*cos(sin(0.7689574090217561*X0**0.4627322232613775*X1 - X0**1.462732223261378*X1))
# -X1*cos(X1 - cos(X0))
# 0.5409451755926489*X1*log(X0)
#
# number of building blocks:  28
